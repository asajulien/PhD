# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdb
from IPython.display import display
import os
import seaborn as sns
import statsmodels.formula.api as sm
from numpy.polynomial.polynomial import polyfit
from sklearn.model_selection import train_test_split
import sklearn
from math import sqrt
import glob

# %%
s_patens = pd.read_csv('C:/Users/arj26323/Documents/Data/Biomass datasets/Massachusetts/LTE-MP-LPP-biomass.csv')
s_alterniflora = pd.read_csv('C:/Users/arj26323/Documents/Data/Biomass datasets/Massachusetts/LTE-MP-LPA-biomass.csv')

s_patens['Latitude'] = 42.730953216553
s_patens['Longitude'] = -70.842918395996

s_alterniflora['Latitude'] = 42.730954
s_alterniflora['Longitude'] = -70.842915

s_patens.rename(columns={'LIVE biomass':'liveMass'}, inplace=True)
s_alterniflora.rename(columns={'MEAN BIOMASS':'liveMass'}, inplace=True)

df = pd.concat([s_patens, s_alterniflora])

df['Date'] = pd.to_datetime(df[['YEAR', 'MONTH', 'DAY']])

display(df)
# Out:
#            SITE  YEAR  MONTH  DAY PLOT TRT  SP biomass  DS biomass  \
# 0    LTE-MP-LPP  2000      8   24    1   N       756.0         0.0
# 1    LTE-MP-LPP  2000      8   24    2   P       313.0         0.0
# 2    LTE-MP-LPP  2000      8   24    3   N       406.0         0.0
# 3    LTE-MP-LPP  2000      8   24    4   N       403.0         0.0
# 4    LTE-MP-LPP  2000      8   24    6   P       725.0         0.0
# ..          ...   ...    ...  ...  ...  ..         ...         ...
# 219  LTE-MP-LPA  2018      5    2  NaN  NP         NaN         NaN
# 220  LTE-MP-LPA  2018      6    8  NaN  NP         NaN         NaN
# 221  LTE-MP-LPA  2018      7   18  NaN  NP         NaN         NaN
# 222  LTE-MP-LPA  2018      8   28  NaN  NP         NaN         NaN
# 223  LTE-MP-LPA  2018     10    3  NaN  NP         NaN         NaN
#
#      SA biomass  SE biomass  liveMass DEAD biomass   Latitude  Longitude  \
# 0          68.0         0.0     823.0          497  42.730953 -70.842918
# 1           0.0         0.0     313.0          248  42.730953 -70.842918
# 2           0.0         0.0     406.0          294  42.730953 -70.842918
# 3           0.0         0.0     403.0          261  42.730953 -70.842918
# 4           0.0         0.0     725.0          297  42.730953 -70.842918
# ..          ...         ...       ...          ...        ...        ...
# 219         NaN         NaN      25.5          NaN  42.730954 -70.842915
# 220         NaN         NaN     792.7          NaN  42.730954 -70.842915
# 221         NaN         NaN    1163.7          NaN  42.730954 -70.842915
# 222         NaN         NaN     636.8          NaN  42.730954 -70.842915
# 223         NaN         NaN     361.2          NaN  42.730954 -70.842915
#
#      BIOMASS SE  MEAN PLANT DENSITY  DENSITY SE       Date
# 0           NaN                 NaN         NaN 2000-08-24
# 1           NaN                 NaN         NaN 2000-08-24
# 2           NaN                 NaN         NaN 2000-08-24
# 3           NaN                 NaN         NaN 2000-08-24
# 4           NaN                 NaN         NaN 2000-08-24
# ..          ...                 ...         ...        ...
# 219         4.5              2050.0       250.0 2018-05-02
# 220       194.5              2600.0       355.9 2018-06-08
# 221       212.4              2333.3       197.8 2018-07-18
# 222       121.9              3050.0       368.6 2018-08-28
# 223        53.6              3050.0       378.4 2018-10-03
#
# [992 rows x 18 columns]

# %%
# print(df['Date'].unique())

# %%
g = sns.FacetGrid(df, row='TRT')
g.map(plt.hist, 'liveMass')

# %%
df = df[df['TRT'] == 'C'] ##Remove fertilized plots? Since they won't represent the pixel well. Look at histogram above
df
# Out:
#            SITE  YEAR  MONTH  DAY PLOT TRT  SP biomass  DS biomass  \
# 8    LTE-MP-LPP  2000      8   24    C   C       561.0         0.0
# 9    LTE-MP-LPP  2000      8   24    D   C       524.0         0.0
# 10   LTE-MP-LPP  2000      8   24    E   C       522.0         0.0
# 20   LTE-MP-LPP  2000      9   27    C   C       833.0         0.0
# 21   LTE-MP-LPP  2000      9   27    D   C      1167.0         0.0
# ..          ...   ...    ...  ...  ...  ..         ...         ...
# 101  LTE-MP-LPA  2018      5    2  NaN   C         NaN         NaN
# 102  LTE-MP-LPA  2018      6    8  NaN   C         NaN         NaN
# 103  LTE-MP-LPA  2018      7   18  NaN   C         NaN         NaN
# 104  LTE-MP-LPA  2018      8   28  NaN   C         NaN         NaN
# 105  LTE-MP-LPA  2018     10    3  NaN   C         NaN         NaN
#
#      SA biomass  SE biomass  liveMass DEAD biomass   Latitude  Longitude  \
# 8           0.0         0.0     561.0          465  42.730953 -70.842918
# 9           0.0         0.0     524.0          424  42.730953 -70.842918
# 10          0.0         0.0     522.0          267  42.730953 -70.842918
# 20          0.0         0.0     833.0          713  42.730953 -70.842918
# 21          0.0         0.0    1167.0          808  42.730953 -70.842918
# ..          ...         ...       ...          ...        ...        ...
# 101         NaN         NaN      16.7          NaN  42.730954 -70.842915
# 102         NaN         NaN     437.0          NaN  42.730954 -70.842915
# 103         NaN         NaN     748.0          NaN  42.730954 -70.842915
# 104         NaN         NaN     563.5          NaN  42.730954 -70.842915
# 105         NaN         NaN     414.3          NaN  42.730954 -70.842915
#
#      BIOMASS SE  MEAN PLANT DENSITY  DENSITY SE       Date
# 8           NaN                 NaN         NaN 2000-08-24
# 9           NaN                 NaN         NaN 2000-08-24
# 10          NaN                 NaN         NaN 2000-08-24
# 20          NaN                 NaN         NaN 2000-09-27
# 21          NaN                 NaN         NaN 2000-09-27
# ..          ...                 ...         ...        ...
# 101         1.9              1833.3       226.1 2018-05-02
# 102        53.6              2616.7       257.4 2018-06-08
# 103        80.4              2300.0       272.0 2018-07-18
# 104        84.4              3900.0       736.7 2018-08-28
# 105        58.9              3550.0       489.7 2018-10-03
#
# [433 rows x 18 columns]
