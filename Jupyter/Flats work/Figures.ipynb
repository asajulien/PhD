# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pdb
from IPython.display import display
import os

# %%
gce_57 = pd.read_csv('C:/Users/arj26323/Documents/Data/flats/Large dfs/Calibrations/gce_57.csv')
gce_87 = pd.read_csv('C:/Users/arj26323/Documents/Data/flats/Large dfs/Calibrations/gce_87.csv')
gce_97 = pd.read_csv('C:/Users/arj26323/Documents/Data/flats/Large dfs/Calibrations/gce_97.csv')

flux_57 = pd.read_csv('C:/Users/arj26323/Documents/Data/flats/Large dfs/Clipped calibrations/clipped_57.csv')
flux_87 = pd.read_csv('C:/Users/arj26323/Documents/Data/flats/Large dfs/Clipped calibrations/clipped_87.csv')
flux_97 = pd.read_csv('C:/Users/arj26323/Documents/Data/flats/Large dfs/Clipped calibrations/clipped_97.csv')

time_flux = pd.read_csv('C:/Users/arj26323/Documents/Data/flats/Large dfs/Time series/gce_timeseries.csv')

# %%
gce_97
# Out:
#      percent  ST_ATRAN_1  ST_EMIS_1    nirv_1      nirv  tidedifference  \
# 0       90.0        8409       9880 -0.004821 -0.005654               0
# 1       90.0        8408       9880 -0.004890 -0.004604               0
# 2       90.0        7204       9880 -0.003962 -0.007352               0
# 3       90.0        7204       9880 -0.003835 -0.005925               0
# 4       90.0        7204       9880 -0.000354  0.000028               0
# ..       ...         ...        ...       ...       ...             ...
# 293     90.0        8592       9749  0.050343  0.052265               0
# 294     90.0        8592       9749  0.055508  0.062785               0
# 295     90.0        8592       9693  0.027186  0.041586               0
# 296     90.0        8592       9761  0.046582  0.049758               0
# 297     90.0        8592       9761  0.047675  0.058565               0
#
#          vari  ST_QA  ST_DRAD  QA_RADSAT  ...       ST_B6   SR_B7_1   SR_B1_1  \
# ...

# %%
#Calibrations - GCE

calibr_list = gce_57
calibr_list = calibr_list[calibr_list['tidedifference'].between(-0.04, 0.04)]

fig, ax = plt.subplots()
fig.set_size_inches(11, 6)

points = plt.scatter(data = calibr_list, x = 'SR_B2', y='SR_B3_1',
                     c="tidedifference", s=20, cmap='BuPu', alpha=0.55)
plt.colorbar(points, label = 'Tide difference (m)')
sns.regplot(x='evi', y="evi_1", data=calibr_list, scatter=False, color=".1").set(xlabel='Landsat 5 EVI', ylabel='Landsat 7 EVI')

plt.plot([-0.1, 0.4], [-0.1, 0.4], 'k--')

print(len(calibr_list))
print(len(calibr_list['tidedifference'].unique()))

# plt.savefig('75.png', bbox_inches='tight', dpi = 300)
# Out:
# 15136
# 14

# %%
calibr_list = gce_57
calibr_list = calibr_list[calibr_list['tidedifference'].between(-0.04, 0.04)]

# fig, ax = plt.subplots()
# fig.set_size_inches(11, 6)

# points = plt.scatter(data = calibr_list, x = 'ndwi', y='ndwi_1',
#                      c="tidedifference", s=20, cmap='BuPu', alpha=0.55)
# plt.colorbar(points, label = 'Tide difference (m)')
# sns.regplot(x='ndwi', y="ndwi_1", data=calibr_list, scatter=False, color=".1").set(xlabel='Landsat 5 NDWI', ylabel='Landsat 7 NDWI')

# plt.plot([-0.5, 2], [-0.1, 2], 'k--')

print(len(calibr_list))
print(len(calibr_list['tidedifference'].unique()))
# Out:
# 15136
# 14

# %%
calibr_78 = gce_87

# calibr_78 = calibr_78[calibr_78['ndwi'].between(-2, 2) & calibr_78['ndwi_1'].between(-2, 2)] #getting rid of the outliers
calibr_78 = calibr_78[calibr_78['evi'].between(-1, 1)] #just getting rid of the outliers
calibr_78 = calibr_78[calibr_78['tidedifference'].between(-0.04, 0.04)]
calibr_78 = calibr_78[calibr_78['tidedifference'] != 0] #removing weird values - recalculate coefficients

fig, ax = plt.subplots()
fig.set_size_inches(11, 6)

points = plt.scatter(data = calibr_78, x = 'evi_1', y='evi',
                     c="tidedifference", s=20, cmap="BuPu", alpha=0.55)
plt.colorbar(points, label = 'Tide difference (m)')
sns.regplot(x='evi_1', y="evi", data=calibr_78, scatter=False, color=".1").set(xlabel='Landsat 8 EVI', ylabel='Landsat 7 EVI')

# plt.plot([-0.25, 0.5], [-0.25, 0.5], 'k--')

# display(calibr_78)
print(len(calibr_78))
print(len(calibr_78['tidedifference'].unique()))
# print(calibr_78['tidedifference'].unique()) ##LOOKING FOR STRANGE PAIR

plt.plot([-0.1, 0.4], [-0.1, 0.4], 'k--')

# for col in calibr_78.columns:
#     print(col)
# Out:
# 10338
# 11

# %%
calibr_78 = gce_87

# calibr_78 = calibr_78[calibr_78['ndwi'].between(-2, 2) & calibr_78['ndwi_1'].between(-2, 2)] #getting rid of the outliers
calibr_78 = calibr_78[calibr_78['evi'].between(-1, 1)] #just getting rid of the outliers
calibr_78 = calibr_78[calibr_78['tidedifference'].between(-0.04, 0.04)]
calibr_78 = calibr_78[calibr_78['tidedifference'] != 0] #removing weird values - recalculate coefficients

# fig, ax = plt.subplots()
# fig.set_size_inches(11, 6)

# points = plt.scatter(data = calibr_78, x = 'ndwi_1', y='ndwi',
#                      c="tidedifference", s=20, cmap="BuPu", alpha=0.55)
# plt.colorbar(points, label = 'Tide difference (m)')
# sns.regplot(x='ndwi_1', y="ndwi", data=calibr_78, scatter=False, color=".1").set(xlabel='Landsat 8 NDWI', ylabel='Landsat 7 NDWI')

# # plt.plot([-0.25, 0.5], [-0.25, 0.5], 'k--')

# # display(calibr_78)
# print(len(calibr_78))
# print(len(calibr_78['tidedifference'].unique()))
# # print(calibr_78['tidedifference'].unique()) ##LOOKING FOR STRANGE PAIR

# plt.plot([-0.75, 1], [-0.75, 1], 'k--')

# plt.savefig('78.png', bbox_inches='tight', dpi = 300)

# %%
calibr_79 = gce_97
calibr_79['tidedifference'] = abs(calibr_79['tidedifference'])


# calibr_89 = calibr_89[calibr_89['ndwi'].between(-2, 2) & calibr_89['ndwi_1'].between(-2, 2)] #getting rid of the outliers
# calibr_79 = calibr_79[calibr_79['tidedifference'].between(-0.04, 0.04)]

fig, ax = plt.subplots()
fig.set_size_inches(11, 6)

points = plt.scatter(data = calibr_79, x = 'evi_1', y='evi',
                     c="tidedifference", s=20, cmap="BuPu", alpha=0.65)
plt.colorbar(points, label = 'Tide difference (m)')
sns.regplot(x='evi_1', y="evi", data=calibr_79, scatter=False, color=".1").set(xlabel='Landsat 9 EVI', ylabel='Landsat 7 EVI')

# g.set_axis_labels("L8 ndwi", "L9 ndwi")
# plt.plot([-0.1, 0.4], [-0.1, 0.4], 'k--')

# display(calibr_89)
print(len(calibr_79))
print(len(calibr_79['tidedifference'].unique()))

plt.plot([-0.05, 0.2], [-0.05, 0.2], 'k--')

# plt.savefig('79.png', bbox_inches='tight', dpi = 300)
# Out:
# 298
# 1

# %%
calibr_79 = gce_97
calibr_79['tidedifference'] = abs(calibr_79['tidedifference'])


# calibr_89 = calibr_89[calibr_89['ndwi'].between(-2, 2) & calibr_89['ndwi_1'].between(-2, 2)] #getting rid of the outliers
calibr_79 = calibr_79[calibr_79['tidedifference'].between(-0.04, 0.04)]

fig, ax = plt.subplots()
fig.set_size_inches(11, 6)

points = plt.scatter(data = calibr_79, x = 'ndwi_1', y='ndwi',
                     c="tidedifference", s=20, cmap="BuPu", alpha=0.65)
plt.colorbar(points, label = 'Tide difference (m)')
sns.regplot(x='ndwi_1', y="ndwi", data=calibr_79, scatter=False, color=".1").set(xlabel='Landsat 9 NDWI', ylabel='Landsat 7 NDWI')

# g.set_axis_labels("L8 ndwi", "L9 ndwi")
# plt.plot([-0.1, 0.4], [-0.1, 0.4], 'k--')

# display(calibr_89)
print(len(calibr_79))
print(len(calibr_79['tidedifference'].unique()))

plt.plot([-0.5, 1], [-0.5, 1], 'k--')

# plt.savefig('79.png', bbox_inches='tight', dpi = 300)
# Out:
# 298
# 1

# %%
calibr_list['Sensors'] = 'Landsat 5/7'
calibr_78['Sensors'] = 'Landsat 8/7'
calibr_79['Sensors'] = 'Landsat 9/7'

x1 = calibr_list[['evi','evi_1','ndwi','ndwi_1','pheno','pheno_1','Sensors','tidedifference']]
x2 = calibr_78[['evi','evi_1','ndwi','ndwi_1','pheno','pheno_1','Sensors','tidedifference']]
x3 = calibr_79[['evi','evi_1','ndwi','ndwi_1','pheno','pheno_1','Sensors','tidedifference']]

x1.rename(columns = {'evi':'Landsat X EVI', 'evi_1':'Landsat 7 EVI', 'ndwi':'Landsat X NDWI', 'ndwi_1' :'Landsat 7 NDWI', 'pheno':'Landsat X pheno', 'pheno_1':'Landsat 7 pheno'}, inplace = True)
x2.rename(columns = {'evi':'Landsat 7 EVI', 'evi_1':'Landsat X EVI', 'ndwi':'Landsat 7 NDWI', 'ndwi_1':'Landsat X NDWI', 'pheno':'Landsat 7 pheno', 'pheno_1':'Landsat X pheno'}, inplace = True)
x3.rename(columns = {'evi': 'Landsat 7 EVI', 'evi_1':'Landsat X EVI', 'ndwi':'Landsat 7 NDWI', 'ndwi_1' :'Landsat X NDWI', 'pheno':'Landsat 7 pheno', 'pheno_1':'Landsat X pheno'}, inplace = True)

#Counts: 15136 10338 298 25772
df = pd.concat([x1,x2,x3], ignore_index=True)
df
# Out:
# C:\Users\arj26323\AppData\Local\Temp\ipykernel_12008\1045049995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calibr_list['Sensors'] = 'Landsat 5/7'
# C:\Users\arj26323\AppData\Local\Temp\ipykernel_12008\1045049995.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x1.rename(columns = {'evi':'Landsat X EVI', 'evi_1':'Landsat 7 EVI', 'ndwi':'Landsat X NDWI', 'ndwi_1' :'Landsat 7 NDWI', 'pheno':'Landsat X pheno', 'pheno_1':'Landsat 7 pheno'}, inplace = True)
# ...

# %%
# g = sns.FacetGrid(df, col="Sensors", height = 4)
# g = g.map(sns.regplot, "Landsat X EVI", "Landsat 7 EVI", scatter_kws={"s": 10, "c":"tidedifference", "cmap":"viridis"})
# # g.add_legend()

# # Add a common color bar
# cbar = plt.colorbar(g.ax[0][0].collections[0], ax=g, orientation='vertical', fraction=0.05)
# cbar.set_label('Tide difference')

# # Show the plot
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Create a list of the unique Sensor values
sensors = df["Sensors"].unique()

# Create a figure and axis objects for each plot
fig, ax = plt.subplots(1, len(sensors), figsize=(15, 6), sharey=True)

# Loop over each Sensor value and create a scatterplot
for i, sensor in enumerate(sensors):
    x = df[df["Sensors"] == sensor]["Landsat X EVI"]
    y = df[df["Sensors"] == sensor]["Landsat 7 EVI"]
    c = df[df["Sensors"] == sensor]["tidedifference"]

    # Plot the data and fit a regression line
    m, b = np.polyfit(x, y, 1)
    ax[i].scatter(x, y, c=c, cmap="copper", s=10, alpha = 0.7)
    ax[i].plot(x, m*x + b, color="black")

    # Label the plot
    ax[i].set_title(sensor)
    ax[i].set_xlabel("Landsat X EVI")

    # Plot the 1:1 line
    ax[i].plot([-0.05, 0.4], [-0.05, 0.4], "--", color="blue")
    
# Set the y-label for the first axis only
ax[0].set_ylabel("Landsat 7 EVI")

#Set the x-labels
ax[0].set_xlabel("Landsat 5 EVI")
ax[1].set_xlabel("Landsat 8 EVI")
ax[2].set_xlabel("Landsat 9 EVI")

# Add a common color bar
cbar = fig.colorbar(ax[0].collections[0], ax=ax, fraction=0.05)
cbar.set_label('Tide Difference (m)')

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


# # Add CI
# for i, sensor in enumerate(sensors):
#     x = df[df["Sensors"] == sensor]["Landsat X"]
#     y = df[df["Sensors"] == sensor]["Landsat 7"]
#     c = df[df["Sensors"] == sensor]["tidediff"]

#     # Plot the data and fit a regression line
#     m, b, _, _, _ = np.polyfit(x, y, 1, full=True)
#     ax[i].scatter(x, y, c=c, cmap="viridis", s=10)
#     ax[i].plot(x, m*x + b, color="black")

#     # Calculate the confidence interval
#     x_pred = np.linspace(x.min(), x.max(), 100)
#     y_pred = m * x_pred + b
#     y_pred_upper, y_pred_lower = sns.utils.ci(sns.regplot, x, y, ci=0.95)(x_pred, y_pred)

#     # Plot the confidence interval
#     ax[i].fill_between(x_pred, y_pred_lower, y_pred_upper, color='gray', alpha=0.5)



#     # Label the plot
#     ax[i].set_title(sensor)
#     ax[i].set_xlabel("Landsat X")



# Show the plot
# plt.savefig('evi_all.png', bbox_inches='tight', dpi = 300)
plt.show()

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\arj26323\\PhD\\Jupyter\\Flats work'

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Create a list of the unique Sensor values
sensors = df["Sensors"].unique()

# Create a figure and axis objects for each plot
fig, ax = plt.subplots(1, len(sensors), figsize=(15, 6), sharey=True)

# Loop over each Sensor value and create a scatterplot
for i, sensor in enumerate(sensors):
    x = df[df["Sensors"] == sensor]["Landsat X NDWI"]
    y = df[df["Sensors"] == sensor]["Landsat 7 NDWI"]
    c = df[df["Sensors"] == sensor]["tidedifference"]

    # Plot the data and fit a regression line
    m, b = np.polyfit(x, y, 1)
    ax[i].scatter(x, y, c=c, cmap="copper", s=10, alpha = 0.7)
    ax[i].plot(x, m*x + b, color="black")

    # Label the plot
    ax[i].set_title(sensor)
    ax[i].set_xlabel("Landsat X NDWI")

    # Plot the 1:1 line
    ax[i].plot([-0.5, 1.25], [-0.5, 1.25], "--", color="blue")
    
# Set the y-label for the first axis only
ax[0].set_ylabel("Landsat 7 NDWI")

#Set the x-labels
ax[0].set_xlabel("Landsat 5 NDWI")
ax[1].set_xlabel("Landsat 8 NDWI")
ax[2].set_xlabel("Landsat 9 NDWI")

# Add a common color bar
cbar = fig.colorbar(ax[0].collections[0], ax=ax, fraction=0.05)
cbar.set_label('Tide Difference (m)')

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Show the plot
# plt.savefig('ndwi_all.png', bbox_inches='tight', dpi = 300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Create a list of the unique Sensor values
sensors = df["Sensors"].unique()

# Create a figure and axis objects for each plot
fig, ax = plt.subplots(1, len(sensors), figsize=(15, 6), sharey=True)

# Loop over each Sensor value and create a scatterplot
for i, sensor in enumerate(sensors):
    x = df[df["Sensors"] == sensor]["Landsat X pheno"]
    y = df[df["Sensors"] == sensor]["Landsat 7 pheno"]
    c = df[df["Sensors"] == sensor]["tidedifference"]

    # Plot the data and fit a regression line
    m, b = np.polyfit(x, y, 1)
    ax[i].scatter(x, y, c=c, cmap="copper", s=10, alpha = 0.55)
    ax[i].plot(x, m*x + b, color="black")

    # Label the plot
    ax[i].set_title(sensor)
    ax[i].set_xlabel("Landsat X pheno")

    # Plot the 1:1 line
    ax[i].plot([-0.25, 0.5], [-0.25, 0.5], "--", color="blue")
    
# Set the y-label for the first axis only
ax[0].set_ylabel("Landsat 7 pheno")

#Set the x-labels
ax[0].set_xlabel("Landsat 5 pheno")
ax[1].set_xlabel("Landsat 8 pheno")
ax[2].set_xlabel("Landsat 9 pheno")

# Add a common color bar
cbar = fig.colorbar(ax[0].collections[0], ax=ax, fraction=0.05)
cbar.set_label('Tide Difference (m)')

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Show the plot
# plt.savefig('ndwi_all.png', bbox_inches='tight', dpi = 300)
plt.show()

# %%
#Calibrations - Flux tower
df['Landsat X EVI'].corr(df['Landsat 7 EVI'])
# Out:
# 0.9092881297865906

# %%
#Time series

##ndvi_y is FLATS-masked

df = time_flux.copy()
# df = df[df['ndvi_y']<1] #Quick fix
df = df[df['count_x']>40] #100 for expanded flux area

df.reset_index(inplace=True, drop=True)
df = df[df['ndvi_x'].notna()]

df = df[df['ndvi_y'] < 0.7] #Apr 26 2023

dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=dims)
g = sns.lineplot(ax = ax, x = "date", y = "ndvi_y", hue = "Sensor_x", data = df, markers = True, dashes = False)
g.set(xlabel ="Year", ylabel = "Average NDVI: masked with FLATS")
g.set_xlabel("Year",fontsize=15)
g.set_ylabel("Average NDVI: masked with FLATS",fontsize=15)
g.tick_params(labelsize=15)
ax.set(ylim=(-0.0, 0.8))
plt.legend(title='Sensor')

# plt.savefig('flux_masked_timeseries_1984.png', bbox_inches='tight', dpi = 300)
# Out:
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df[520:540]
# Out:
#        ndvi_x                     date   Sensor_x  count_x    ndvi_y  \
# 540  0.313993  2011-08-04 11:49:44.007  Landsat 5       71  0.358951
# 541  0.332508  2011-08-20 11:49:35.746  Landsat 5       71  0.358645
# 542  0.372240  2011-09-21 11:49:11.923  Landsat 5       71  0.412654
# 543  0.318831  2011-10-07 11:48:52.357  Landsat 5       71  0.364249
# 544  0.327139  2011-10-23 11:48:45.289  Landsat 5       71  0.365800
# 545  0.283174  2011-11-08 10:48:27.217  Landsat 5       71  0.349022
# 546  0.376056  1999-08-20 11:47:28.779  Landsat 7       69  0.379962
# 547  0.342877  1999-09-05 11:47:32.931  Landsat 7       71  0.366393
# 548  0.440231  1999-10-23 11:47:28.369  Landsat 7       71  0.464345
# 549  0.431181  1999-11-08 10:47:32.236  Landsat 7       71  0.463735
# 550  0.255589  1999-12-26 10:47:26.370  Landsat 7       71  0.340262
# 551  0.292759  2000-01-11 10:47:27.561  Landsat 7       71  0.318273
# 552  0.330750  2000-01-27 10:47:25.523  Landsat 7       70  0.352985
# ...

# %%
df = time_flux.copy()
df = df[df['Sensor_x'] == 'Landsat 7']
df = df[df['count_x']>40] #100 for expanded flux area

df.reset_index(inplace=True, drop=True)
df = df[df['ndvi_x'].notna()]

dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=dims)
g = sns.lineplot(ax = ax, x = "date", y = "ndvi_y", color = "b", data = df)
# ax2 = ax.twinx()
df.plot(x="date", y="ndvi_x", ax=ax, legend=True, color="r")


g.set(xlabel ="Year", ylabel = "Average NDVI")
g.set_xlabel("Year",fontsize=15)
g.set_ylabel("Average NDVI",fontsize=15)
g.tick_params(labelsize=15)
ax.set(ylim=(-0.3, 1))
plt.legend(title='', labels=['Tidally filtered', 'Unmasked'])

import os
os.chdir("C:/Users/arj26323/Downloads")
# plt.savefig('L7_timeseries.png', bbox_inches='tight', dpi = 300)
# Out:
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df = time_flux.copy()
df = df[df['count_x']>40] #100 for expanded flux area
df.reset_index(inplace=True, drop=True)
df = df[df['ndvi_x'].notna()]
df = df[df['ndvi_y'] < 0.7] #Apr 26 2023


len(df['ndvi_y'])
# Out:
# 997

# %%
#Chat GPT
df = time_flux.copy()
df = df[df['count_x']>40] #100 for expanded flux area
df.reset_index(inplace=True, drop=True)
df = df[df['ndvi_x'].notna()]
df = df[df['ndvi_y'] < 0.7] #Apr 26 2023

import pandas as pd
import matplotlib.dates as mdates

# Convert the date column to a datetime object
df['date'] = pd.to_datetime(df['date'])

# Set the date format for the x-axis ticks
date_fmt = mdates.DateFormatter('%Y')

dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=dims)

# Plot the two lines
sns.lineplot(ax=ax, x="date", y="ndvi_y", color="black", data=df)
df.plot(x="date", y="ndvi_x", ax=ax, legend=True, color="r", alpha = 0.65)

# Set the x-axis ticks to show only the beginning of each year
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(date_fmt)

# Set the x-axis and y-axis labels and limits
ax.set_xlabel("", fontsize=15)
ax.set_ylabel("Average NDVI", fontsize=15)
ax.set_ylim((-0.3, 1))

# Set the legend labels
ax.legend(title='', labels=['Masked with FLATS+', '', 'Unmasked'])

# Set the x-axis ticks to show only every other year
ax.xaxis.set_major_locator(mdates.YearLocator(2))

# Set the x-axis tick label font size
ax.tick_params(axis='x', which='major', labelsize=12)


# os.chdir('C:/Users/arj26323/Downloads')
# plt.savefig('timeseries_comparison.png', bbox_inches='tight', dpi = 300)
# Out:
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=dims)

# Plot the two lines and assign labels
sns.lineplot(ax=ax, x="date", y="ndvi_y", color="black", data=df, label='Masked with FLATS+')
df.plot(x="date", y="ndvi_x", ax=ax, legend=True, color="r", alpha=0.65, label='Unmasked')

# Set the x-axis ticks to show only the beginning of each year
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(date_fmt)

# Set the x-axis and y-axis labels and limits
ax.set_xlabel("", fontsize=15)
ax.set_ylabel("Average NDVI", fontsize=15)
ax.set_ylim((-0.3, 1))

# Set the legend labels without empty strings
ax.legend(title='')

# Set the x-axis ticks to show only every other year
ax.xaxis.set_major_locator(mdates.YearLocator(2))

# Set the x-axis tick label font size
ax.tick_params(axis='x', which='major', labelsize=12)

# Save the plot if needed
# os.chdir('C:/Users/arj26323/Downloads')
# plt.savefig('timeseries_comparison.png', bbox_inches='tight', dpi=300)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#Time series

##ndvi_y is FLATS-masked

df = time_flux.copy()
# df = df[df['ndvi_y']<1] #Quick fix
df = df[df['count_x']>40] #100 for expanded flux area

df.reset_index(inplace=True, drop=True)
df = df[df['ndvi_x'].notna()]

df = df[df['ndvi_y'] < 0.7] #Apr 26 2023

dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=dims)
g = sns.lineplot(ax = ax, x = "date", y = "ndvi_y", color = 'black', data = df)
df.plot(x="date", y="ndvi_x", ax=ax, legend=True, color="r")

g.set(xlabel ="Year", ylabel = "Average NDVI: masked with FLATS")
g.set_xlabel("Year",fontsize=15)
g.set_ylabel("Average NDVI: masked with FLATS",fontsize=15)
g.tick_params(labelsize=15)
ax.set(ylim=(-0.3, 1))
plt.legend(title='Sensor')

# os.chdir('C:/Users/arj26323/Downloads')
# plt.savefig('flux_masked-unmasked_timeseries_comparison.png', bbox_inches='tight', dpi = 300)
# Out:
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df_diff = df.copy
df_diff['ndvi_diff'] = df_diff['ndvi_y'] - df_diff['ndvi_x']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 df_diff = df.copy
# ----> 2 df_diff['ndvi_diff'] = df_diff['ndvi_y'] - df_diff['ndvi_x']
#
# TypeError: 'method' object is not subscriptable

# %%
df.head()

# %%
#Single pixel dry vs. flooded ndvi - might make sense to do this in another sheet
