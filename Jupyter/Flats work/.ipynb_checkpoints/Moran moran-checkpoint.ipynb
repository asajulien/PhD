# %%
import matplotlib.pyplot as plt
import numpy as np
import rasterio
import geopandas as gpd
from geopy.distance import great_circle
from matplotlib_scalebar.scalebar import ScaleBar
import matplotlib.colors as colors

h_x = "F:/Flats imagery/Tide stage composites/high_slope.scale.tif"
m_x = "F:/Flats imagery/Tide stage composites/mid_slope.scale.tif"
l_x = "F:/Flats imagery/Tide stage composites/low_slope.scale.tif"

slope_paths = [l_x, m_x, h_x]

def plot_geotiff_with_scale_and_north_arrow(geotiff_path, ax, title, data_min, data_max):
    with rasterio.open(geotiff_path) as src:
        data = src.read(1)
        extent = (src.bounds.left, src.bounds.right, src.bounds.bottom, src.bounds.top)
        
        gamma = 1
        data = data ** gamma 

        # Normalize the data based on the overall min and max values
        data_normalized = (data) / (1)*100
        
        cmap = 'BrBG'
        im = ax.imshow(data_normalized, extent=extent, cmap=cmap, vmin=-2, vmax=2)
        
        ax.set_xticks([])
        ax.set_yticks([])
        
        scale_bar = ScaleBar(dx=dx, location='lower right')
        ax.add_artist(scale_bar)
        
        ax.annotate('', xy=(0.95, 0.98), xycoords='axes fraction', fontsize=18, ha='center', va='center',
                    xytext=(0.95, 0.92), textcoords='axes fraction',
                    arrowprops=dict(arrowstyle='->', lw=2, color='black'))
        
        ax.set_title(title)
        
        return im

# Calculate dx for scale_bar
point1 = (31.425, -81.29)
point2 = (31.425, -80.29)
dx = great_circle(point1, point2).meters

fig, axs = plt.subplots(1, 3, figsize=(12, 4))  # Adjusted figsize

ims = []
titles = ['Low tide imagery', 'Mid tide imagery', 'High tide imagery']
data_min = float('inf')
data_max = float('-inf')

for i, ax in enumerate(axs.flat):
    with rasterio.open(slope_paths[i]) as src:
        data = src.read(1)
        data_min = min(data_min, np.min(data))
        data_max = max(data_max, np.max(data))

for i, ax in enumerate(axs.flat):
    im = plot_geotiff_with_scale_and_north_arrow(slope_paths[i], ax, titles[i], data_min, data_max)
    ims.append(im)

plt.suptitle('Trend in flooding probability, 1984-2023', fontsize=16)

fig.subplots_adjust(right=0.85)
plt.subplots_adjust(top=0.85)

# cbar.set_ticks([-0.02, -0.01, 0, 0.01, 0.02])
cbar_ax = fig.add_axes([0.9, 0.15, 0.02, 0.7])
cbar = plt.colorbar(ims[-1], cax=cbar_ax, label='Percent change per year')

# Savefig
import os
os.chdir("C:/Users/arj26323/Downloads")
# plt.savefig('percentslopes_trend.png',bbox_inches='tight', dpi = 300)

plt.show()

# %%
# ##Convert geotiffs to geopandas dataframe

# np.float = float    

import rioxarray as rxr
import xarray as xr
import rasterio

dataarray = rxr.open_rasterio(h_x)
dataarray = xr.open_rasterio(h_x)

df = dataarray[0].to_geopandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 5
#       1 # ##Convert geotiffs to geopandas dataframe
#       2
#       3 # np.float = float
# ----> 5 import rioxarray as rxr
#       6 import xarray as xr
#       7 import rasterio
#
# File C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\rioxarray\__init__.py:12
#       8 import rioxarray.rioxarray  # noqa
#      10 try:
#      11     # This requires xarray >= 0.12.3
# ---> 12     from rioxarray._io import open_rasterio  # noqa
#      13 except ImportError:
#      14     from xarray import open_rasterio  # noqa
#
# File C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\rioxarray\_io.py:250
#     240         parsed_tags[key] = value
#     241     return parsed_tags
#     244 NETCDF_DTYPE_MAP = {
#     245     0: object,  # NC_NAT
#     246     1: np.byte,  # NC_BYTE
#     247     2: np.char,  # NC_CHAR
#     248     3: np.short,  # NC_SHORT
#     249     4: np.int_,  # NC_INT, NC_LONG
# --> 250     5: np.float,  # NC_FLOAT
#     251     6: np.double,  # NC_DOUBLE
#     252     7: np.ubyte,  # NC_UBYTE
#     253     8: np.ushort,  # NC_USHORT
#     254     9: np.uint,  # NC_UINT
#     255     10: np.int64,  # NC_INT64
#     256     11: np.uint64,  # NC_UINT64
#     257     12: object,  # NC_STRING
#     258 }
#     261 def _load_netcdf_attrs(tags, data_array):
#     262     """
#     263     Loads the netCDF attributes into the data array
#     264
#     265     Attributes stored in this format:
#     266     - variable_name#attr_name: attr_value
#     267     """
#
# File C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\numpy\__init__.py:319, in __getattr__(attr)
#     314     warnings.warn(
#     315         f"In the future `np.{attr}` will be defined as the "
#     316         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     318 if attr in __former_attrs__:
# --> 319     raise AttributeError(__former_attrs__[attr])
#     321 if attr == 'testing':
#     322     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
import numpy as np
import rasterio
from libpysal import weights
import pysal
from esda.moran import Moran

# Read GeoTIFF file
with rasterio.open(h_x) as src:
    raster_data = src.read(1)  # Read the first band
    profile = src.profile
    transform = src.transform

# Convert raster data to numpy array
raster_array = np.array(raster_data)

# Create spatial weights
w = weights.Kernel.from_array(raster_array)

# Calculate Moran's I
moran = Moran(raster_array, w)

# Print Moran's I value
print("Moran's I:", moran.I)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 20
#      17 w = weights.Kernel.from_array(raster_array)
#      19 # Calculate Moran's I
# ---> 20 moran = Moran(raster_array, w)
#      22 # Print Moran's I value
#      23 print("Moran's I:", moran.I)
#
# File C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\esda\moran.py:166, in Moran.__init__(self, y, w, transformation, permutations, two_tailed)
#     164 self.permutations = permutations
#     165 self.__moments()
# --> 166 self.I = self.__calc(self.z)  # noqa E741
#     167 self.z_norm = (self.I - self.EI) / self.seI_norm
#     168 self.z_rand = (self.I - self.EI) / self.seI_rand
#
# File C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\esda\moran.py:236, in Moran.__calc(self, z)
#     235 def __calc(self, z):
# --> 236     zl = slag(self.w, z)
#     237     inum = (z * zl).sum()
#     238     return self.n / self.w.s0 * inum / self.z2ss
#
# File C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\libpysal\weights\spatial_lag.py:87, in lag_spatial(w, y)
#       9 def lag_spatial(w, y):
#      10     """
#      11     Spatial lag operator.
#      12
#    (...)
#      85
#      86     """
# ---> 87     return w.sparse * y
#
# File C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\scipy\sparse\_base.py:590, in spmatrix.__mul__(self, other)
#     589 def __mul__(self, other):
# --> 590     return self._mul_dispatch(other)
#
# File C:\ProgramData\Anaconda3\envs\gee\lib\site-packages\scipy\sparse\_base.py:559, in spmatrix._mul_dispatch(self, other)
#     556 if other.ndim == 1 or other.ndim == 2 and other.shape[1] == 1:
#     557     # dense row or column vector
#     558     if other.shape != (N,) and other.shape != (N, 1):
# --> 559         raise ValueError('dimension mismatch')
#     561     result = self._mul_vector(np.ravel(other))
#     563     if isinstance(other, np.matrix):
#
# ValueError: dimension mismatch

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 len(w)
#
# TypeError: object of type 'Kernel' has no len()
