# %%
import os, sys, traceback
import geemap, ee
import pandas as pd
import numpy as np

# %%
ee.Initialize()
center_pt = ee.Feature(ee.Geometry.Point([-81.3494, 31.4373]), {'site_id': '1'})

vis_param = {'min': 0, 
             'max': 2000, 
             'bands': ['B4', 'B3', 'B2'], 
             'gamma': 1.5}

l8_param = {'min': 0, 
             'max': 2000, 
             'bands': ['B5', 'B4', 'B3'], 
             'gamma': 1.5}

# %%
Map = geemap.Map(center=[40,-100], zoom=4)

# gce_bounds = 'C:/Users/arj26323/Documents/Data/Burns et al. 2021 data/Burns_data/Boundary_GCE.shp'

# %%
LS5 = ee.ImageCollection('LANDSAT/LT05/C01/T1_SR') \
    .filter(ee.Filter.calendarRange(2002, 2002,'year')) \
    .filter(ee.Filter.calendarRange(9, 11,'month')) \
    .filterBounds(ga_pts) \
    .filterMetadata('CLOUD_COVER', 'less_than', 100) \
    .sort('CLOUD_COVER', True)

LS1 = ee.ImageCollection('LANDSAT/LM01/C01/T1') \
    .filter(ee.Filter.calendarRange(1973, 1973,'year')) \
    .filter(ee.Filter.calendarRange(9, 11,'month')) \
    .filterBounds(ga_pts) \
    .filterMetadata('CLOUD_COVER', 'less_than', 100) \
    .sort('CLOUD_COVER', True)

LS8 = ee.ImageCollection('LANDSAT/LC08/C01/T1_SR') \
    .filter(ee.Filter.calendarRange(2013, 2013,'year')) \
    .filter(ee.Filter.calendarRange(9, 11,'month')) \
    .filterBounds(ga_pts) \
    .filterMetadata('CLOUD_COVER', 'less_than', 100) \
    .sort('CLOUD_COVER', True)

# %%
LS5.aggregate_array('system:id').getInfo()
#LS8.aggregate_array('system:id').getInfo()
# Out:
# ['LANDSAT/LT05/C01/T1_SR/LT05_016038_20021124',
#  'LANDSAT/LT05/C01/T1_SR/LT05_016038_20021007',
#  'LANDSAT/LT05/C01/T1_SR/LT05_017038_20020912',
#  'LANDSAT/LT05/C01/T1_SR/LT05_016038_20020921',
#  'LANDSAT/LT05/C01/T1_SR/LT05_017038_20020928',
#  'LANDSAT/LT05/C01/T1_SR/LT05_017038_20021115',
#  'LANDSAT/LT05/C01/T1_SR/LT05_017038_20021030']

# %%
ls_13 = ee.Image('LANDSAT/LC08/C01/T1_SR/LC08_017038_20131113')
ls_84 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_19841106') ##some clouds
ls_84.getInfo()
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'B2',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'B3',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'B4',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'B5',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'B6',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'B7',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'sr_atmos_opacity',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'sr_cloud_qa',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'pixel_qa',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]},
#   {'id': 'radsat_qa',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7781, 7001],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 435885, 0, -30, 3615915]}],
#  'id': 'LANDSAT/LT05/C01/T1_SR/LT05_016038_19841106',
#  'version': 1538942433639986,
#  'properties': {'IMAGE_QUALITY': 9,
#   'SATELLITE': 'LANDSAT_5',
#   'SOLAR_AZIMUTH_ANGLE': 149.453323,
#   'CLOUD_COVER': 4,
#   'WRS_PATH': 16,
#   'EARTH_SUN_DISTANCE': 0.991012,
#   'system:time_start': 468602673142,
#   'LANDSAT_ID': 'LT05_L1TP_016038_19841106_20161004_01_T1',
#   'SENSING_TIME': '1984-11-06T15:24:33.1420440Z',
#   'ESPA_VERSION': '2_19_0c',
#   'SOLAR_ZENITH_ANGLE': 53.674679,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[-79.26666940241006, 32.38483440449987],
#     [-79.26699489865578, 32.38702039951852],
#     [-79.2878851069482, 32.39026884648027],
#     [-79.5257820237856, 32.4266515139381],
#     [-80.09325122311829, 32.51148538907872],
#     [-81.20443365394733, 32.66971669895856],
#     [-81.20891423413477, 32.6679586220019],
#     [-81.21303541261544, 32.65889958805639],
#     [-81.22895453475175, 32.59850328310162],
#     [-81.62074705882058, 31.078910945937125],
#     [-81.6180717824107, 31.075336707651196],
#     [-81.49353713570504, 31.058021177735444],
#     [-79.71017883008933, 30.797051573494603],
#     [-79.70809196067736, 30.801124608877846],
#     [-79.70414810866589, 30.814101433575168],
#     [-79.5191300890387, 31.481705801190426],
#     [-79.3491981679148, 32.0882133834286],
#     [-79.32236885123692, 32.183675755028915],
#     [-79.2851949961965, 32.3163085396535],
#     [-79.27219425539793, 32.363216024473104],
#     [-79.26666940241006, 32.38483440449987]]},
#   'WRS_ROW': 38,
#   'GEOMETRIC_RMSE_MODEL_Y': 3.048,
#   'LEVEL1_PRODUCTION_DATE': 1475599339000,
#   'CLOUD_COVER_LAND': 0,
#   'GEOMETRIC_RMSE_MODEL_X': 2.536,
#   'system:asset_size': 213224476,
#   'GEOMETRIC_RMSE_MODEL': 3.965,
#   'SR_APP_VERSION': 'LEDAPS_3.2.0',
#   'PIXEL_QA_VERSION': 'generate_pixel_qa_1.5.0',
#   'system:index': 'LT05_016038_19841106'}}

# %%
Map.addLayer(ls_02, vis_param, "Feesh")
Map
# Out:
# Map(bottom=428184.0, center=[31.39701876012577, -81.31050109863283], controls=(WidgetControl(options=['positio…

# %%
gce_shp = r'C:\Users\arj26323\Documents\Data\Burns et al. 2021 data\Burns_data\Boundary_GCE.shp'
gce_bounds = geemap.shp_to_ee(gce_shp)
Map.addLayer(gce_bounds, {}, "GCE")
Map.centerObject(gce_bounds, 10)

# %%
##Look at coastsat shoreline detection package (sent in email, works with geemap) - uses sentinel-2 and landsat data
##Might need a separate virtual environment location for this one

# %%
ls_85 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_19851109')
ls_86 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_19861002')
ls_87 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_19871030')
ls_88 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_19881007')
ls_89 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_19891111')
ls_90 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_19901029')
ls_91 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_19911016')
ls_92 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_19921027') ##tide
ls_93 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_19931122') ##month/tide
ls_94 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_19941102')
ls_95 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_19951121') ##month/tide
ls_96 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_19961022')
ls_97 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_19970930')
ls_98 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_19981019')
ls_99 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_19991022')
ls_00 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_20001024')
ls_01 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_20011027')
ls_02 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_20021007')
ls_03 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_20031102')
ls_04 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_20041104')
ls_05 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_20051015')
ls_06 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_20061119')
ls_07 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_20070926')
ls_08 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_20080928')
ls_09 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_20091001')
ls_10 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_016038_20101114')
ls_11 = ee.Image('LANDSAT/LT05/C01/T1_SR/LT05_017038_20111023')

ls_99.getInfo()
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'B2',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'B3',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'B4',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'B5',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'B6',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'B7',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'sr_atmos_opacity',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'sr_cloud_qa',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'pixel_qa',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]},
#   {'id': 'radsat_qa',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7871, 7181],
#    'crs': 'EPSG:32617',
#    'crs_transform': [30, 0, 276885, 0, -30, 3621615]}],
#  'id': 'LANDSAT/LT05/C01/T1_SR/LT05_017038_19991022',
#  'version': 1538942845640300.0,
#  'properties': {'IMAGE_QUALITY': 9,
#   'SATELLITE': 'LANDSAT_5',
#   'SOLAR_AZIMUTH_ANGLE': 147.927002,
#   'CLOUD_COVER': 0,
#   'WRS_PATH': 17,
#   'EARTH_SUN_DISTANCE': 0.995183,
#   'system:time_start': 940606638379,
#   'LANDSAT_ID': 'LT05_L1TP_017038_19991022_20160919_01_T1',
#   'SENSING_TIME': '1999-10-22T15:37:18.3790690Z',
#   'ESPA_VERSION': '2_19_0c',
#   'SOLAR_ZENITH_ANGLE': 48.560959,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[-83.28362134487939, 31.0827938242979],
#     [-83.1298708717139, 31.06159850433026],
#     [-82.46470101640234, 30.967730531967224],
#     [-81.37745924278353, 30.806610501729285],
#     [-81.33646079665716, 30.954951887528765],
#     [-81.26680766301352, 31.207670273146917],
#     [-81.17985336940121, 31.521540290238555],
#     [-81.08505296180753, 31.861596813886486],
#     [-80.96533211055353, 32.28870850992435],
#     [-80.92793965903543, 32.42278101132598],
#     [-80.92793687465313, 32.42623336224687],
#     [-81.14066775265096, 32.458635009125615],
#     [-82.86387234298584, 32.70676872860958],
#     [-82.86915236918738, 32.705085226046855],
#     [-82.8768724723113, 32.6786343312996],
#     [-83.08162076476184, 31.887465175905966],
#     [-83.25784916143397, 31.19632282712548],
#     [-83.2831727601935, 31.095806141134933],
#     [-83.2852068361253, 31.086318631133153],
#     [-83.28362134487939, 31.0827938242979]]},
#   'WRS_ROW': 38,
#   'GEOMETRIC_RMSE_MODEL_Y': 3.193,
#   'LEVEL1_PRODUCTION_DATE': 1474273385000,
#   'CLOUD_COVER_LAND': 0,
#   'GEOMETRIC_RMSE_MODEL_X': 2.759,
#   'system:asset_size': 334445688,
#   'GEOMETRIC_RMSE_MODEL': 4.22,
#   'SR_APP_VERSION': 'LEDAPS_3.2.0',
#   'PIXEL_QA_VERSION': 'generate_pixel_qa_1.5.0',
#   'system:index': 'LT05_017038_19991022'}}

# %%
##Function to cloud mask from the pixel_qa band of Landsat 5/8 SR data.
##Seems to change reflectance values slightly (besides the dividing by 10000 part)
def maskL5sr(image):
  ## Bits 3 and 5 are cloud shadow and cloud, respectively.
  cloudShadowBitMask = 1 << 3
  cloudsBitMask = 1 << 5

  ##Get the pixel QA band.
  qa = image.select('pixel_qa')

  ##Both flags should be set to zero, indicating clear conditions.
  mask = qa.bitwiseAnd(cloudShadowBitMask).eq(0) \
      .And(qa.bitwiseAnd(cloudsBitMask).eq(0))

  ##Return the masked image, scaled to reflectance, without the QA bands.
  return image.updateMask(mask).divide(10000) \
      .select("B[0-9]*") \
      .copyProperties(image, ["system:time_start"])

##Water masking

##Load or import the Hansen et al. forest change dataset.
hansenImage = ee.Image('UMD/hansen/global_forest_change_2015')

##Select the land/water mask.
datamask = hansenImage.select('datamask')

##Create a binary mask.
watermask = datamask.eq(1)

#watermasked00 = ga00.updateMask(watermask)
#Map.addLayer(watermasked00, vis_param, 'masked')

##Works! Although it is not perfect. Make sure to turn off background layers to see.
##See if there are any other water masks that perform better. Small creeks not masked at all

# %%
##Masking all the images
m_84 = ee.Image(maskL5sr(ls_84)).updateMask(watermask)
m_85 = ee.Image(maskL5sr(ls_85)).updateMask(watermask)
m_86 = ee.Image(maskL5sr(ls_86)).updateMask(watermask)
m_87 = ee.Image(maskL5sr(ls_87)).updateMask(watermask)
m_88 = ee.Image(maskL5sr(ls_88)).updateMask(watermask)
m_89 = ee.Image(maskL5sr(ls_89)).updateMask(watermask)
m_90 = ee.Image(maskL5sr(ls_90)).updateMask(watermask)
m_91 = ee.Image(maskL5sr(ls_91)).updateMask(watermask)
m_92 = ee.Image(maskL5sr(ls_92)).updateMask(watermask)
m_93 = ee.Image(maskL5sr(ls_93)).updateMask(watermask)
m_94 = ee.Image(maskL5sr(ls_94)).updateMask(watermask)
m_95 = ee.Image(maskL5sr(ls_95)).updateMask(watermask)
m_96 = ee.Image(maskL5sr(ls_96)).updateMask(watermask)
m_97 = ee.Image(maskL5sr(ls_97)).updateMask(watermask)
m_98 = ee.Image(maskL5sr(ls_98)).updateMask(watermask)
m_99 = ee.Image(maskL5sr(ls_99)).updateMask(watermask)
m_00 = ee.Image(maskL5sr(ls_00)).updateMask(watermask)
m_01 = ee.Image(maskL5sr(ls_01)).updateMask(watermask)
m_02 = ee.Image(maskL5sr(ls_02)).updateMask(watermask)
m_03 = ee.Image(maskL5sr(ls_03)).updateMask(watermask)
m_04 = ee.Image(maskL5sr(ls_04)).updateMask(watermask)
m_05 = ee.Image(maskL5sr(ls_05)).updateMask(watermask)
m_06 = ee.Image(maskL5sr(ls_06)).updateMask(watermask)
m_07 = ee.Image(maskL5sr(ls_07)).updateMask(watermask) ##too much masked
m_08 = ee.Image(maskL5sr(ls_08)).updateMask(watermask)
m_09 = ee.Image(maskL5sr(ls_09)).updateMask(watermask)
m_10 = ee.Image(maskL5sr(ls_10)).updateMask(watermask)
m_11 = ee.Image(maskL5sr(ls_11)).updateMask(watermask)
m_13 = ee.Image(maskL5sr(ls_13)).updateMask(watermask)

Map.addLayer(m_92, {'bands': ['B4',  'B3',  'B2'], 'min': 0, 'max': 0.2}, "masked")

##Next steps: zonal stats on each, combine csvs, calculate average NDVI over time

# %%
##Image collection
masked_collection = ee.ImageCollection.fromImages([m_84, m_85, m_86, m_87, m_88, m_89, m_90, m_91, m_92, m_93, m_94, m_95, \
                                                   m_96, m_97, m_98, m_99, m_00, m_01, m_02, m_03, m_04, m_05, m_06, m_07, \
                                                   m_08, m_09, m_10, m_11, m_13])

# %%
##Calculating zonal statistics
out_dir = os.path.expanduser('~/Downloads')

out_stats = os.path.join(out_dir, 'landsat_stats.csv')  

geemap.zonal_statistics(masked_collection, gce_bounds, out_stats, statistics_type='MEAN', scale=1000)
# Out:
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/a6ef421bf148b70cbd225823c0331d39-e6127fb5a2ba21c5973d1c66dcc2a31c:getFeatures
# Please wait ...
# Data downloaded to C:\Users\arj26323\Downloads\landsat_stats.csv

# %%
##Statistical analysis
df = pd.read_csv('C:/Users/arj26323/Documents/Classes/landsat_stats.csv')
df = df[df['Year'] != 2007]
df = df[df['Year'] != 1992]
df = df[df['Year'] != 2002]

# def ndvi(x, y):
#     return (x-y)/(x+y)

# ls_stats = df.groupby('Year').apply(ndvi())

import seaborn as sns

sns.lineplot( x = 'Year', y = 'ndvi', data = df, label = 'NDVI')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='ndvi'>
