# %%
import os
import glob
import rasterio
import geemap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdb
from IPython.display import display
import ee
import os
# Out:
# C:\Users\arj26323\.conda\envs\mappy\lib\site-packages\google\api_core\_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
import ee
import geemap
service_account = ' boba-account@boba-430314.iam.gserviceaccount.com '
credentials = ee.ServiceAccountCredentials(service_account,'C:/Users/arj26323/OneDrive - University of Georgia/Documents/GEE AUTH/boba-430314-a19be859bfca.json')

ee.Initialize(credentials)

print(geemap.__version__)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 0.37.1

# %%
mml_path = "F:/Hotspots/Project shapefiles/mml.shp"
mml = geemap.shp_to_ee(mml_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# mml.getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'FeatureCollection',
#  'columns': {'Shape_Leng': 'Float', 'system:index': 'String'},
#  'features': [{'type': 'Feature',
#    'geometry': {'geodesic': False,
#     'type': 'LineString',
#     'coordinates': [[-81.58818699853286, 30.739783933863382],
#      [-81.58741558591781, 30.740287029834345],
#      [-81.58685659283383, 30.74073422690893],
#      [-81.58671125476758, 30.74104726441418],
#      [-81.58657709866733, 30.74157271966389],
#      [-81.5865323804837, 30.741885756147035],
#      [-81.58663299988841, 30.742154073339922],
#      [-81.58689013833515, 30.74234413088372],
#      [-81.5871808157156, 30.742467109419234],
#      [-81.58746031418524, 30.74261244806837],
#      [-81.58782925106797, 30.74256772743598],
#      [-81.58813110755206, 30.74256772672494],
#      [-81.58833234666389, 30.742645986625725],
#      [-81.58835470732981, 30.742847224056234],
#      [-81.58809757088872, 30.743149082203672],
#      [-81.58778453405306, 30.74337268003067],
#      [-81.58752739733461, 30.743618638389247],
#      [-81.58734851914238, 30.743696897376275]]},
#    'id': '0',
#    'properties': {'Shape_Leng': 668.005731835}},
#   {'type': 'Feature',
#    'geometry': {'geodesic': False,
#     'type': 'LineString',
#     'coordinates': [[-81.53294646389001, 30.759986791341728],
#      [-81.53275430982232, 30.760528317853435],
#      [-81.53292899716394, 30.76098250037996],
#      [-81.53326090183619, 30.761628839217323],
#      [-81.53338318293734, 30.762257708541583],
#      [-81.53322596665414, 30.76286910987914],
#      [-81.53306875151846, 30.763707602588656],
#      [-81.53256216177748, 30.763847352370476],
#      [-81.53207304027325, 30.763480511742713],
#      [-81.53174113691186, 30.76334076334114],
#      [-81.53142670274431, 30.7633232954348],
#      [-81.53105986164205, 30.76342810778678],
#      [-81.53048339853676, 30.763794949109435],
#      [-81.52974971934597, 30.764109385787762],
#      [-81.52982797876949, 30.764860535308834],
#      [-81.52961556231514, 30.765307730931625],
#      [-81.5289447691445, 30.765710208784558],
#      [-81.52846403510748, 30.766280384583258],
#      [-81.52821248775503, 30.76683448917496],
#      [-81.52767096218402, 30.767393484479943],
#      [-81.52737399754277, 30.767760325657125],
#      [-81.52718184414661, 30.768197040677368],
#      [-81.52740893561179, 30.76849400725283],
#      [-81.52791552458861, 30.76854641174547],
#      [-81.52829983432544, 30.76863375361295],
#      [-81.52856186402416, 30.76879097192958],
#      [-81.52850945815068, 30.769175280562845],
#      [-81.52828236759476, 30.769559590643183],
#      [-81.52775831033878, 30.769751745885017],

# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# C:\Users\arj26323\.conda\envs\mappy\lib\site-packages\ee\deprecation.py:215: DeprecationWarning:
#
# Attention required for USGS/3DEP/10m! You are using a deprecated asset.
# To make sure your code keeps working, please update it.
# This dataset has been superseded by USGS/3DEP/10m_collection
#
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/USGS_3DEP_10m
#
#   warnings.warn(warning, category=DeprecationWarning)

# %%
Map = geemap.Map(center=[31.539096,-81.422318], zoom=10)

elevVis = {
    'min': 0,
    'max': 500,
    'palette': ['#3288bd', '#fee08b', '#d53e4f'] # Blue (low) to Red (high)
}

slopeVis = {
    'min': 0,
    'max': 10,
    'palette': ['#3288bd', '#fee08b', '#d53e4f'] # Blue (flat) to Red (steep)
}

Map.addLayer(elev, elevVis, 'elevation')
Map.addLayer(slope, slopeVis, 'slope')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
fc = mml
# 3. Extract slope values along the lines
# Using reduceRegions to get the average slope for each polyline

slope_data = slope.reduceRegions( collection=fc, 
                                  reducer=ee.Reducer.mean(), # Or ee.Reducer.max() if you want the highest slope point 
                                  scale=30 )
# 4. Flag/Filter regions above a certain slope (e.g., 15 degrees)

threshold = 0
high_slope_lines = slope_data.filter(ee.Filter.gt('mean', threshold))
# Display on map

Map.add_layer(high_slope_lines, {'color': 'yellow'}, 'High Slope Lines')
# Map.center_object(high_slope_lines)

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=53697.0, center=[31.60403659820493, -81.55700683593751], controls=(WidgetControl(options=['position…

# %%
fc = mml 
fc = fc.map(lambda f: f.set('total_length_m', f.length(maxError=1)))
high_slope_mask = slope.gt(threshold)

threshold = 10

def get_high_slope_length_fixed(feature):
    # 1. Create a buffer
    buffered = feature.buffer(30, maxError=1)
    
    # 2. Extract only the high-slope pixels as a geometry
    # .selfMask() ensures we only get the steep pixels
    steep_geometry = high_slope_mask.updateMask(high_slope_mask).clip(buffered).reduceToVectors(
        geometry=buffered.geometry(),
        scale=30,
        geometryType='polygon'
    )
    
    # 3. Intersect the original line with the steep polygons
    # This gives you the specific segments of the line that are steep
    steep_segments = feature.intersection(steep_geometry.geometry(), maxError=1)
    
    # 4. Get the actual length of these specific segments
    return feature.set('high_slope_length_m', steep_segments.length(maxError=1))

# Now run this, and you will get the actual geometry length
results = fc.map(get_high_slope_length_fixed)


def add_percentage(feature):
    total = ee.Number(feature.get('total_length_m'))
    steep = ee.Number(feature.get('high_slope_length_m'))
    # Avoid division by zero
    percent = steep.divide(total).multiply(100)
    return feature.set('percent_high_slope', percent)

final_results = results.map(add_percentage)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# final_results
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# 5. Export to CSV for final analysis
geemap.ee_export_vector(
    final_results, 
    filename="C:/Downloads/slopesandlengths.csv", 
    verbose=True
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/3c7da5b5c2b72ded2dce7c68042cf855-c1a67729db3b73cb40a00293f917d188:getFeatures
# Please wait ...
# An error occurred while downloading.
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\.conda\envs\mappy\lib\site-packages\requests\models.py:1116, in Response.json(self, **kwargs)
#    1115 try:
# -> 1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\.conda\envs\mappy\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\.conda\envs\mappy\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\.conda\envs\mappy\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[51], line 2
#       1 # 5. Export to CSV for final analysis
# ----> 2 geemap.ee_export_vector(
#       3     final_results,
#       4     filename="C:/Downloads/slopesandlengths.csv",
#       5     verbose=True
#       6 )
#
# File ~\.conda\envs\mappy\lib\site-packages\geemap\common.py:1045, in ee_export_vector(ee_object, filename, selectors, verbose, keep_zip, timeout, proxies)
#    1043     print("An error occurred while downloading.")
#    1044     if r is not None:
# -> 1045         print(r.json()["error"]["message"])
#    1046     raise ValueError(e)
#    1048 try:
#
# File ~\.conda\envs\mappy\lib\site-packages\requests\models.py:1120, in Response.json(self, **kwargs)
#    1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# -> 1120     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
buffered_fc = fc.map(lambda feature: feature.buffer(30)) ##buffering the lines so that they can be summarized easily

slope_threshold = 15 ##15 degrees - is this a high slope for marsh migration?
high_slope_mask = slope.gt(slope_threshold)


slope_segments = slope.reduceRegions(
    collection=buffered_fc,
    reducer=ee.Reducer.mean(), # Or max, or even a list of all pixel values
    scale=30
)



# 2. Extract the high-slope areas as polygons
# This turns the "high slope" pixels into vector shapes
high_slope_polygons = high_slope_mask.selfMask().reduceToVectors(
    geometry=fc.geometry().bounds(),
    scale=30,
    geometryType='polygon'
)

# 3. Intersect your original lines with these polygons
# This leaves you only with the portions of your lines inside high-slope zones
high_slope_segments = fc.map(lambda feature: 
    feature.intersection(high_slope_polygons.geometry(), ee.ErrorMargin(1))
)

# 4. Calculate length of the resulting segments
# Note: You may need to flatten the output if segments are broken into pieces
def add_length(feature):
    return feature.set('segment_length_m', feature.length())

segments_with_length = high_slope_segments.map(add_length)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 segments_with_length
#
# NameError: name 'segments_with_length' is not defined

# %%
segments_with_length

# Grouping by 'line_id' to sum segment_length_m
stats = segments_with_length.reduceColumns(
    reducer=ee.Reducer.sum().group(
        groupField=0,
        groupName='line_id'
    ),
    selectors=['line_id', 'segment_length_m']
)

print(stats.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'groups': []}

# %%
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\.conda\envs\mappy\lib\site-packages\ee\data.py:359, in _execute_cloud_call(call, num_retries)
#     358 try:
# --> 359   return call.execute(num_retries=num_retries)
#     360 except googleapiclient.errors.HttpError as e:
#
# File ~\.conda\envs\mappy\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\.conda\envs\mappy\lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "Image.reduceToVectors: Too many pixels in the region. Found 14777375, but maxPixels allows only 10000000.
# Ensure that you are not aggregating at a higher resolution than you intended; that is a frequent cause of this error. If not, then you may set the 'maxPixels' argument to a limit suitable for your computation; set 'bestEffort' to true to aggregate at whatever scale results in 'maxPixels' total pixels; or both.". Details: "Image.reduceToVectors: Too many pixels in the region. Found 14777375, but maxPixels allows only 10000000.
# Ensure that you are not aggregating at a higher resolution than you intended; that is a frequent cause of this error. If not, then you may set the 'maxPixels' argument to a limit suitable for your computation; set 'bestEffort' to true to aggregate at whatever scale results in 'maxPixels' total pixels; or both.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 segments_with_length.getInfo()
#
# File ~\.conda\envs\mappy\lib\site-packages\ee\collection.py:589, in Collection.getInfo(self)
#     576 def getInfo(self) -> Any | None:
#     577   """Returns all the known information about this collection.
#     578
#     579   This function makes a REST call to to retrieve all the known information
#    (...)
#     587          properties.
#     588   """
# --> 589   return super().getInfo()
#
# File ~\.conda\envs\mappy\lib\site-packages\ee\computedobject.py:108, in ComputedObject.getInfo(self)
#     102 def getInfo(self) -> Any | None:
#     103   """Fetch and return information about this object.
#     104
#     105   Returns:
#     106     The object can evaluate to anything.
#     107   """
# --> 108   return data.computeValue(self)
#
# File ~\.conda\envs\mappy\lib\site-packages\ee\data.py:1080, in computeValue(obj)
#    1077 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1078 _maybe_populate_workload_tag(body)
# -> 1080 return _execute_cloud_call(
#    1081     _get_cloud_projects()
#    1082     .value()
#    1083     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1084 )['result']
#
# File ~\.conda\envs\mappy\lib\site-packages\ee\data.py:361, in _execute_cloud_call(call, num_retries)
#     359   return call.execute(num_retries=num_retries)
#     360 except googleapiclient.errors.HttpError as e:
# --> 361   raise _translate_cloud_exception(e)
#
# EEException: Image.reduceToVectors: Too many pixels in the region. Found 14777375, but maxPixels allows only 10000000.
# Ensure that you are not aggregating at a higher resolution than you intended; that is a frequent cause of this error. If not, then you may set the 'maxPixels' argument to a limit suitable for your computation; set 'bestEffort' to true to aggregate at whatever scale results in 'maxPixels' total pixels; or both.
