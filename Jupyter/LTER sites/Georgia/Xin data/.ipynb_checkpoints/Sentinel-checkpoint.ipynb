# %%
import geemap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdb
from IPython.display import display
import ee
import os
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import ee
import geemap
service_account = ' boba-account@boba-430314.iam.gserviceaccount.com '
credentials = ee.ServiceAccountCredentials(service_account,'C:/Users/arj26323/OneDrive - University of Georgia/Documents/GEE AUTH/boba-430314-a19be859bfca.json')

ee.Initialize(credentials)

print(geemap.__version__)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 0.34.1

# %%
Map = geemap.Map(center=[31.539096,-81.422318], zoom=10)

##Adding every plot coordinate
allplots_fc = 'C:/Users/arj26323/Documents/Data/Biomass datasets/Sapelo/GA_allplots_NEW.csv'
fc_all = geemap.csv_to_ee(allplots_fc, latitude = "Latitude", longitude = "Longitude")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#Cloud masking
aoi = fc_all
start_date = '2017-01-01'
end_date = '2024-12-31'
CLOUD_FILTER = 60
CLD_PRB_THRESH = 50
NIR_DRK_THRESH = 0.15
CLD_PRJ_DIST = 1
BUFFER = 50

def get_s2_sr_cld_col(aoi, start_date, end_date):
    # Import and filter S2 SR.
    s2_sr_col = (ee.ImageCollection('COPERNICUS/S2_SR')
        .filterBounds(aoi)
        .filterDate(start_date, end_date)
        .filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', CLOUD_FILTER)))

    # Import and filter s2cloudless.
    s2_cloudless_col = (ee.ImageCollection('COPERNICUS/S2_CLOUD_PROBABILITY')
        .filterBounds(aoi)
        .filterDate(start_date, end_date))

    # Join the filtered s2cloudless collection to the SR collection by the 'system:index' property.
    return ee.ImageCollection(ee.Join.saveFirst('s2cloudless').apply(**{
        'primary': s2_sr_col,
        'secondary': s2_cloudless_col,
        'condition': ee.Filter.equals(**{
            'leftField': 'system:index',
            'rightField': 'system:index'
        })
    }))

s2_sr_cld_col_eval = get_s2_sr_cld_col(aoi, start_date, end_date)

def add_cloud_bands(img):
    # Get s2cloudless image, subset the probability band.
    cld_prb = ee.Image(img.get('s2cloudless')).select('probability')

    # Condition s2cloudless by the probability threshold value.
    is_cloud = cld_prb.gt(CLD_PRB_THRESH).rename('clouds')

    # Add the cloud probability layer and cloud mask as image bands.
    return img.addBands(ee.Image([cld_prb, is_cloud]))

def add_shadow_bands(img):
    # Identify water pixels from the SCL band.
    not_water = img.select('SCL').neq(6)

    # Identify dark NIR pixels that are not water (potential cloud shadow pixels).
    SR_BAND_SCALE = 1e4
    dark_pixels = img.select('B8').lt(NIR_DRK_THRESH*SR_BAND_SCALE).multiply(not_water).rename('dark_pixels')

    # Determine the direction to project cloud shadow from clouds (assumes UTM projection).
    shadow_azimuth = ee.Number(90).subtract(ee.Number(img.get('MEAN_SOLAR_AZIMUTH_ANGLE')));

    # Project shadows from clouds for the distance specified by the CLD_PRJ_DIST input.
    cld_proj = (img.select('clouds').directionalDistanceTransform(shadow_azimuth, CLD_PRJ_DIST*10)
        .reproject(**{'crs': img.select(0).projection(), 'scale': 100})
        .select('distance')
        .mask()
        .rename('cloud_transform'))

    # Identify the intersection of dark pixels with cloud shadow projection.
    shadows = cld_proj.multiply(dark_pixels).rename('shadows')

    # Add dark pixels, cloud projection, and identified shadows as image bands.
    return img.addBands(ee.Image([dark_pixels, cld_proj, shadows]))

def add_cld_shdw_mask(img):
    # Add cloud component bands.
    img_cloud = add_cloud_bands(img)

    # Add cloud shadow component bands.
    img_cloud_shadow = add_shadow_bands(img_cloud)

    # Combine cloud and shadow mask, set cloud and shadow as value 1, else 0.
    is_cld_shdw = img_cloud_shadow.select('clouds').add(img_cloud_shadow.select('shadows')).gt(0)

    # Remove small cloud-shadow patches and dilate remaining pixels by BUFFER input.
    # 20 m scale is for speed, and assumes clouds don't require 10 m precision.
    is_cld_shdw = (is_cld_shdw.focalMin(2).focalMax(BUFFER*2/20)
        .reproject(**{'crs': img.select([0]).projection(), 'scale': 20})
        .rename('cloudmask'))

    # Add the final cloud-shadow mask to the image.
#     return img.addBands(is_cld_shdw)

    return img_cloud_shadow.addBands(is_cld_shdw)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def cloudmask(image):
    # Select bands
    clouds = image.select('clouds')
    shadows = image.select('shadows')
    dark_pixels = image.select('dark_pixels')

    # Create a combined mask where any of the bands equal 1
    combined_mask = clouds.eq(1).Or(shadows.eq(1)).Or(dark_pixels.eq(1))

    # Invert the mask (setting 1s to 0s and vice versa)
    inverted_mask = combined_mask.Not()

    # Apply the inverted mask to the image
    return image.updateMask(inverted_mask)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# def addSENTINELFLATS(image):
#     flats = ee.Image(0).expression(
#         '1/(1+2.718281828459045**-(-1.57 + 20*(RED-SWIR)/(RED+SWIR) + 68.6*(GREEN-RED)/(GREEN+RED)))', {
#             'SWIR': image.select('B8'),
#             'RED': image.select('B4'),
#             'GREEN': image.select('B3')
#         })
    
#     return image.addBands(flats.rename('flats'))

def addSENTINELFLATS(image):
    flats = ee.Image(0).expression(
        '1/(1+2.718281828459045**-(1.51 + 12.5*(RED-SWIR)/(RED+SWIR) - 41.2*(NIR-RED)/(NIR+6*RED-7.5*BLUE+1)))', {
            'SWIR': image.select('B11'),
            'NIR': image.select('B8'),
            'RED': image.select('B4'),
            'BLUE': image.select('B2')
        })
    
    return image.addBands(flats.rename('flats'))


def addDate(image):
    img_date = ee.Date(image.date())
    img_date = ee.Number.parse(img_date.format('YYYYMMdd'))
    return image.addBands(ee.Image(img_date).rename('imagedate').toInt())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
gaS2 = s2_sr_cld_col_eval.map(add_cld_shdw_mask).map(cloudmask).filterBounds(fc_all).map(addSENTINELFLATS).select('flats')

# gaS2 = (ee.ImageCollection('COPERNICUS/S2_SR')
#         .filterBounds(aoi)).map(addSENTINELFLATS).select('flats')

ultra_col = gaS2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def rasterExtraction(image, fc_subset):
    return image.sampleRegions(
        collection=fc_subset,  # Use the subset of locations
        scale=10,
        tileScale=8  # Adjust tile scale for performance
    ).map(lambda f: f.set('date', image.date().format('YYYY-MM-dd')))

out_dir = os.path.expanduser('~/Documents/Xin data/Sentinel')

# Split locations into batches of 100
batch_size = 100
fc_list = fc_all.toList(fc_all.size())  # Convert to list
num_features = fc_all.size().getInfo()

# Calculate the number of batches without math.ceil()
num_batches = (num_features + batch_size - 1) // batch_size  # Equivalent to math.ceil(num_features / batch_size)

years = range(2019, 2025)

for year in years:
    for batch in range(num_batches):
        # Subset locations for this batch
        fc_subset = ee.FeatureCollection(fc_list.slice(batch * batch_size, (batch + 1) * batch_size))

        print(f"Processing {year}, Batch {batch + 1}/{num_batches}...")

        # Filter Landsat images for the year
        subset = ultra_col.filterDate(f"{year}-01-01", f"{year}-12-31")

        # Fix: Use a lambda function to pass `fc_subset` properly
        extracted_features = subset.map(lambda img: rasterExtraction(img, fc_subset)).flatten()

        fc_dict = extracted_features.getInfo()
        features = [feature['properties'] for feature in fc_dict['features']]
        df = pd.DataFrame(features)
        df['date'] = pd.to_datetime(df['date'])

        # Save file in the specified directory
        filename = os.path.join(out_dir, f"sentinelflats_{year}_batch{batch + 1}.csv")
        df.to_csv(filename, index=False)
        print(f"Saved {filename}")

print("All batches processed!")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing 2019, Batch 1/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch1.csv
# Processing 2019, Batch 2/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch2.csv
# Processing 2019, Batch 3/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch3.csv
# Processing 2019, Batch 4/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch4.csv
# Processing 2019, Batch 5/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch5.csv
# Processing 2019, Batch 6/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch6.csv
# Processing 2019, Batch 7/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch7.csv
# Processing 2019, Batch 8/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch8.csv
# Processing 2019, Batch 9/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch9.csv
# Processing 2019, Batch 10/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch10.csv
# Processing 2019, Batch 11/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch11.csv
# Processing 2019, Batch 12/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch12.csv
# Processing 2019, Batch 13/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch13.csv
# Processing 2019, Batch 14/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch14.csv
# Processing 2019, Batch 15/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch15.csv
# Processing 2019, Batch 16/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch16.csv
# Processing 2019, Batch 17/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch17.csv
# Processing 2019, Batch 18/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch18.csv
# Processing 2019, Batch 19/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch19.csv
# Processing 2019, Batch 20/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch20.csv
# Processing 2019, Batch 21/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch21.csv
# Processing 2019, Batch 22/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch22.csv
# Processing 2019, Batch 23/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch23.csv
# Processing 2019, Batch 24/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch24.csv
# Processing 2019, Batch 25/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch25.csv
# Processing 2019, Batch 26/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch26.csv
# Processing 2019, Batch 27/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch27.csv
# Processing 2019, Batch 28/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch28.csv
# Processing 2019, Batch 29/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch29.csv
# Processing 2019, Batch 30/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch30.csv
# Processing 2019, Batch 31/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch31.csv
# Processing 2019, Batch 32/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch32.csv
# Processing 2019, Batch 33/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2019_batch33.csv
# Processing 2020, Batch 1/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch1.csv
# Processing 2020, Batch 2/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch2.csv
# Processing 2020, Batch 3/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch3.csv
# Processing 2020, Batch 4/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch4.csv
# Processing 2020, Batch 5/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch5.csv
# Processing 2020, Batch 6/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch6.csv
# Processing 2020, Batch 7/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch7.csv
# Processing 2020, Batch 8/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch8.csv
# Processing 2020, Batch 9/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch9.csv
# Processing 2020, Batch 10/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch10.csv
# Processing 2020, Batch 11/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch11.csv
# Processing 2020, Batch 12/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch12.csv
# Processing 2020, Batch 13/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch13.csv
# Processing 2020, Batch 14/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch14.csv
# Processing 2020, Batch 15/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch15.csv
# Processing 2020, Batch 16/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch16.csv
# Processing 2020, Batch 17/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch17.csv
# Processing 2020, Batch 18/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch18.csv
# Processing 2020, Batch 19/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch19.csv
# Processing 2020, Batch 20/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch20.csv
# Processing 2020, Batch 21/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch21.csv
# Processing 2020, Batch 22/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch22.csv
# Processing 2020, Batch 23/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch23.csv
# Processing 2020, Batch 24/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch24.csv
# Processing 2020, Batch 25/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch25.csv
# Processing 2020, Batch 26/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch26.csv
# Processing 2020, Batch 27/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch27.csv
# Processing 2020, Batch 28/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch28.csv
# Processing 2020, Batch 29/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch29.csv
# Processing 2020, Batch 30/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch30.csv
# Processing 2020, Batch 31/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch31.csv
# Processing 2020, Batch 32/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch32.csv
# Processing 2020, Batch 33/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2020_batch33.csv
# Processing 2021, Batch 1/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch1.csv
# Processing 2021, Batch 2/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch2.csv
# Processing 2021, Batch 3/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch3.csv
# Processing 2021, Batch 4/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch4.csv
# Processing 2021, Batch 5/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch5.csv
# Processing 2021, Batch 6/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch6.csv
# Processing 2021, Batch 7/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch7.csv
# Processing 2021, Batch 8/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch8.csv
# Processing 2021, Batch 9/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch9.csv
# Processing 2021, Batch 10/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch10.csv
# Processing 2021, Batch 11/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch11.csv
# Processing 2021, Batch 12/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch12.csv
# Processing 2021, Batch 13/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch13.csv
# Processing 2021, Batch 14/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch14.csv
# Processing 2021, Batch 15/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch15.csv
# Processing 2021, Batch 16/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch16.csv
# Processing 2021, Batch 17/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch17.csv
# Processing 2021, Batch 18/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch18.csv
# Processing 2021, Batch 19/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch19.csv
# Processing 2021, Batch 20/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch20.csv
# Processing 2021, Batch 21/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch21.csv
# Processing 2021, Batch 22/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch22.csv
# Processing 2021, Batch 23/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch23.csv
# Processing 2021, Batch 24/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch24.csv
# Processing 2021, Batch 25/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch25.csv
# Processing 2021, Batch 26/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch26.csv
# Processing 2021, Batch 27/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch27.csv
# Processing 2021, Batch 28/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch28.csv
# Processing 2021, Batch 29/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch29.csv
# Processing 2021, Batch 30/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch30.csv
# Processing 2021, Batch 31/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch31.csv
# Processing 2021, Batch 32/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch32.csv
# Processing 2021, Batch 33/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2021_batch33.csv
# Processing 2022, Batch 1/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch1.csv
# Processing 2022, Batch 2/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch2.csv
# Processing 2022, Batch 3/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch3.csv
# Processing 2022, Batch 4/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch4.csv
# Processing 2022, Batch 5/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch5.csv
# Processing 2022, Batch 6/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch6.csv
# Processing 2022, Batch 7/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch7.csv
# Processing 2022, Batch 8/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch8.csv
# Processing 2022, Batch 9/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch9.csv
# Processing 2022, Batch 10/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch10.csv
# Processing 2022, Batch 11/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch11.csv
# Processing 2022, Batch 12/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch12.csv
# Processing 2022, Batch 13/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch13.csv
# Processing 2022, Batch 14/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch14.csv
# Processing 2022, Batch 15/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch15.csv
# Processing 2022, Batch 16/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch16.csv
# Processing 2022, Batch 17/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch17.csv
# Processing 2022, Batch 18/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch18.csv
# Processing 2022, Batch 19/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch19.csv
# Processing 2022, Batch 20/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch20.csv
# Processing 2022, Batch 21/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch21.csv
# Processing 2022, Batch 22/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch22.csv
# Processing 2022, Batch 23/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch23.csv
# Processing 2022, Batch 24/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch24.csv
# Processing 2022, Batch 25/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch25.csv
# Processing 2022, Batch 26/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch26.csv
# Processing 2022, Batch 27/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch27.csv
# Processing 2022, Batch 28/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch28.csv
# Processing 2022, Batch 29/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch29.csv
# Processing 2022, Batch 30/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch30.csv
# Processing 2022, Batch 31/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch31.csv
# Processing 2022, Batch 32/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch32.csv
# Processing 2022, Batch 33/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2022_batch33.csv
# Processing 2023, Batch 1/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch1.csv
# Processing 2023, Batch 2/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch2.csv
# Processing 2023, Batch 3/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch3.csv
# Processing 2023, Batch 4/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch4.csv
# Processing 2023, Batch 5/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch5.csv
# Processing 2023, Batch 6/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch6.csv
# Processing 2023, Batch 7/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch7.csv
# Processing 2023, Batch 8/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch8.csv
# Processing 2023, Batch 9/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch9.csv
# Processing 2023, Batch 10/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch10.csv
# Processing 2023, Batch 11/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch11.csv
# Processing 2023, Batch 12/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch12.csv
# Processing 2023, Batch 13/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch13.csv
# Processing 2023, Batch 14/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch14.csv
# Processing 2023, Batch 15/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch15.csv
# Processing 2023, Batch 16/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch16.csv
# Processing 2023, Batch 17/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch17.csv
# Processing 2023, Batch 18/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch18.csv
# Processing 2023, Batch 19/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch19.csv
# Processing 2023, Batch 20/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch20.csv
# Processing 2023, Batch 21/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch21.csv
# Processing 2023, Batch 22/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch22.csv
# Processing 2023, Batch 23/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch23.csv
# Processing 2023, Batch 24/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch24.csv
# Processing 2023, Batch 25/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch25.csv
# Processing 2023, Batch 26/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch26.csv
# Processing 2023, Batch 27/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch27.csv
# Processing 2023, Batch 28/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch28.csv
# Processing 2023, Batch 29/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch29.csv
# Processing 2023, Batch 30/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch30.csv
# Processing 2023, Batch 31/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch31.csv
# Processing 2023, Batch 32/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch32.csv
# Processing 2023, Batch 33/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2023_batch33.csv
# Processing 2024, Batch 1/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch1.csv
# Processing 2024, Batch 2/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch2.csv
# Processing 2024, Batch 3/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch3.csv
# Processing 2024, Batch 4/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch4.csv
# Processing 2024, Batch 5/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch5.csv
# Processing 2024, Batch 6/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch6.csv
# Processing 2024, Batch 7/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch7.csv
# Processing 2024, Batch 8/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch8.csv
# Processing 2024, Batch 9/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch9.csv
# Processing 2024, Batch 10/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch10.csv
# Processing 2024, Batch 11/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch11.csv
# Processing 2024, Batch 12/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch12.csv
# Processing 2024, Batch 13/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch13.csv
# Processing 2024, Batch 14/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch14.csv
# Processing 2024, Batch 15/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch15.csv
# Processing 2024, Batch 16/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch16.csv
# Processing 2024, Batch 17/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch17.csv
# Processing 2024, Batch 18/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch18.csv
# Processing 2024, Batch 19/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch19.csv
# Processing 2024, Batch 20/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch20.csv
# Processing 2024, Batch 21/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch21.csv
# Processing 2024, Batch 22/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch22.csv
# Processing 2024, Batch 23/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch23.csv
# Processing 2024, Batch 24/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch24.csv
# Processing 2024, Batch 25/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch25.csv
# Processing 2024, Batch 26/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch26.csv
# Processing 2024, Batch 27/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch27.csv
# Processing 2024, Batch 28/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch28.csv
# Processing 2024, Batch 29/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch29.csv
# Processing 2024, Batch 30/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch30.csv
# Processing 2024, Batch 31/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch31.csv
# Processing 2024, Batch 32/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch32.csv
# Processing 2024, Batch 33/33...
# Saved C:\Users\arj26323/Documents/Xin data/Sentinel\sentinelflats_2024_batch33.csv
# All batches processed!

# %%
# xxx= ee.Image((ultra_col.toList(ultra_col.size())).get(48))

# Map.addLayer(xxx, {}, 'xxx')
# Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import glob

# path = r'C:/Users/arj26323/Documents/Xin data/Sentinel' 
# all_files = glob.glob(path + "/*.csv")

# li = []

# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     li.append(df)

# df = pd.concat(li, axis=0, ignore_index=True)

# df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Convert date column to datetime if it's not already
# df['date'] = pd.to_datetime(df['date'])

# Group by unique latitude/longitude pairs
grouped = df.groupby(['Latitude', 'Longitude'])

# Select one unique location (e.g., first location in the grouped data)
(lat, lon), location_df = next(iter(grouped))

# Sort by date to ensure proper time series order
location_df = location_df.sort_values('date')

# Plot the time series of 'flats' for this location
plt.figure(figsize=(10, 5))
plt.plot(location_df['date'], location_df['flats'], marker='o', linestyle='-')

plt.xlabel("Date")
plt.ylabel("Flats")
plt.title(f"Time Series for Location: ({lat}, {lon})")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Get unique latitude/longitude pairs
unique_locations = df[['Latitude', 'Longitude']].drop_duplicates().reset_index(drop=True)

# # Display indexed locations
# print("Available Locations:")
# for i, (lat, lon) in unique_locations.iterrows():
#     print(f"{i}: ({lat}, {lon})")

# Ask user to select a location by index
selection = int(input("Enter the index of the location you want to plot: "))

# Extract selected location
lat, lon = unique_locations.iloc[selection]

# Filter dataframe for the selected location
location_df = df[(df['Latitude'] == lat) & (df['Longitude'] == lon)].sort_values('date')

# Plot time series for selected location
plt.figure(figsize=(10, 5))
plt.plot(location_df['date'], location_df['flats'], marker='o', linestyle='--')

plt.xlabel("Date")
plt.ylabel("Flats")
plt.title(f"Time Series for Location: ({lat}, {lon})")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Enter the index of the location you want to plot: 120
