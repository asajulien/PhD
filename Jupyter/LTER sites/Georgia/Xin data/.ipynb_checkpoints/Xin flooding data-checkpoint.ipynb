# %%
import geemap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdb
from IPython.display import display
import ee
import os

# %%
import ee
import geemap
service_account = ' boba-account@boba-430314.iam.gserviceaccount.com '
credentials = ee.ServiceAccountCredentials(service_account,'C:/Users/arj26323/OneDrive - University of Georgia/Documents/GEE AUTH/boba-430314-a19be859bfca.json')

ee.Initialize(credentials)

print(geemap.__version__)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 0.34.1

# %%
Map = geemap.Map(center=[31.539096,-81.422318], zoom=10)

##Adding every plot coordinate
allplots_fc = 'C:/Users/arj26323/Documents/Data/Biomass datasets/Sapelo/GA_allplots_NEW.csv'
xin_fc =  'C:/Users/arj26323/Documents/Xin data/Biomass_Shapefile/Biomass.shp'

# fc_all = geemap.csv_to_ee(allplots_fc, latitude = "Latitude", longitude = "Longitude")
fc_test = geemap.csv_to_ee(allplots_fc, latitude = "Latitude", longitude = "Longitude")

fc_all = geemap.shp_to_ee(xin_fc, latitude = "Latitude", longitude = "Longitude")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# fc_all
# Function to add latitude and longitude as properties
def add_lat_lon(feature):
    coords = feature.geometry().coordinates()
    return feature.set({
        'Latitude': coords.get(1),  # Extract latitude
        'Longitude': coords.get(0)   # Extract longitude
    })

# Apply function to all features in fc_all
fc_all = fc_all.map(add_lat_lon)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
##Function to cloud mask from the pixel_qa band of Landsat 5/8 SR data.

#IS THIS SAME BETWEEN SENSORS: https://github.com/giswqs/geemap/discussions/672

def maskL8sr(image):
    qaMask = image.select('QA_PIXEL').bitwiseAnd(int('11111', 2)).eq(0)
    saturationMask = image.select('QA_RADSAT').eq(0)
    # Apply the scaling factors to the appropriate bands.
    opticalBands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
    thermalBands = image.select('ST_B.*').multiply(0.00341802).add(149.0)
    # Replace the original bands with the scaled ones and apply the masks.
    return image.addBands(opticalBands, None, True) \
    .addBands(thermalBands, None, True) \
    .updateMask(qaMask) \
    .updateMask(saturationMask)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#12/08/22 - adding CALIBRATED FLATS
def addFLATSL7(image):
    flats = ee.Image(0).expression(
        '1/(1+2.718281828459045**-(1.51 + 12.5*(RED-SWIR)/(RED+SWIR) - 41.2*(NIR-RED)/(NIR+6*RED-7.5*BLUE+1)))', {
            'SWIR': image.select('SR_B5'),
            'NIR': image.select('SR_B4'),
            'RED': image.select('SR_B3'),
            'BLUE': image.select('SR_B1')
        })
    
    return image.addBands(flats.rename('flats'))

def addFLATSL5(image):
    flats = ee.Image(0).expression(
        '1/(1+2.718281828459045**-(1.51 + 12.5*(0.972*(RED-SWIR)/(RED+SWIR)-0.008) - 41.2*(0.991*(NIR-RED)/(NIR+6*RED-7.5*BLUE+1)-0.0014)))', {
            'SWIR': image.select('SR_B5'),
            'NIR': image.select('SR_B4'),
            'RED': image.select('SR_B3'),
            'BLUE': image.select('SR_B1')
        })
    
    return image.addBands(flats.rename('flats'))


def addFLATSL8(image):
    flats = ee.Image(0).expression(
        '1/(1+2.718281828459045**-(1.51 + 12.5*(0.841*(RED-SWIR)/(RED+SWIR) - 0.019) - 41.2*(0.771*(NIR-RED)/(NIR+6*RED-7.5*BLUE+1) + 0.011)))', {
            'SWIR': image.select('SR_B6'),
            'NIR': image.select('SR_B5'),
            'RED': image.select('SR_B4'),
            'BLUE': image.select('SR_B2')
        })
    
    return image.addBands(flats.rename('flats'))

def addFLATSL9(image):
    flats = ee.Image(0).expression(
        '1/(1+2.718281828459045**-(1.51 + 12.5*(1.225*(RED-SWIR)/(RED+SWIR) + 0.096) - 41.2*(1.038* (NIR-RED)/(NIR+6*RED-7.5*BLUE+1) - 0.004)))', {
            'SWIR': image.select('SR_B6'),
            'NIR': image.select('SR_B5'),
            'RED': image.select('SR_B4'),
            'BLUE': image.select('SR_B2')
        })
    
    return image.addBands(flats.rename('flats'))

##MASKING FLATS
def maskFLATS(image):
    mask1 = image.select('flats').lte(0.1) #less than or equal to 0.1 - change?
    return image.updateMask(mask1)

##ADDING NDVI (for min/max variables)
def addL5ndvi(image):
    ndvi = image.expression(
        '(NIR-RED)/(RED+NIR)', {
            'NIR': image.select('SR_B4'),
            'RED': image.select('SR_B3'),
            'GREEN': image.select('SR_B2')
        })
    
    return image.addBands(ndvi.rename('ndvi'))

def addL8ndvi(image):
    ndvi = image.expression(
        '(NIR-RED)/(RED+NIR)', {
            'NIR': image.select('SR_B5'),
            'RED': image.select('SR_B4'),
            'GREEN': image.select('SR_B3')
        })
    
    return image.addBands(ndvi.rename('ndvi'))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
##Pixel extraction functions - addDate for dateless images/collections
def addDate(image):
    img_date = ee.Date(image.date())
    img_date = ee.Number.parse(img_date.format('YYYYMMdd'))
    return image.addBands(ee.Image(img_date).rename('imagedate').toInt())

##For Landsat images:
def rasterExtraction(image):
    feature = image.sampleRegions(
        collection = fc_all,
        scale = 30,
        tileScale = 16 #ADDED 10/6/2022 - make sure it doesn't affect results (see thread below)
    )
    return feature
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#Datasets
ls5_collect = ee.ImageCollection('LANDSAT/LT05/C02/T1_L2').filterBounds(fc_all).map(maskL8sr).map(addFLATSL5)
ls7_collect = ee.ImageCollection('LANDSAT/LE07/C02/T1_L2').filterBounds(fc_all).map(maskL8sr).map(addFLATSL7)
ls8_collect = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2').filterBounds(fc_all).map(maskL8sr).map(addFLATSL8)
ls9_collect = ee.ImageCollection('LANDSAT/LC09/C02/T1_L2').filterBounds(fc_all).map(maskL8sr).map(addFLATSL8)

#Merge
ultra_col = ls8_collect.merge(ls5_collect).merge(ls7_collect).merge(ls9_collect).select('flats')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
##Uncomment to run extraction

# def rasterExtraction(image, fc_subset):
#     return image.sampleRegions(
#         collection=fc_subset,  # Use the subset of locations
#         scale=30,
#         tileScale=8  # Adjust tile scale for performance
#     ).map(lambda f: f.set('date', image.date().format('YYYY-MM-dd')))

# out_dir = os.path.expanduser('~/Documents/Xin data/Landsat')

# # Split locations into batches of 100
# batch_size = 100
# fc_list = fc_all.toList(fc_all.size())  # Convert to list
# num_features = fc_all.size().getInfo()

# # Calculate the number of batches without math.ceil()
# num_batches = (num_features + batch_size - 1) // batch_size  # Equivalent to math.ceil(num_features / batch_size)

# years = range(1984, 2025)

# for year in years:
#     for batch in range(num_batches):
#         # Subset locations for this batch
#         fc_subset = ee.FeatureCollection(fc_list.slice(batch * batch_size, (batch + 1) * batch_size))

#         print(f"Processing {year}, Batch {batch + 1}/{num_batches}...")

#         # Filter Landsat images for the year
#         subset = ultra_col.filterDate(f"{year}-01-01", f"{year}-12-31")

#         # Fix: Use a lambda function to pass `fc_subset` properly
#         extracted_features = subset.map(lambda img: rasterExtraction(img, fc_subset)).flatten()

#         fc_dict = extracted_features.getInfo()
#         features = [feature['properties'] for feature in fc_dict['features']]
#         df = pd.DataFrame(features)
#         df['date'] = pd.to_datetime(df['date'])

#         # Save file in the specified directory
#         filename = os.path.join(out_dir, f"landsatflats_{year}_batch{batch + 1}.csv")
#         df.to_csv(filename, index=False)
#         print(f"Saved {filename}")

# print("All batches processed!")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing 2017, Batch 1/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch1.csv
# Processing 2017, Batch 2/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch2.csv
# Processing 2017, Batch 3/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch3.csv
# Processing 2017, Batch 4/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch4.csv
# Processing 2017, Batch 5/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch5.csv
# Processing 2017, Batch 6/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch6.csv
# Processing 2017, Batch 7/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch7.csv
# Processing 2017, Batch 8/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch8.csv
# Processing 2017, Batch 9/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch9.csv
# Processing 2017, Batch 10/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch10.csv
# Processing 2017, Batch 11/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch11.csv
# Processing 2017, Batch 12/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch12.csv
# Processing 2017, Batch 13/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch13.csv
# Processing 2017, Batch 14/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch14.csv
# Processing 2017, Batch 15/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch15.csv
# Processing 2017, Batch 16/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch16.csv
# Processing 2017, Batch 17/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch17.csv
# Processing 2017, Batch 18/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch18.csv
# Processing 2017, Batch 19/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch19.csv
# Processing 2017, Batch 20/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch20.csv
# Processing 2017, Batch 21/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch21.csv
# Processing 2017, Batch 22/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch22.csv
# Processing 2017, Batch 23/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch23.csv
# Processing 2017, Batch 24/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch24.csv
# Processing 2017, Batch 25/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch25.csv
# Processing 2017, Batch 26/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch26.csv
# Processing 2017, Batch 27/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch27.csv
# Processing 2017, Batch 28/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch28.csv
# Processing 2017, Batch 29/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch29.csv
# Processing 2017, Batch 30/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch30.csv
# Processing 2017, Batch 31/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch31.csv
# Processing 2017, Batch 32/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2017_batch32.csv
# Processing 2018, Batch 1/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch1.csv
# Processing 2018, Batch 2/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch2.csv
# Processing 2018, Batch 3/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch3.csv
# Processing 2018, Batch 4/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch4.csv
# Processing 2018, Batch 5/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch5.csv
# Processing 2018, Batch 6/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch6.csv
# Processing 2018, Batch 7/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch7.csv
# Processing 2018, Batch 8/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch8.csv
# Processing 2018, Batch 9/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch9.csv
# Processing 2018, Batch 10/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch10.csv
# Processing 2018, Batch 11/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch11.csv
# Processing 2018, Batch 12/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch12.csv
# Processing 2018, Batch 13/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch13.csv
# Processing 2018, Batch 14/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch14.csv
# Processing 2018, Batch 15/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch15.csv
# Processing 2018, Batch 16/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch16.csv
# Processing 2018, Batch 17/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch17.csv
# Processing 2018, Batch 18/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch18.csv
# Processing 2018, Batch 19/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch19.csv
# Processing 2018, Batch 20/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch20.csv
# Processing 2018, Batch 21/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch21.csv
# Processing 2018, Batch 22/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch22.csv
# Processing 2018, Batch 23/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch23.csv
# Processing 2018, Batch 24/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch24.csv
# Processing 2018, Batch 25/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch25.csv
# Processing 2018, Batch 26/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch26.csv
# Processing 2018, Batch 27/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch27.csv
# Processing 2018, Batch 28/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch28.csv
# Processing 2018, Batch 29/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch29.csv
# Processing 2018, Batch 30/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch30.csv
# Processing 2018, Batch 31/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch31.csv
# Processing 2018, Batch 32/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2018_batch32.csv
# Processing 2019, Batch 1/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch1.csv
# Processing 2019, Batch 2/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch2.csv
# Processing 2019, Batch 3/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch3.csv
# Processing 2019, Batch 4/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch4.csv
# Processing 2019, Batch 5/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch5.csv
# Processing 2019, Batch 6/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch6.csv
# Processing 2019, Batch 7/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch7.csv
# Processing 2019, Batch 8/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch8.csv
# Processing 2019, Batch 9/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch9.csv
# Processing 2019, Batch 10/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch10.csv
# Processing 2019, Batch 11/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch11.csv
# Processing 2019, Batch 12/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch12.csv
# Processing 2019, Batch 13/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch13.csv
# Processing 2019, Batch 14/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch14.csv
# Processing 2019, Batch 15/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch15.csv
# Processing 2019, Batch 16/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch16.csv
# Processing 2019, Batch 17/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch17.csv
# Processing 2019, Batch 18/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch18.csv
# Processing 2019, Batch 19/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch19.csv
# Processing 2019, Batch 20/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch20.csv
# Processing 2019, Batch 21/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch21.csv
# Processing 2019, Batch 22/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch22.csv
# Processing 2019, Batch 23/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch23.csv
# Processing 2019, Batch 24/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch24.csv
# Processing 2019, Batch 25/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch25.csv
# Processing 2019, Batch 26/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch26.csv
# Processing 2019, Batch 27/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch27.csv
# Processing 2019, Batch 28/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch28.csv
# Processing 2019, Batch 29/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch29.csv
# Processing 2019, Batch 30/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch30.csv
# Processing 2019, Batch 31/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch31.csv
# Processing 2019, Batch 32/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2019_batch32.csv
# Processing 2020, Batch 1/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch1.csv
# Processing 2020, Batch 2/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch2.csv
# Processing 2020, Batch 3/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch3.csv
# Processing 2020, Batch 4/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch4.csv
# Processing 2020, Batch 5/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch5.csv
# Processing 2020, Batch 6/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch6.csv
# Processing 2020, Batch 7/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch7.csv
# Processing 2020, Batch 8/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch8.csv
# Processing 2020, Batch 9/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch9.csv
# Processing 2020, Batch 10/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch10.csv
# Processing 2020, Batch 11/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch11.csv
# Processing 2020, Batch 12/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch12.csv
# Processing 2020, Batch 13/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch13.csv
# Processing 2020, Batch 14/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch14.csv
# Processing 2020, Batch 15/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch15.csv
# Processing 2020, Batch 16/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch16.csv
# Processing 2020, Batch 17/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch17.csv
# Processing 2020, Batch 18/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch18.csv
# Processing 2020, Batch 19/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch19.csv
# Processing 2020, Batch 20/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch20.csv
# Processing 2020, Batch 21/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch21.csv
# Processing 2020, Batch 22/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch22.csv
# Processing 2020, Batch 23/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch23.csv
# Processing 2020, Batch 24/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch24.csv
# Processing 2020, Batch 25/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch25.csv
# Processing 2020, Batch 26/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch26.csv
# Processing 2020, Batch 27/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch27.csv
# Processing 2020, Batch 28/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch28.csv
# Processing 2020, Batch 29/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch29.csv
# Processing 2020, Batch 30/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch30.csv
# Processing 2020, Batch 31/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch31.csv
# Processing 2020, Batch 32/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2020_batch32.csv
# Processing 2021, Batch 1/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch1.csv
# Processing 2021, Batch 2/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch2.csv
# Processing 2021, Batch 3/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch3.csv
# Processing 2021, Batch 4/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch4.csv
# Processing 2021, Batch 5/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch5.csv
# Processing 2021, Batch 6/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch6.csv
# Processing 2021, Batch 7/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch7.csv
# Processing 2021, Batch 8/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch8.csv
# Processing 2021, Batch 9/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch9.csv
# Processing 2021, Batch 10/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch10.csv
# Processing 2021, Batch 11/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch11.csv
# Processing 2021, Batch 12/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch12.csv
# Processing 2021, Batch 13/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch13.csv
# Processing 2021, Batch 14/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch14.csv
# Processing 2021, Batch 15/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch15.csv
# Processing 2021, Batch 16/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch16.csv
# Processing 2021, Batch 17/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch17.csv
# Processing 2021, Batch 18/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch18.csv
# Processing 2021, Batch 19/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch19.csv
# Processing 2021, Batch 20/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch20.csv
# Processing 2021, Batch 21/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch21.csv
# Processing 2021, Batch 22/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch22.csv
# Processing 2021, Batch 23/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch23.csv
# Processing 2021, Batch 24/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch24.csv
# Processing 2021, Batch 25/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch25.csv
# Processing 2021, Batch 26/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch26.csv
# Processing 2021, Batch 27/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch27.csv
# Processing 2021, Batch 28/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch28.csv
# Processing 2021, Batch 29/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch29.csv
# Processing 2021, Batch 30/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch30.csv
# Processing 2021, Batch 31/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch31.csv
# Processing 2021, Batch 32/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2021_batch32.csv
# Processing 2022, Batch 1/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch1.csv
# Processing 2022, Batch 2/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch2.csv
# Processing 2022, Batch 3/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch3.csv
# Processing 2022, Batch 4/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch4.csv
# Processing 2022, Batch 5/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch5.csv
# Processing 2022, Batch 6/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch6.csv
# Processing 2022, Batch 7/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch7.csv
# Processing 2022, Batch 8/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch8.csv
# Processing 2022, Batch 9/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch9.csv
# Processing 2022, Batch 10/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch10.csv
# Processing 2022, Batch 11/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch11.csv
# Processing 2022, Batch 12/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch12.csv
# Processing 2022, Batch 13/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch13.csv
# Processing 2022, Batch 14/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch14.csv
# Processing 2022, Batch 15/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch15.csv
# Processing 2022, Batch 16/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch16.csv
# Processing 2022, Batch 17/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch17.csv
# Processing 2022, Batch 18/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch18.csv
# Processing 2022, Batch 19/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch19.csv
# Processing 2022, Batch 20/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch20.csv
# Processing 2022, Batch 21/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch21.csv
# Processing 2022, Batch 22/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch22.csv
# Processing 2022, Batch 23/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch23.csv
# Processing 2022, Batch 24/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch24.csv
# Processing 2022, Batch 25/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch25.csv
# Processing 2022, Batch 26/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch26.csv
# Processing 2022, Batch 27/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch27.csv
# Processing 2022, Batch 28/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch28.csv
# Processing 2022, Batch 29/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch29.csv
# Processing 2022, Batch 30/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch30.csv
# Processing 2022, Batch 31/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch31.csv
# Processing 2022, Batch 32/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2022_batch32.csv
# Processing 2023, Batch 1/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch1.csv
# Processing 2023, Batch 2/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch2.csv
# Processing 2023, Batch 3/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch3.csv
# Processing 2023, Batch 4/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch4.csv
# Processing 2023, Batch 5/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch5.csv
# Processing 2023, Batch 6/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch6.csv
# Processing 2023, Batch 7/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch7.csv
# Processing 2023, Batch 8/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch8.csv
# Processing 2023, Batch 9/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch9.csv
# Processing 2023, Batch 10/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch10.csv
# Processing 2023, Batch 11/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch11.csv
# Processing 2023, Batch 12/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch12.csv
# Processing 2023, Batch 13/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch13.csv
# Processing 2023, Batch 14/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch14.csv
# Processing 2023, Batch 15/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch15.csv
# Processing 2023, Batch 16/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch16.csv
# Processing 2023, Batch 17/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch17.csv
# Processing 2023, Batch 18/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch18.csv
# Processing 2023, Batch 19/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch19.csv
# Processing 2023, Batch 20/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch20.csv
# Processing 2023, Batch 21/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch21.csv
# Processing 2023, Batch 22/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch22.csv
# Processing 2023, Batch 23/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch23.csv
# Processing 2023, Batch 24/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch24.csv
# Processing 2023, Batch 25/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch25.csv
# Processing 2023, Batch 26/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch26.csv
# Processing 2023, Batch 27/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch27.csv
# Processing 2023, Batch 28/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch28.csv
# Processing 2023, Batch 29/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch29.csv
# Processing 2023, Batch 30/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch30.csv
# Processing 2023, Batch 31/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch31.csv
# Processing 2023, Batch 32/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2023_batch32.csv
# Processing 2024, Batch 1/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch1.csv
# Processing 2024, Batch 2/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch2.csv
# Processing 2024, Batch 3/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch3.csv
# Processing 2024, Batch 4/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch4.csv
# Processing 2024, Batch 5/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch5.csv
# Processing 2024, Batch 6/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch6.csv
# Processing 2024, Batch 7/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch7.csv
# Processing 2024, Batch 8/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch8.csv
# Processing 2024, Batch 9/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch9.csv
# Processing 2024, Batch 10/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch10.csv
# Processing 2024, Batch 11/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch11.csv
# Processing 2024, Batch 12/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch12.csv
# Processing 2024, Batch 13/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch13.csv
# Processing 2024, Batch 14/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch14.csv
# Processing 2024, Batch 15/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch15.csv
# Processing 2024, Batch 16/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch16.csv
# Processing 2024, Batch 17/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch17.csv
# Processing 2024, Batch 18/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch18.csv
# Processing 2024, Batch 19/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch19.csv
# Processing 2024, Batch 20/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch20.csv
# Processing 2024, Batch 21/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch21.csv
# Processing 2024, Batch 22/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch22.csv
# Processing 2024, Batch 23/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch23.csv
# Processing 2024, Batch 24/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch24.csv
# Processing 2024, Batch 25/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch25.csv
# Processing 2024, Batch 26/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch26.csv
# Processing 2024, Batch 27/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch27.csv
# Processing 2024, Batch 28/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch28.csv
# Processing 2024, Batch 29/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch29.csv
# Processing 2024, Batch 30/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch30.csv
# Processing 2024, Batch 31/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch31.csv
# Processing 2024, Batch 32/32...
# Saved C:\Users\arj26323/Documents/Xin data/Landsat\landsatflats_2024_batch32.csv
# All batches processed!

# %%
#PROPORTION OF TIME FLOODED
#Inundation intensity
#Rajneesh

# import glob

# path = r'C:/Users/arj26323/Documents/Xin data/Landsat' 
# all_files = glob.glob(path + "/landsatflats_1984_*")

# li = []

# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     li.append(df)

# df = pd.concat(li, axis=0, ignore_index=True)

# df

# upd = df[['Latitude', 'Longitude']].drop_duplicates().reset_index()
# upd

# Map.add_points_from_xy(upd, x="Longitude", y="Latitude")
# Map.addLayer(ultra_col.first(),{},'flats')
# Map.addLayer(fc_all,{},'points')
# Map
# fc_all
# Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import glob

# path = r'C:/Users/arj26323/Documents/Xin data/Landsat' 
# all_files = glob.glob(path + "/*.csv")

# li = []

# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     li.append(df)

# df = pd.concat(li, axis=0, ignore_index=True)

# df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#           Biomass      Date  Flwrn_S   Latitude  Longitude Spcs_Cd  \
# 0        2506.982  20151023      NaN  31.335017 -81.478711      A4
# 1        4006.166  20161024      NaN  31.335017 -81.478711      A4
# 2        3363.712  20171016      NaN  31.335017 -81.478711      A4
# 3        3177.366  20181015      NaN  31.335017 -81.478711      A4
# 4        1821.010  20191008      NaN  31.335017 -81.478711      A4
# ...           ...       ...      ...        ...        ...     ...
# 1921195   734.632  20211017      0.0  31.451282 -81.366151      A1
# 1921196   537.364  20221018      0.0  31.451282 -81.366151      A1
# 1921197   439.348  20231011      0.0  31.451282 -81.366151      A1
# 1921198   963.908  20151020      0.0  31.451204 -81.366127      A1
# 1921199  1003.284  20161026      1.0  31.451204 -81.366127      A1
#
#                date     flats
# 0        1984-05-14  0.001437
# 1        1984-05-14  0.001437
# 2        1984-05-14  0.001437
# 3        1984-05-14  0.001437
# 4        1984-05-14  0.001437
# ...             ...       ...
# 1921195  2024-12-21  0.041580
# 1921196  2024-12-21  0.041580
# 1921197  2024-12-21  0.041580
# 1921198  2024-12-21  0.041580
# 1921199  2024-12-21  0.041580
#
# [1921200 rows x 8 columns]

# %%
# Group by unique latitude/longitude pairs
grouped = df.groupby(['Latitude', 'Longitude'])

# Select one unique location (e.g., first location in the grouped data)
(lat, lon), location_df = next(iter(grouped))

# Sort by date to ensure proper time series order
location_df = location_df.sort_values('date')

# Plot the time series of 'flats' for this location
plt.figure(figsize=(10, 5))
plt.plot(location_df['date'], location_df['flats'], marker='o', linestyle='')

plt.xlabel("Date")
plt.ylabel("Flats")
plt.title(f"Time Series for Location: ({lat}, {lon})")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Get unique latitude/longitude pairs
unique_locations = df[['Latitude', 'Longitude']].drop_duplicates().reset_index(drop=True)

# Display indexed locations
# print("Available Locations:")
# for i, (lat, lon) in unique_locations.iterrows():
#     print(f"{i}: ({lat}, {lon})")

# Ask user to select a location by index
selection = int(input("Enter the index of the location you want to plot: "))

# Extract selected location
lat, lon = unique_locations.iloc[selection]

# Filter dataframe for the selected location
location_df = df[(df['Latitude'] == lat) & (df['Longitude'] == lon)].sort_values('date')

# Plot time series for selected location
plt.figure(figsize=(10, 5))
plt.plot(location_df['date'], location_df['flats'], marker='o', linestyle='')

plt.xlabel("Date")
plt.ylabel("Flats")
plt.title(f"Time Series for Location: ({lat}, {lon})")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Enter the index of the location you want to plot: 98

# %%
#df.groupby(['Latitude','Longitude']).size()

df_flooding = df.groupby(['Latitude', 'Longitude']).apply(
    lambda g: (g['flats'] >= 0.2).mean()).reset_index(name='Percent_flooding'
                                                     )
df_flooding
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       Latitude  Longitude  Percent_flooding
# 0    31.307529 -81.415324          0.039201
# 1    31.307562 -81.415389          0.039201
# 2    31.307641 -81.415468          0.039201
# 3    31.307693 -81.415592          0.721236
# 4    31.307760 -81.415721          0.721236
# ..         ...        ...               ...
# 176  31.539429 -81.422410          0.009724
# 177  31.539457 -81.422250          0.006415
# 178  31.539480 -81.422098          0.006415
# 179  31.539491 -81.421750          0.004831
# 180  31.539505 -81.421937          0.004831
#
# [181 rows x 3 columns]

# %%
# xxx= ee.Image((ultra_col.toList(ultra_col.size())).get(0))

# Map.addLayer(xxx, {}, 'xxx')
# Map


# import os

# out_dir = os.path.expanduser('~/Downloads')
# out_csv = os.path.join(out_dir, 'flood_freq.csv')

# df_flooding.to_csv(out_csv)

dfx = df[df['Date'] == 20151023]

dfy =dfx[dfx['Latitude'] == 31.335017]

dfy
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#           Biomass      Date  Flwrn_S   Latitude  Longitude Spcs_Cd  \
# 0        2506.982  20151023      NaN  31.335017 -81.478711      A4
# 100      2506.982  20151023      NaN  31.335017 -81.478711      A4
# 200      2506.982  20151023      NaN  31.335017 -81.478711      A4
# 300      2506.982  20151023      NaN  31.335017 -81.478711      A4
# 400      2506.982  20151023      NaN  31.335017 -81.478711      A4
# ...           ...       ...      ...        ...        ...     ...
# 1855582  2506.982  20151023      NaN  31.335017 -81.478711      A4
# 1855632  2506.982  20151023      NaN  31.335017 -81.478711      A4
# 1855682  2506.982  20151023      NaN  31.335017 -81.478711      A4
# 1855732  2506.982  20151023      NaN  31.335017 -81.478711      A4
# 1855782  2506.982  20151023      NaN  31.335017 -81.478711      A4
#
#                date     flats
# 0        1984-05-14  0.001437
# 100      1984-06-15  0.000173
# 200      1984-08-18  0.000316
# 300      1984-09-03  0.000237
# 400      1984-10-21  0.000929
# ...             ...       ...
# 1855582  2024-05-11  0.000631
# 1855632  2024-07-30  0.000433
# 1855682  2024-08-31  0.000151
# 1855732  2024-10-18  0.000642
# 1855782  2024-12-21  0.007868
#
# [1191 rows x 8 columns]
