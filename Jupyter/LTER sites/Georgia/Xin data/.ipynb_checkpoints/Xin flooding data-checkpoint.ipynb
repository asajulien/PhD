# %%
import geemap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdb
from IPython.display import display
import ee
import os

# %%
import ee
import geemap
service_account = ' boba-account@boba-430314.iam.gserviceaccount.com '
credentials = ee.ServiceAccountCredentials(service_account,'C:/Users/arj26323/OneDrive - University of Georgia/Documents/GEE AUTH/boba-430314-a19be859bfca.json')

ee.Initialize(credentials)

print(geemap.__version__)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 0.34.1

# %%
Map = geemap.Map(center=[31.539096,-81.422318], zoom=10)

##Adding every plot coordinate
#GA:
allplots_fc = 'C:/Users/arj26323/Documents/Data/Biomass datasets/Sapelo/GA_allplots_NEW.csv'

##Virginia:
# allplots_fc= 'C:/Users/arj26323/Documents/Data/Biomass datasets/Virginia/Coordinates and biomass/va_allspecies2.csv'

xin_fc =  'C:/Users/arj26323/Documents/Xin data/Biomass_Shapefile/Biomass.shp'

fc_all = geemap.csv_to_ee(allplots_fc, latitude = "Latitude", longitude = "Longitude")
fc_test = pd.read_csv(allplots_fc)

# fc_all = geemap.shp_to_ee(allplots_fc, latitude = "Latitude", longitude = "Longitude")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# fc_all
# Function to add latitude and longitude as properties
def add_lat_lon(feature):
    coords = feature.geometry().coordinates()
    return feature.set({
        'Latitude': coords.get(1),  # Extract latitude
        'Longitude': coords.get(0)   # Extract longitude
    })

# Apply function to all features in fc_all
# fc_all = fc_all.map(add_lat_lon)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
##Function to cloud mask from the pixel_qa band of Landsat 5/8 SR data.

#IS THIS SAME BETWEEN SENSORS: https://github.com/giswqs/geemap/discussions/672

def maskL8sr(image):
    qaMask = image.select('QA_PIXEL').bitwiseAnd(int('11111', 2)).eq(0)
    saturationMask = image.select('QA_RADSAT').eq(0)
    # Apply the scaling factors to the appropriate bands.
    opticalBands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
    thermalBands = image.select('ST_B.*').multiply(0.00341802).add(149.0)
    # Replace the original bands with the scaled ones and apply the masks.
    return image.addBands(opticalBands, None, True) \
    .addBands(thermalBands, None, True) \
    .updateMask(qaMask) \
    .updateMask(saturationMask)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#12/08/22 - adding CALIBRATED FLATS
def addFLATSL7(image):
    flats = ee.Image(0).expression(
        '1/(1+2.718281828459045**-(1.51 + 12.5*(RED-SWIR)/(RED+SWIR) - 41.2*(NIR-RED)/(NIR+6*RED-7.5*BLUE+1)))', {
            'SWIR': image.select('SR_B5'),
            'NIR': image.select('SR_B4'),
            'RED': image.select('SR_B3'),
            'BLUE': image.select('SR_B1')
        })
    
    return image.addBands(flats.rename('flats'))

def addFLATSL5(image):
    flats = ee.Image(0).expression(
        '1/(1+2.718281828459045**-(1.51 + 12.5*(0.972*(RED-SWIR)/(RED+SWIR)-0.008) - 41.2*(0.991*(NIR-RED)/(NIR+6*RED-7.5*BLUE+1)-0.0014)))', {
            'SWIR': image.select('SR_B5'),
            'NIR': image.select('SR_B4'),
            'RED': image.select('SR_B3'),
            'BLUE': image.select('SR_B1')
        })
    
    return image.addBands(flats.rename('flats'))


def addFLATSL8(image):
    flats = ee.Image(0).expression(
        '1/(1+2.718281828459045**-(1.51 + 12.5*(0.841*(RED-SWIR)/(RED+SWIR) - 0.019) - 41.2*(0.771*(NIR-RED)/(NIR+6*RED-7.5*BLUE+1) + 0.011)))', {
            'SWIR': image.select('SR_B6'),
            'NIR': image.select('SR_B5'),
            'RED': image.select('SR_B4'),
            'BLUE': image.select('SR_B2')
        })
    
    return image.addBands(flats.rename('flats'))

def addFLATSL9(image):
    flats = ee.Image(0).expression(
        '1/(1+2.718281828459045**-(1.51 + 12.5*(1.225*(RED-SWIR)/(RED+SWIR) + 0.096) - 41.2*(1.038* (NIR-RED)/(NIR+6*RED-7.5*BLUE+1) - 0.004)))', {
            'SWIR': image.select('SR_B6'),
            'NIR': image.select('SR_B5'),
            'RED': image.select('SR_B4'),
            'BLUE': image.select('SR_B2')
        })
    
    return image.addBands(flats.rename('flats'))

##MASKING FLATS
def maskFLATS(image):
    mask1 = image.select('flats').lte(0.2) #less than or equal to 0.1 - change?
    return image.updateMask(mask1)

##ADDING NDVI (for min/max variables)
def addL5ndvi(image):
    ndvi = image.expression(
        '(NIR-RED)/(RED+NIR)', {
            'NIR': image.select('SR_B4'),
            'RED': image.select('SR_B3'),
            'GREEN': image.select('SR_B2')
        })
    
    return image.addBands(ndvi.rename('ndvi'))

def addL8ndvi(image):
    ndvi = image.expression(
        '(NIR-RED)/(RED+NIR)', {
            'NIR': image.select('SR_B5'),
            'RED': image.select('SR_B4'),
            'GREEN': image.select('SR_B3')
        })
    
    return image.addBands(ndvi.rename('ndvi'))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
##Pixel extraction functions - addDate for dateless images/collections
def addDate(image):
    img_date = ee.Date(image.date())
    img_date = ee.Number.parse(img_date.format('YYYYMMdd'))
    return image.addBands(ee.Image(img_date).rename('imagedate').toInt())

##For Landsat images:
def rasterExtraction(image):
    feature = image.sampleRegions(
        collection = fc_all,
        scale = 30,
        tileScale = 16 #ADDED 10/6/2022 - make sure it doesn't affect results (see thread below)
    )
    return feature
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#Datasets
ls5_collect = ee.ImageCollection('LANDSAT/LT05/C02/T1_L2').filterBounds(fc_all).map(maskL8sr).map(addFLATSL5)
ls7_collect = ee.ImageCollection('LANDSAT/LE07/C02/T1_L2').filterBounds(fc_all).map(maskL8sr).map(addFLATSL7)
ls8_collect = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2').filterBounds(fc_all).map(maskL8sr).map(addFLATSL8)
ls9_collect = ee.ImageCollection('LANDSAT/LC09/C02/T1_L2').filterBounds(fc_all).map(maskL8sr).map(addFLATSL8)

#Merge
ultra_col = ls8_collect.merge(ls5_collect).merge(ls7_collect).merge(ls9_collect).select('flats')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map.addLayer(fc_all)
# Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#Uncomment to run extraction

# def rasterExtraction(image, fc_subset):
#     return image.sampleRegions(
#         collection=fc_subset,  # Use the subset of locations
#         scale=30,
#         tileScale=8  # Adjust tile scale for performance
#     ).map(lambda f: f.set('date', image.date().format('YYYY-MM-dd')))

# out_dir = os.path.expanduser('~/Documents/Xin data/Virginia')

# # Split locations into batches of 100
# batch_size = 100
# fc_list = fc_all.toList(fc_all.size())  # Convert to list
# num_features = fc_all.size().getInfo()

# # Calculate the number of batches without math.ceil()
# num_batches = (num_features + batch_size - 1) // batch_size  # Equivalent to math.ceil(num_features / batch_size)

# years = range(1984, 2020)

# for year in years:
#     for batch in range(num_batches):
#         # Subset locations for this batch
#         fc_subset = ee.FeatureCollection(fc_list.slice(batch * batch_size, (batch + 1) * batch_size))

#         print(f"Processing {year}, Batch {batch + 1}/{num_batches}...")

#         # Filter Landsat images for the year
#         subset = ultra_col.filterDate(f"{year}-01-01", f"{year}-12-31")

#         # Fix: Use a lambda function to pass `fc_subset` properly
#         extracted_features = subset.map(lambda img: rasterExtraction(img, fc_subset)).flatten()

#         fc_dict = extracted_features.getInfo()
#         features = [feature['properties'] for feature in fc_dict['features']]
#         df = pd.DataFrame(features)
#         df['date'] = pd.to_datetime(df['date'])

#         # Save file in the specified directory
#         filename = os.path.join(out_dir, f"VAlandsatflats_{year}_batch{batch + 1}.csv")
#         df.to_csv(filename, index=False)
#         print(f"Saved {filename}")

# print("All batches processed!")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing 1984, Batch 1/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch1.csv
# Processing 1984, Batch 2/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch2.csv
# Processing 1984, Batch 3/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch3.csv
# Processing 1984, Batch 4/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch4.csv
# Processing 1984, Batch 5/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch5.csv
# Processing 1984, Batch 6/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch6.csv
# Processing 1984, Batch 7/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch7.csv
# Processing 1984, Batch 8/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch8.csv
# Processing 1984, Batch 9/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch9.csv
# Processing 1984, Batch 10/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch10.csv
# Processing 1984, Batch 11/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch11.csv
# Processing 1984, Batch 12/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch12.csv
# Processing 1984, Batch 13/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch13.csv
# Processing 1984, Batch 14/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch14.csv
# Processing 1984, Batch 15/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch15.csv
# Processing 1984, Batch 16/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch16.csv
# Processing 1984, Batch 17/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch17.csv
# Processing 1984, Batch 18/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch18.csv
# Processing 1984, Batch 19/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch19.csv
# Processing 1984, Batch 20/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch20.csv
# Processing 1984, Batch 21/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch21.csv
# Processing 1984, Batch 22/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch22.csv
# Processing 1984, Batch 23/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch23.csv
# Processing 1984, Batch 24/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch24.csv
# Processing 1984, Batch 25/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch25.csv
# Processing 1984, Batch 26/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch26.csv
# Processing 1984, Batch 27/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch27.csv
# Processing 1984, Batch 28/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch28.csv
# Processing 1984, Batch 29/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch29.csv
# Processing 1984, Batch 30/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch30.csv
# Processing 1984, Batch 31/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch31.csv
# Processing 1984, Batch 32/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch32.csv
# Processing 1984, Batch 33/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch33.csv
# Processing 1984, Batch 34/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch34.csv
# Processing 1984, Batch 35/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch35.csv
# Processing 1984, Batch 36/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch36.csv
# Processing 1984, Batch 37/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch37.csv
# Processing 1984, Batch 38/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch38.csv
# Processing 1984, Batch 39/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch39.csv
# Processing 1984, Batch 40/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch40.csv
# Processing 1984, Batch 41/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch41.csv
# Processing 1984, Batch 42/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch42.csv
# Processing 1984, Batch 43/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch43.csv
# Processing 1984, Batch 44/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch44.csv
# Processing 1984, Batch 45/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch45.csv
# Processing 1984, Batch 46/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch46.csv
# Processing 1984, Batch 47/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch47.csv
# Processing 1984, Batch 48/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch48.csv
# Processing 1984, Batch 49/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch49.csv
# Processing 1984, Batch 50/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch50.csv
# Processing 1984, Batch 51/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch51.csv
# Processing 1984, Batch 52/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch52.csv
# Processing 1984, Batch 53/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch53.csv
# Processing 1984, Batch 54/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch54.csv
# Processing 1984, Batch 55/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch55.csv
# Processing 1984, Batch 56/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch56.csv
# Processing 1984, Batch 57/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch57.csv
# Processing 1984, Batch 58/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch58.csv
# Processing 1984, Batch 59/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch59.csv
# Processing 1984, Batch 60/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch60.csv
# Processing 1984, Batch 61/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch61.csv
# Processing 1984, Batch 62/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch62.csv
# Processing 1984, Batch 63/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch63.csv
# Processing 1984, Batch 64/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch64.csv
# Processing 1984, Batch 65/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch65.csv
# Processing 1984, Batch 66/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch66.csv
# Processing 1984, Batch 67/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch67.csv
# Processing 1984, Batch 68/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch68.csv
# Processing 1984, Batch 69/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch69.csv
# Processing 1984, Batch 70/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch70.csv
# Processing 1984, Batch 71/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch71.csv
# Processing 1984, Batch 72/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch72.csv
# Processing 1984, Batch 73/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch73.csv
# Processing 1984, Batch 74/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch74.csv
# Processing 1984, Batch 75/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch75.csv
# Processing 1984, Batch 76/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch76.csv
# Processing 1984, Batch 77/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1984_batch77.csv
# Processing 1985, Batch 1/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch1.csv
# Processing 1985, Batch 2/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch2.csv
# Processing 1985, Batch 3/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch3.csv
# Processing 1985, Batch 4/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch4.csv
# Processing 1985, Batch 5/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch5.csv
# Processing 1985, Batch 6/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch6.csv
# Processing 1985, Batch 7/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch7.csv
# Processing 1985, Batch 8/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch8.csv
# Processing 1985, Batch 9/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch9.csv
# Processing 1985, Batch 10/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch10.csv
# Processing 1985, Batch 11/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch11.csv
# Processing 1985, Batch 12/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch12.csv
# Processing 1985, Batch 13/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch13.csv
# Processing 1985, Batch 14/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch14.csv
# Processing 1985, Batch 15/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch15.csv
# Processing 1985, Batch 16/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch16.csv
# Processing 1985, Batch 17/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch17.csv
# Processing 1985, Batch 18/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch18.csv
# Processing 1985, Batch 19/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch19.csv
# Processing 1985, Batch 20/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch20.csv
# Processing 1985, Batch 21/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch21.csv
# Processing 1985, Batch 22/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch22.csv
# Processing 1985, Batch 23/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch23.csv
# Processing 1985, Batch 24/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch24.csv
# Processing 1985, Batch 25/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch25.csv
# Processing 1985, Batch 26/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch26.csv
# Processing 1985, Batch 27/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch27.csv
# Processing 1985, Batch 28/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch28.csv
# Processing 1985, Batch 29/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch29.csv
# Processing 1985, Batch 30/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch30.csv
# Processing 1985, Batch 31/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch31.csv
# Processing 1985, Batch 32/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch32.csv
# Processing 1985, Batch 33/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch33.csv
# Processing 1985, Batch 34/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch34.csv
# Processing 1985, Batch 35/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch35.csv
# Processing 1985, Batch 36/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch36.csv
# Processing 1985, Batch 37/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch37.csv
# Processing 1985, Batch 38/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch38.csv
# Processing 1985, Batch 39/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch39.csv
# Processing 1985, Batch 40/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch40.csv
# Processing 1985, Batch 41/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch41.csv
# Processing 1985, Batch 42/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch42.csv
# Processing 1985, Batch 43/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch43.csv
# Processing 1985, Batch 44/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch44.csv
# Processing 1985, Batch 45/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch45.csv
# Processing 1985, Batch 46/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch46.csv
# Processing 1985, Batch 47/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch47.csv
# Processing 1985, Batch 48/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch48.csv
# Processing 1985, Batch 49/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch49.csv
# Processing 1985, Batch 50/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch50.csv
# Processing 1985, Batch 51/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch51.csv
# Processing 1985, Batch 52/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch52.csv
# Processing 1985, Batch 53/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch53.csv
# Processing 1985, Batch 54/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch54.csv
# Processing 1985, Batch 55/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch55.csv
# Processing 1985, Batch 56/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch56.csv
# Processing 1985, Batch 57/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch57.csv
# Processing 1985, Batch 58/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch58.csv
# Processing 1985, Batch 59/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch59.csv
# Processing 1985, Batch 60/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch60.csv
# Processing 1985, Batch 61/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch61.csv
# Processing 1985, Batch 62/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch62.csv
# Processing 1985, Batch 63/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch63.csv
# Processing 1985, Batch 64/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch64.csv
# Processing 1985, Batch 65/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch65.csv
# Processing 1985, Batch 66/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch66.csv
# Processing 1985, Batch 67/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch67.csv
# Processing 1985, Batch 68/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch68.csv
# Processing 1985, Batch 69/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch69.csv
# Processing 1985, Batch 70/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch70.csv
# Processing 1985, Batch 71/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch71.csv
# Processing 1985, Batch 72/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch72.csv
# Processing 1985, Batch 73/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch73.csv
# Processing 1985, Batch 74/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch74.csv
# Processing 1985, Batch 75/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch75.csv
# Processing 1985, Batch 76/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch76.csv
# Processing 1985, Batch 77/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1985_batch77.csv
# Processing 1986, Batch 1/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch1.csv
# Processing 1986, Batch 2/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch2.csv
# Processing 1986, Batch 3/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch3.csv
# Processing 1986, Batch 4/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch4.csv
# Processing 1986, Batch 5/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch5.csv
# Processing 1986, Batch 6/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch6.csv
# Processing 1986, Batch 7/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch7.csv
# Processing 1986, Batch 8/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch8.csv
# Processing 1986, Batch 9/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch9.csv
# Processing 1986, Batch 10/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch10.csv
# Processing 1986, Batch 11/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch11.csv
# Processing 1986, Batch 12/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch12.csv
# Processing 1986, Batch 13/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch13.csv
# Processing 1986, Batch 14/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch14.csv
# Processing 1986, Batch 15/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch15.csv
# Processing 1986, Batch 16/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch16.csv
# Processing 1986, Batch 17/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch17.csv
# Processing 1986, Batch 18/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch18.csv
# Processing 1986, Batch 19/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch19.csv
# Processing 1986, Batch 20/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch20.csv
# Processing 1986, Batch 21/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch21.csv
# Processing 1986, Batch 22/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch22.csv
# Processing 1986, Batch 23/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch23.csv
# Processing 1986, Batch 24/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch24.csv
# Processing 1986, Batch 25/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch25.csv
# Processing 1986, Batch 26/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch26.csv
# Processing 1986, Batch 27/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch27.csv
# Processing 1986, Batch 28/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch28.csv
# Processing 1986, Batch 29/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch29.csv
# Processing 1986, Batch 30/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch30.csv
# Processing 1986, Batch 31/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch31.csv
# Processing 1986, Batch 32/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch32.csv
# Processing 1986, Batch 33/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch33.csv
# Processing 1986, Batch 34/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch34.csv
# Processing 1986, Batch 35/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch35.csv
# Processing 1986, Batch 36/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch36.csv
# Processing 1986, Batch 37/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch37.csv
# Processing 1986, Batch 38/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch38.csv
# Processing 1986, Batch 39/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch39.csv
# Processing 1986, Batch 40/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch40.csv
# Processing 1986, Batch 41/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch41.csv
# Processing 1986, Batch 42/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch42.csv
# Processing 1986, Batch 43/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch43.csv
# Processing 1986, Batch 44/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch44.csv
# Processing 1986, Batch 45/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch45.csv
# Processing 1986, Batch 46/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch46.csv
# Processing 1986, Batch 47/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch47.csv
# Processing 1986, Batch 48/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch48.csv
# Processing 1986, Batch 49/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch49.csv
# Processing 1986, Batch 50/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch50.csv
# Processing 1986, Batch 51/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch51.csv
# Processing 1986, Batch 52/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch52.csv
# Processing 1986, Batch 53/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch53.csv
# Processing 1986, Batch 54/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch54.csv
# Processing 1986, Batch 55/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch55.csv
# Processing 1986, Batch 56/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch56.csv
# Processing 1986, Batch 57/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch57.csv
# Processing 1986, Batch 58/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch58.csv
# Processing 1986, Batch 59/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch59.csv
# Processing 1986, Batch 60/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch60.csv
# Processing 1986, Batch 61/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch61.csv
# Processing 1986, Batch 62/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch62.csv
# Processing 1986, Batch 63/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch63.csv
# Processing 1986, Batch 64/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch64.csv
# Processing 1986, Batch 65/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch65.csv
# Processing 1986, Batch 66/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch66.csv
# Processing 1986, Batch 67/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch67.csv
# Processing 1986, Batch 68/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch68.csv
# Processing 1986, Batch 69/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch69.csv
# Processing 1986, Batch 70/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch70.csv
# Processing 1986, Batch 71/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch71.csv
# Processing 1986, Batch 72/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch72.csv
# Processing 1986, Batch 73/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch73.csv
# Processing 1986, Batch 74/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch74.csv
# Processing 1986, Batch 75/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch75.csv
# Processing 1986, Batch 76/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch76.csv
# Processing 1986, Batch 77/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1986_batch77.csv
# Processing 1987, Batch 1/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch1.csv
# Processing 1987, Batch 2/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch2.csv
# Processing 1987, Batch 3/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch3.csv
# Processing 1987, Batch 4/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch4.csv
# Processing 1987, Batch 5/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch5.csv
# Processing 1987, Batch 6/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch6.csv
# Processing 1987, Batch 7/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch7.csv
# Processing 1987, Batch 8/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch8.csv
# Processing 1987, Batch 9/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch9.csv
# Processing 1987, Batch 10/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch10.csv
# Processing 1987, Batch 11/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch11.csv
# Processing 1987, Batch 12/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch12.csv
# Processing 1987, Batch 13/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch13.csv
# Processing 1987, Batch 14/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch14.csv
# Processing 1987, Batch 15/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch15.csv
# Processing 1987, Batch 16/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch16.csv
# Processing 1987, Batch 17/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch17.csv
# Processing 1987, Batch 18/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch18.csv
# Processing 1987, Batch 19/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch19.csv
# Processing 1987, Batch 20/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch20.csv
# Processing 1987, Batch 21/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch21.csv
# Processing 1987, Batch 22/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch22.csv
# Processing 1987, Batch 23/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch23.csv
# Processing 1987, Batch 24/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch24.csv
# Processing 1987, Batch 25/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch25.csv
# Processing 1987, Batch 26/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch26.csv
# Processing 1987, Batch 27/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch27.csv
# Processing 1987, Batch 28/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch28.csv
# Processing 1987, Batch 29/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch29.csv
# Processing 1987, Batch 30/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch30.csv
# Processing 1987, Batch 31/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch31.csv
# Processing 1987, Batch 32/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch32.csv
# Processing 1987, Batch 33/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch33.csv
# Processing 1987, Batch 34/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch34.csv
# Processing 1987, Batch 35/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch35.csv
# Processing 1987, Batch 36/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch36.csv
# Processing 1987, Batch 37/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch37.csv
# Processing 1987, Batch 38/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch38.csv
# Processing 1987, Batch 39/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch39.csv
# Processing 1987, Batch 40/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch40.csv
# Processing 1987, Batch 41/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch41.csv
# Processing 1987, Batch 42/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch42.csv
# Processing 1987, Batch 43/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch43.csv
# Processing 1987, Batch 44/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch44.csv
# Processing 1987, Batch 45/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch45.csv
# Processing 1987, Batch 46/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch46.csv
# Processing 1987, Batch 47/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch47.csv
# Processing 1987, Batch 48/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch48.csv
# Processing 1987, Batch 49/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch49.csv
# Processing 1987, Batch 50/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch50.csv
# Processing 1987, Batch 51/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch51.csv
# Processing 1987, Batch 52/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch52.csv
# Processing 1987, Batch 53/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch53.csv
# Processing 1987, Batch 54/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch54.csv
# Processing 1987, Batch 55/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch55.csv
# Processing 1987, Batch 56/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch56.csv
# Processing 1987, Batch 57/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch57.csv
# Processing 1987, Batch 58/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch58.csv
# Processing 1987, Batch 59/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch59.csv
# Processing 1987, Batch 60/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch60.csv
# Processing 1987, Batch 61/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch61.csv
# Processing 1987, Batch 62/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch62.csv
# Processing 1987, Batch 63/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch63.csv
# Processing 1987, Batch 64/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch64.csv
# Processing 1987, Batch 65/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch65.csv
# Processing 1987, Batch 66/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch66.csv
# Processing 1987, Batch 67/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch67.csv
# Processing 1987, Batch 68/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch68.csv
# Processing 1987, Batch 69/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch69.csv
# Processing 1987, Batch 70/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch70.csv
# Processing 1987, Batch 71/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch71.csv
# Processing 1987, Batch 72/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch72.csv
# Processing 1987, Batch 73/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch73.csv
# Processing 1987, Batch 74/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch74.csv
# Processing 1987, Batch 75/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch75.csv
# Processing 1987, Batch 76/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch76.csv
# Processing 1987, Batch 77/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1987_batch77.csv
# Processing 1988, Batch 1/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch1.csv
# Processing 1988, Batch 2/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch2.csv
# Processing 1988, Batch 3/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch3.csv
# Processing 1988, Batch 4/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch4.csv
# Processing 1988, Batch 5/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch5.csv
# Processing 1988, Batch 6/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch6.csv
# Processing 1988, Batch 7/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch7.csv
# Processing 1988, Batch 8/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch8.csv
# Processing 1988, Batch 9/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch9.csv
# Processing 1988, Batch 10/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch10.csv
# Processing 1988, Batch 11/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch11.csv
# Processing 1988, Batch 12/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch12.csv
# Processing 1988, Batch 13/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch13.csv
# Processing 1988, Batch 14/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch14.csv
# Processing 1988, Batch 15/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch15.csv
# Processing 1988, Batch 16/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch16.csv
# Processing 1988, Batch 17/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch17.csv
# Processing 1988, Batch 18/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch18.csv
# Processing 1988, Batch 19/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch19.csv
# Processing 1988, Batch 20/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch20.csv
# Processing 1988, Batch 21/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch21.csv
# Processing 1988, Batch 22/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch22.csv
# Processing 1988, Batch 23/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch23.csv
# Processing 1988, Batch 24/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch24.csv
# Processing 1988, Batch 25/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch25.csv
# Processing 1988, Batch 26/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch26.csv
# Processing 1988, Batch 27/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch27.csv
# Processing 1988, Batch 28/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch28.csv
# Processing 1988, Batch 29/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch29.csv
# Processing 1988, Batch 30/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch30.csv
# Processing 1988, Batch 31/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch31.csv
# Processing 1988, Batch 32/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch32.csv
# Processing 1988, Batch 33/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch33.csv
# Processing 1988, Batch 34/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch34.csv
# Processing 1988, Batch 35/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch35.csv
# Processing 1988, Batch 36/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch36.csv
# Processing 1988, Batch 37/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch37.csv
# Processing 1988, Batch 38/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch38.csv
# Processing 1988, Batch 39/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch39.csv
# Processing 1988, Batch 40/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch40.csv
# Processing 1988, Batch 41/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch41.csv
# Processing 1988, Batch 42/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch42.csv
# Processing 1988, Batch 43/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch43.csv
# Processing 1988, Batch 44/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch44.csv
# Processing 1988, Batch 45/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch45.csv
# Processing 1988, Batch 46/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch46.csv
# Processing 1988, Batch 47/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch47.csv
# Processing 1988, Batch 48/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch48.csv
# Processing 1988, Batch 49/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch49.csv
# Processing 1988, Batch 50/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch50.csv
# Processing 1988, Batch 51/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch51.csv
# Processing 1988, Batch 52/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch52.csv
# Processing 1988, Batch 53/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch53.csv
# Processing 1988, Batch 54/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch54.csv
# Processing 1988, Batch 55/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch55.csv
# Processing 1988, Batch 56/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch56.csv
# Processing 1988, Batch 57/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch57.csv
# Processing 1988, Batch 58/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch58.csv
# Processing 1988, Batch 59/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch59.csv
# Processing 1988, Batch 60/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch60.csv
# Processing 1988, Batch 61/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch61.csv
# Processing 1988, Batch 62/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch62.csv
# Processing 1988, Batch 63/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch63.csv
# Processing 1988, Batch 64/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch64.csv
# Processing 1988, Batch 65/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch65.csv
# Processing 1988, Batch 66/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch66.csv
# Processing 1988, Batch 67/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch67.csv
# Processing 1988, Batch 68/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch68.csv
# Processing 1988, Batch 69/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch69.csv
# Processing 1988, Batch 70/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch70.csv
# Processing 1988, Batch 71/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch71.csv
# Processing 1988, Batch 72/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch72.csv
# Processing 1988, Batch 73/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch73.csv
# Processing 1988, Batch 74/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch74.csv
# Processing 1988, Batch 75/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch75.csv
# Processing 1988, Batch 76/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch76.csv
# Processing 1988, Batch 77/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1988_batch77.csv
# Processing 1989, Batch 1/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch1.csv
# Processing 1989, Batch 2/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch2.csv
# Processing 1989, Batch 3/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch3.csv
# Processing 1989, Batch 4/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch4.csv
# Processing 1989, Batch 5/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch5.csv
# Processing 1989, Batch 6/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch6.csv
# Processing 1989, Batch 7/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch7.csv
# Processing 1989, Batch 8/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch8.csv
# Processing 1989, Batch 9/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch9.csv
# Processing 1989, Batch 10/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch10.csv
# Processing 1989, Batch 11/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch11.csv
# Processing 1989, Batch 12/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch12.csv
# Processing 1989, Batch 13/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch13.csv
# Processing 1989, Batch 14/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch14.csv
# Processing 1989, Batch 15/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch15.csv
# Processing 1989, Batch 16/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch16.csv
# Processing 1989, Batch 17/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch17.csv
# Processing 1989, Batch 18/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch18.csv
# Processing 1989, Batch 19/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch19.csv
# Processing 1989, Batch 20/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch20.csv
# Processing 1989, Batch 21/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch21.csv
# Processing 1989, Batch 22/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch22.csv
# Processing 1989, Batch 23/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_1989_batch23.csv
# Processing 1989, Batch 24/77...
# ...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch17.csv
# Processing 2018, Batch 18/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch18.csv
# Processing 2018, Batch 19/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch19.csv
# Processing 2018, Batch 20/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch20.csv
# Processing 2018, Batch 21/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch21.csv
# Processing 2018, Batch 22/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch22.csv
# Processing 2018, Batch 23/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch23.csv
# Processing 2018, Batch 24/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch24.csv
# Processing 2018, Batch 25/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch25.csv
# Processing 2018, Batch 26/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch26.csv
# Processing 2018, Batch 27/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch27.csv
# Processing 2018, Batch 28/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch28.csv
# Processing 2018, Batch 29/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch29.csv
# Processing 2018, Batch 30/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch30.csv
# Processing 2018, Batch 31/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch31.csv
# Processing 2018, Batch 32/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch32.csv
# Processing 2018, Batch 33/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch33.csv
# Processing 2018, Batch 34/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch34.csv
# Processing 2018, Batch 35/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch35.csv
# Processing 2018, Batch 36/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch36.csv
# Processing 2018, Batch 37/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch37.csv
# Processing 2018, Batch 38/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch38.csv
# Processing 2018, Batch 39/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch39.csv
# Processing 2018, Batch 40/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch40.csv
# Processing 2018, Batch 41/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch41.csv
# Processing 2018, Batch 42/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch42.csv
# Processing 2018, Batch 43/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch43.csv
# Processing 2018, Batch 44/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch44.csv
# Processing 2018, Batch 45/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch45.csv
# Processing 2018, Batch 46/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch46.csv
# Processing 2018, Batch 47/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch47.csv
# Processing 2018, Batch 48/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch48.csv
# Processing 2018, Batch 49/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch49.csv
# Processing 2018, Batch 50/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch50.csv
# Processing 2018, Batch 51/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch51.csv
# Processing 2018, Batch 52/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch52.csv
# Processing 2018, Batch 53/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch53.csv
# Processing 2018, Batch 54/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch54.csv
# Processing 2018, Batch 55/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch55.csv
# Processing 2018, Batch 56/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch56.csv
# Processing 2018, Batch 57/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch57.csv
# Processing 2018, Batch 58/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch58.csv
# Processing 2018, Batch 59/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch59.csv
# Processing 2018, Batch 60/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch60.csv
# Processing 2018, Batch 61/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch61.csv
# Processing 2018, Batch 62/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch62.csv
# Processing 2018, Batch 63/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch63.csv
# Processing 2018, Batch 64/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch64.csv
# Processing 2018, Batch 65/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch65.csv
# Processing 2018, Batch 66/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch66.csv
# Processing 2018, Batch 67/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch67.csv
# Processing 2018, Batch 68/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch68.csv
# Processing 2018, Batch 69/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch69.csv
# Processing 2018, Batch 70/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch70.csv
# Processing 2018, Batch 71/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch71.csv
# Processing 2018, Batch 72/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch72.csv
# Processing 2018, Batch 73/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch73.csv
# Processing 2018, Batch 74/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch74.csv
# Processing 2018, Batch 75/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch75.csv
# Processing 2018, Batch 76/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch76.csv
# Processing 2018, Batch 77/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2018_batch77.csv
# Processing 2019, Batch 1/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch1.csv
# Processing 2019, Batch 2/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch2.csv
# Processing 2019, Batch 3/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch3.csv
# Processing 2019, Batch 4/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch4.csv
# Processing 2019, Batch 5/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch5.csv
# Processing 2019, Batch 6/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch6.csv
# Processing 2019, Batch 7/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch7.csv
# Processing 2019, Batch 8/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch8.csv
# Processing 2019, Batch 9/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch9.csv
# Processing 2019, Batch 10/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch10.csv
# Processing 2019, Batch 11/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch11.csv
# Processing 2019, Batch 12/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch12.csv
# Processing 2019, Batch 13/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch13.csv
# Processing 2019, Batch 14/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch14.csv
# Processing 2019, Batch 15/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch15.csv
# Processing 2019, Batch 16/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch16.csv
# Processing 2019, Batch 17/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch17.csv
# Processing 2019, Batch 18/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch18.csv
# Processing 2019, Batch 19/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch19.csv
# Processing 2019, Batch 20/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch20.csv
# Processing 2019, Batch 21/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch21.csv
# Processing 2019, Batch 22/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch22.csv
# Processing 2019, Batch 23/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch23.csv
# Processing 2019, Batch 24/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch24.csv
# Processing 2019, Batch 25/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch25.csv
# Processing 2019, Batch 26/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch26.csv
# Processing 2019, Batch 27/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch27.csv
# Processing 2019, Batch 28/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch28.csv
# Processing 2019, Batch 29/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch29.csv
# Processing 2019, Batch 30/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch30.csv
# Processing 2019, Batch 31/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch31.csv
# Processing 2019, Batch 32/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch32.csv
# Processing 2019, Batch 33/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch33.csv
# Processing 2019, Batch 34/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch34.csv
# Processing 2019, Batch 35/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch35.csv
# Processing 2019, Batch 36/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch36.csv
# Processing 2019, Batch 37/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch37.csv
# Processing 2019, Batch 38/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch38.csv
# Processing 2019, Batch 39/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch39.csv
# Processing 2019, Batch 40/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch40.csv
# Processing 2019, Batch 41/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch41.csv
# Processing 2019, Batch 42/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch42.csv
# Processing 2019, Batch 43/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch43.csv
# Processing 2019, Batch 44/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch44.csv
# Processing 2019, Batch 45/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch45.csv
# Processing 2019, Batch 46/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch46.csv
# Processing 2019, Batch 47/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch47.csv
# Processing 2019, Batch 48/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch48.csv
# Processing 2019, Batch 49/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch49.csv
# Processing 2019, Batch 50/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch50.csv
# Processing 2019, Batch 51/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch51.csv
# Processing 2019, Batch 52/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch52.csv
# Processing 2019, Batch 53/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch53.csv
# Processing 2019, Batch 54/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch54.csv
# Processing 2019, Batch 55/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch55.csv
# Processing 2019, Batch 56/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch56.csv
# Processing 2019, Batch 57/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch57.csv
# Processing 2019, Batch 58/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch58.csv
# Processing 2019, Batch 59/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch59.csv
# Processing 2019, Batch 60/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch60.csv
# Processing 2019, Batch 61/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch61.csv
# Processing 2019, Batch 62/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch62.csv
# Processing 2019, Batch 63/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch63.csv
# Processing 2019, Batch 64/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch64.csv
# Processing 2019, Batch 65/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch65.csv
# Processing 2019, Batch 66/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch66.csv
# Processing 2019, Batch 67/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch67.csv
# Processing 2019, Batch 68/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch68.csv
# Processing 2019, Batch 69/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch69.csv
# Processing 2019, Batch 70/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch70.csv
# Processing 2019, Batch 71/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch71.csv
# Processing 2019, Batch 72/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch72.csv
# Processing 2019, Batch 73/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch73.csv
# Processing 2019, Batch 74/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch74.csv
# Processing 2019, Batch 75/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch75.csv
# Processing 2019, Batch 76/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch76.csv
# Processing 2019, Batch 77/77...
# Saved C:\Users\arj26323/Documents/Xin data/Virginia\VAlandsatflats_2019_batch77.csv
# All batches processed!

# %%
#PROPORTION OF TIME FLOODED
#Inundation intensity
#Rajneesh

# import glob

# path = r'C:/Users/arj26323/Documents/Xin data/Landsat' 
# all_files = glob.glob(path + "/landsatflats_1984_*")

# li = []

# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     li.append(df)

# df = pd.concat(li, axis=0, ignore_index=True)

# df

# upd = df[['Latitude', 'Longitude']].drop_duplicates().reset_index()
# upd

# Map.add_points_from_xy(upd, x="Longitude", y="Latitude")
# Map.addLayer(ultra_col.first(),{},'flats')
# Map.addLayer(fc_all,{},'points')
# Map
# fc_all
# Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      index   Latitude  Longitude
# 0        0  31.538627 -81.422539
# 1       19  31.536199 -81.296118
# 2       21  31.436090 -81.339919
# 3       61  31.518920 -81.228956
# 4       73  31.451676 -81.365498
# ..     ...        ...        ...
# 203  49966  31.435830 -81.341134
# 204  49985  31.387957 -81.280219
# 205  49996  31.387957 -81.280220
# 206  50061  31.351060 -81.333347
# 207  50080  31.476954 -81.271005
#
# [208 rows x 3 columns]

# %%
import glob

# path = r'C:/Users/arj26323/Documents/Xin data/Landsat' 
# all_files = glob.glob(path + "/*.csv")

# li = []

# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     li.append(df)

# df = pd.concat(li, axis=0, ignore_index=True)

# df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                Date   Latitude  Longitude  Plant_Biomass  Plot  Sample_Size  \
# 0        10/11/2000  31.538627 -81.422539        516.324     1           23
# 1        10/17/2001  31.538627 -81.422539        424.416     1           18
# 2        10/16/2002  31.538627 -81.422539        259.784     1           16
# 3        10/25/2004  31.538627 -81.422539        436.332     1           18
# 4        10/24/2005  31.538627 -81.422539        649.300     1           25
# ...             ...        ...        ...            ...   ...          ...
# 3983823  10/26/2011  31.477098 -81.270523        286.096     2           11
# 3983824  10/14/2012  31.477098 -81.270523        371.072     2           12
# 3983825  10/13/2013  31.477098 -81.270523        475.344     2           14
# 3983826  10/18/2014  31.477098 -81.270523        446.432     2           17
# 3983827  10/24/2015  31.477098 -81.270523        608.608     2           18
#
#          Site Species_Code  Year  Zone        date     flats
# 0           1           A1  2000     1  1984-04-12  0.003720
# 1           1           A1  2001     1  1984-04-12  0.003720
# 2           1           A1  2002     1  1984-04-12  0.003720
# 3           1           A1  2004     1  1984-04-12  0.003720
# 4           1           A1  2005     1  1984-04-12  0.003720
# ...       ...          ...   ...   ...         ...       ...
# 3983823    10           A1  2011     2  2024-12-21  0.004613
# 3983824    10           A1  2012     2  2024-12-21  0.004613
# 3983825    10           A1  2013     2  2024-12-21  0.004613
# 3983826    10           A1  2014     2  2024-12-21  0.004613
# 3983827    10           A1  2015     2  2024-12-21  0.004613
#
# [3983828 rows x 12 columns]

# %%
# Group by unique latitude/longitude pairs
grouped = df.groupby(['Latitude', 'Longitude'])

# Select one unique location (e.g., first location in the grouped data)
(lat, lon), location_df = next(iter(grouped))

# Sort by date to ensure proper time series order
location_df = location_df.sort_values('date')

# Plot the time series of 'flats' for this location
plt.figure(figsize=(10, 5))
plt.plot(location_df['date'], location_df['flats'], marker='o', linestyle='')

plt.xlabel("Date")
plt.ylabel("Flats")
plt.title(f"Time Series for Location: ({lat}, {lon})")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
location_df['date']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      Latitude  Longitude
# 6   31.352109 -81.333734
# 84  31.352050 -81.333824

# %%
# Get unique latitude/longitude pairs
unique_locations = df[['Latitude', 'Longitude']].drop_duplicates().reset_index(drop=True)

# Display indexed locations
# print("Available Locations:")
# for i, (lat, lon) in unique_locations.iterrows():
#     print(f"{i}: ({lat}, {lon})")

# Ask user to select a location by index
# selection = int(input("Enter the index of the location you want to plot: "))

# Extract selected location
# lat, lon = unique_locations.iloc[selection]
lat, lon = (31.30776, -81.415721)

# Filter dataframe for the selected location
location_df = df[(df['Latitude'] == lat) & (df['Longitude'] == lon)].sort_values('date')

location_df['date'] = pd.to_datetime(location_df['date'])

# Plot time series for selected location
plt.figure(figsize=(10, 5))
plt.plot(location_df['date'], location_df['flats'], marker='o', linestyle='')

plt.xlabel("Date")
plt.ylabel("Flats")

plt.xticks(rotation=0) # Rotate the x-axis labels by 45 degrees

# fig, ax = plt.subplots()
# fig.autofmt_xdate()

plt.title(f"Time Series for Location: ({lat}, {lon})")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#df.groupby(['Latitude','Longitude']).size()

df_flooding = df.groupby(['Latitude', 'Longitude']).apply(
    lambda g: (g['flats'] >= 0.2).mean()).reset_index(name='Percent_flooding'
                                                     )
df_flooding
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       Latitude  Longitude  Percent_flooding
# 0    31.307529 -81.415324          0.039201
# 1    31.307562 -81.415389          0.039201
# 2    31.307641 -81.415468          0.039201
# 3    31.307693 -81.415592          0.721236
# 4    31.307760 -81.415721          0.721236
# ..         ...        ...               ...
# 176  31.539429 -81.422410          0.009724
# 177  31.539457 -81.422250          0.006415
# 178  31.539480 -81.422098          0.006415
# 179  31.539491 -81.421750          0.004831
# 180  31.539505 -81.421937          0.004831
#
# [181 rows x 3 columns]

# %%
# xxx= ee.Image((ultra_col.toList(ultra_col.size())).get(0))

# Map.addLayer(xxx, {}, 'xxx')
# Map


# import os

# out_dir = os.path.expanduser('~/Downloads')
# out_csv = os.path.join(out_dir, 'flood_freq.csv')

# df_flooding.to_csv(out_csv)

dfx = df[df['Date'] == 20151023]

dfy =dfx[dfx['Latitude'] == 31.335017]

dfy
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#           Biomass      Date  Flwrn_S   Latitude  Longitude Spcs_Cd  \
# 0        2506.982  20151023      NaN  31.335017 -81.478711      A4
# 100      2506.982  20151023      NaN  31.335017 -81.478711      A4
# 200      2506.982  20151023      NaN  31.335017 -81.478711      A4
# 300      2506.982  20151023      NaN  31.335017 -81.478711      A4
# 400      2506.982  20151023      NaN  31.335017 -81.478711      A4
# ...           ...       ...      ...        ...        ...     ...
# 1855582  2506.982  20151023      NaN  31.335017 -81.478711      A4
# 1855632  2506.982  20151023      NaN  31.335017 -81.478711      A4
# 1855682  2506.982  20151023      NaN  31.335017 -81.478711      A4
# 1855732  2506.982  20151023      NaN  31.335017 -81.478711      A4
# 1855782  2506.982  20151023      NaN  31.335017 -81.478711      A4
#
#                date     flats
# 0        1984-05-14  0.001437
# 100      1984-06-15  0.000173
# 200      1984-08-18  0.000316
# 300      1984-09-03  0.000237
# 400      1984-10-21  0.000929
# ...             ...       ...
# 1855582  2024-05-11  0.000631
# 1855632  2024-07-30  0.000433
# 1855682  2024-08-31  0.000151
# 1855732  2024-10-18  0.000642
# 1855782  2024-12-21  0.007868
#
# [1191 rows x 8 columns]

# %%
grouped = fc_test.groupby(['Latitude', 'Longitude']).count()
grouped
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                       Plot  Zone  Site  Year  Plant_Biomass  Sample_Size  \
# Latitude  Longitude
# 31.307529 -81.415324    20    20    20    20             20           20
# 31.307562 -81.415389    19    19    19    19             19           19
# 31.307641 -81.415468    19    19    19    19             19           19
# 31.307682 -81.415608    14    14    14    14             14           14
# 31.307693 -81.415592     5     5     5     5              5            5
# ...                    ...   ...   ...   ...            ...          ...
# 31.539429 -81.422410    19    19    19    19             19           19
# 31.539457 -81.422250    19    19    19    19             19           19
# 31.539480 -81.422098    19    19    19    19             19           19
# 31.539491 -81.421750    19    19    19    19             19           19
# 31.539505 -81.421937    19    19    19    19             19           19
#
#                       Species_Code  Date
# Latitude  Longitude
# 31.307529 -81.415324            20    20
# 31.307562 -81.415389            19    19
# 31.307641 -81.415468            19    19
# 31.307682 -81.415608            14    14
# 31.307693 -81.415592             5     5
# ...                            ...   ...
# 31.539429 -81.422410            19    19
# 31.539457 -81.422250            19    19
# 31.539480 -81.422098            19    19
# 31.539491 -81.421750            19    19
# 31.539505 -81.421937            19    19
#
# [208 rows x 8 columns]
