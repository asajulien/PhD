# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_csv('C:/Users/arj26323/Documents/Data/Restoration_trends/fixed_restoration_window_trends_3.csv') ##3x3 window

df = df0.iloc[:, [3,4,5] + list(range(6,47))].dropna() ##FOR ORIGINALS

df
# Out:
#                                          Site name  Installation_year  \
# 0                            Plantation Creek Site               2010
# 1                             Florida Passage Site               2012
# 2                                     Oatland Site               2014
# 4             Estuaries Area of the Altamaha River               2009
# 5                     Jekyll Island Boat Ramp Site               2009
# 7                              Oyster Creek Site B               2013
# 9                      Jointer Creek Oyster Reef A               2012
# 10                     Jointer Creek Oyster Reef B               2012
# 11                     Jointer Creek Oyster Reef C               2012
# 12                     Jointer Creek Oyster Reef D               2012
# 13                                        Turtle A               2014
# 14                                        Turtle B               2014
# 15                                        Turtle C               2014
# 16                                        Turtle D               2014
# 17                                        Turtle E               2014
# 18                        Bellville Boat Ramp Site               2008
# 20                       Ashantilly, Sapelo Island               2010
# 21                       Long Tabby, Sapelo Island               2010
# 22       Mosquito Creek, Little St. Simon's Island               2013
# 23     Cannon's Point Preserve, St. Simon's Island               2015
# 24     Skidaway Island State Park, Skidaway Island               2015
# 25                        Burton 4-H, Tybee Island               2015
# 26     Beach Road Bridge, Little St. Simons Island               2017
# 27                        Little Cumberland Island               2020
# 28                     Fortson Pond, Jekyll Island               2021
# 29  DNR's Coastal Regional Headquarters, Brunswick               2023
# 30                                      Jekyll TLP               2019
#
#                     type                          geometry  biomass_1984  \
# 0            Oyster Reef      POINT (-81.477183 31.122967)    415.569183
# 1            Oyster Reef     POINT (-81.15333333 31.83865)    546.787598
# 2            Oyster Reef  POINT (-81.01923333 32.04801667)    454.848907
# 4            Oyster Reef     POINT (-81.32228333 31.32615)    432.954224
# 5            Oyster Reef     POINT (-81.42301667 31.04165)    426.000030
# 7            Oyster Reef  POINT (-80.91488333 32.00441667)    239.060226
# 9            Oyster Reef      POINT (-81.50021667 31.0808)    280.419067
# 10           Oyster Reef      POINT (-81.49396667 31.0796)    289.923523
# 11           Oyster Reef  POINT (-81.49078333 31.08058333)    324.102203
# 12           Oyster Reef         POINT (-81.47005 31.0704)    389.009094
# 13           Oyster Reef  POINT (-81.47906667 31.12626667)    673.846741
# 14           Oyster Reef      POINT (-81.53143333 31.1941)    327.873016
# 15           Oyster Reef     POINT (-81.53795 31.19638333)    619.667481
# 16           Oyster Reef  POINT (-81.53013333 31.18371667)    420.449310
# 17           Oyster Reef  POINT (-81.46218333 31.13126667)    354.036194
# 18           Oyster Reef  POINT (-81.35853333 31.53118333)    832.575562
# 20      Living Shoreline    POINT (-81.2811768 31.4343441)    725.934387
# 21      Living Shoreline    POINT (-81.2826582 31.4319577)    869.103272
# 22      Living Shoreline    POINT (-81.3018728 31.2600958)    589.755554
# 23      Living Shoreline    POINT (-81.3400528 31.2602929)    938.501465
# 24      Living Shoreline     POINT (-81.055935 31.9516058)    722.534790
# 25      Living Shoreline     POINT (-80.8518889 32.007583)    512.275696
# 26      Living Shoreline    POINT (-81.2934479 31.2495847)    561.316894
# 27      Living Shoreline    POINT (-81.4210473 30.9502178)    896.741882
# 28      Living Shoreline    POINT (-81.4145619 31.0534927)    986.878967
# 29      Living Shoreline    POINT (-81.4773196 31.1235759)    399.133545
# 30  Thin Layer Placement    POINT (-81.4335094 31.0877631)    245.474884
#
#     biomass_1985  biomass_1986  biomass_1987  biomass_1988  biomass_1989  ...  \
# 0     596.696716    424.160248    444.760101    454.666901    633.744324  ...
# 1     628.008118    713.233459    566.339539    714.556763    735.787537  ...
# 2     431.684174    551.176636    462.359711    528.941162    523.316772  ...
# 4     432.954224    346.108185    367.529571    435.826538    432.954224  ...
# 5     584.057495    406.831421    387.468353    468.236969    562.722290  ...
# 7     372.658814    358.286591    291.562958    369.751556    366.183044  ...
# 9     399.076416    300.492676    347.091125    369.082184    375.255920  ...
# 10    397.946197    302.668671    360.008637    337.579590    381.647827  ...
# 11    431.120758    335.510895    355.180176    337.854858    380.114990  ...
# 12    544.705017    405.797211    418.006592    403.280395    508.578888  ...
# 13    974.247375    729.606628    701.898438    736.581299    883.016113  ...
# 14    428.230347    348.279419    396.591858    467.893280    453.417877  ...
# 15    939.707031    564.506165    638.696716    780.221375    812.389648  ...
# 16    524.113342    411.366669    472.512054    525.667908    555.373169  ...
# 17    451.991547    328.853729    373.322693    320.478180    445.854401  ...
# 18   1029.989502    823.914673    810.875244   1027.419189   1022.601196  ...
# 20    695.160400    805.097168    730.561523    738.896118    865.767456  ...
# 21    784.144714    680.016968   1002.779785    842.643250    980.532715  ...
# 22    705.826965    510.175995    607.865662    661.074768    716.204468  ...
# 23    983.160156    795.183044    841.881775    993.405884   1077.825562  ...
# 24    707.014587    934.858826    718.645874    920.998169    929.078735  ...
# 25    566.087402    693.563110    522.491333    692.007935    776.721069  ...
# 26    848.273315    574.211548    601.928650    632.907166    946.942139  ...
# 27   1053.376709    883.325317    872.865356    890.562500   1062.445801  ...
# 28   1053.104370    971.976379    998.429993   1126.533569   1086.337280  ...
# 29    578.778565    407.504211    437.650574    441.216248    605.445496  ...
# 30    395.184815    256.055542    312.617126    295.381775    388.574097  ...
#
#     biomass_2014  biomass_2015  biomass_2016  biomass_2017  biomass_2018  \
# 0     468.044190    664.676269    467.191315    615.905273    478.254791
# 1     392.914490    673.458801    477.707764    490.022613    480.411011
# 2     409.996338    560.010925    399.928101    434.612732    431.465637
# 4    1785.122437   1951.631470   1691.542358   1945.601929   1816.893677
# 5     403.886597    589.351074    412.766602    562.577576    411.958008
# 7     251.925461    379.952362    205.888474    232.572906    215.731125
# 9     246.608215    368.636231    251.039337    361.807617    229.932373
# 10    274.967621    381.692657    266.043488    378.523407    241.847824
# 11    262.336914    375.519836    249.687531    361.999756    234.102936
# 12    369.914581    668.582764    369.886169    505.491394    675.972778
# 13    717.710388   1119.431152    761.646179    872.395019    800.138000
# 14    329.033875    472.753845    300.441559    422.936493    313.756042
# 15    507.736786    809.971497    500.277344    790.875916    519.512817
# 16    334.611969    565.732422    359.775604    400.561066    912.296204
# 17    301.034180    525.222839    280.393707    302.622986    281.318665
# 18    779.644165    775.549622    766.673462   1013.814941    778.083557
# 20    516.998169    841.799011    442.513336    439.480988    437.720612
# 21    761.466065    966.029480    570.443848   1159.304199    661.316834
# 22    604.123535    780.585510    597.300171    487.294708    600.094482
# 23    950.361816   1039.586182    928.047546    931.910217    966.073731
# 24    680.769592    941.972595    695.792786    598.664246    619.575806
# 25    597.255249    873.314270    537.537170    516.680115    516.220947
# 26    746.999573    965.995422    581.893494    624.188538    681.158752
# 27    881.967651   1044.132690    865.995972   1020.771362    865.713440
# 28   1058.848022   1126.922119   1066.402466   1086.390259    974.697082
# 29    806.282104    947.455688    760.211609    791.208008    631.176880
# 30    222.532715    369.797211    226.536346    372.142975    233.620468
#
#     biomass_2019  biomass_2020  biomass_2021  biomass_2022  biomass_2023
# 0     434.525177    714.136902    823.788635    479.731964    464.357910
# 1     418.332519    560.940308    493.276245    459.225952    502.592590
# 2     378.262756    505.979706    516.557861    391.161011    401.994263
# 4    1365.065308   1973.961060   1929.251587   1754.852905   1458.545532
# 5     411.658356    465.735260    575.580261    408.291718    419.075836
# 7     246.284225    249.831177    214.575150    207.701630    215.857468
# 9     265.036041    363.710510    365.909576    254.114487    320.252197
# 10    267.323761    389.814179    370.218231    254.134232    271.862732
# 11    269.492859    398.049225    368.151306    257.852875    271.058777
# 12    384.359161    470.159119    603.878601    355.689270    916.806274
# 13    691.642395   1124.234375   1071.091309    780.271668    832.802063
# 14    286.695892    543.611084    468.616272    464.666687    351.859039
# 15    620.624756    946.911804    734.345398    503.080322    615.188171
# 16    328.488251    654.536377    495.078980    365.702393    403.559815
# 17    288.022675    511.678162    448.159882    320.579773    342.254150
# 18    753.842896   1094.224976   1083.768555    818.363281    831.408081
# 20    426.317352    518.563416    454.475830    425.100617    571.178284
# 21    669.801758    927.404968    565.239319   1333.237549   1198.355103
# 22    531.215332    785.536865    730.699036    628.918091    593.870056
# 23    969.026489   1108.160034   1101.747681    972.595581    974.015137
# 24    574.401978    698.878784    660.033142    697.426941    709.111206
# 25    522.401245    570.532104    544.994629    571.632385    524.108765
# 26    663.015564    971.219055    977.167114    696.566650    721.923462
# 27    879.585022    868.380554   1038.432861    864.384216    854.794678
# 28    957.501526   1091.748291   1083.312134   1064.949463    985.661926
# 29    629.930176    830.889587   1100.889404    717.473511    689.125305
# 30    249.775742    367.070190    365.679565    248.875458    261.082672
#
# [27 rows x 44 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

##With LS site updates, you need this:
df['Site'] = df['Site name']
df['Install_year'] = df['Installation_year'] ##manually changed from 'year' in output

df = df.drop(columns=['Site name', 'Installation_year', 'geometry'])

# 1. Melt the DataFrame
# Assumes 'site' is the column that identifies your locations
df_long = pd.melt(
    df, 
    id_vars=['Site', 'Install_year', 'type'], 
    var_name='year', 
    value_name='biomass'
)

# 2. Clean the 'year' column
# Remove 'biomass_' prefix and convert to numeric
df_long['year'] = df_long['year'].str.replace('biomass_', '').astype(int)

# %%
'''##SYNTHETIC CONTROLS
df0 = pd.read_csv('C:/Users/arj26323/Documents/Data/GA_conservation/synthetic_contols/synthetic_controls_3.csv') ##3x3 window
##NOTE THE DIFFERENT FILE PATH ON SYNTHETIC CONTROLS VS. ORIGINALS

df = df0.iloc[:, [1,2,3,4,5] + list(range(10,51))].dropna() ##FOR SYNTHETIC CONTROLS

df['Installation_year'] = df['year']
df['Install_year'] = df['year']

df['Site'] = df['Site name']

df

df = df.drop(columns=['Site name', 'Installation_year', 'geometry', 'year', 'Latitude', 'Longitude'])

# 1. Melt the DataFrame
# Assumes 'site' is the column that identifies your locations
df_long = pd.melt(
    df, 
    id_vars=['Site', 'Install_year', 'type'], 
    var_name='year', 
    value_name='biomass'
)

# 2. Clean the 'year' column
# Remove 'biomass_' prefix and convert to numeric
df_long['year'] = df_long['year'].str.replace('biomass_', '').astype(int)

df_long'''
# Out:
# "##SYNTHETIC CONTROLS\ndf0 = pd.read_csv('C:/Users/arj26323/Documents/Data/GA_conservation/synthetic_contols/synthetic_controls_3.csv') ##3x3 window\n##NOTE THE DIFFERENT FILE PATH ON SYNTHETIC CONTROLS VS. ORIGINALS\n\ndf = df0.iloc[:, [1,2,3,4,5] + list(range(10,51))].dropna() ##FOR SYNTHETIC CONTROLS\n\ndf['Installation_year'] = df['year']\ndf['Install_year'] = df['year']\n\ndf['Site'] = df['Site name']\n\ndf\n\ndf = df.drop(columns=['Site name', 'Installation_year', 'geometry', 'year', 'Latitude', 'Longitude'])\n\n# 1. Melt the DataFrame\n# Assumes 'site' is the column that identifies your locations\ndf_long = pd.melt(\n    df, \n    id_vars=['Site', 'Install_year', 'type'], \n    var_name='year', \n    value_name='biomass'\n)\n\n# 2. Clean the 'year' column\n# Remove 'biomass_' prefix and convert to numeric\ndf_long['year'] = df_long['year'].str.replace('biomass_', '').astype(int)\n\ndf_long"

# %%
df_long['Site'].unique()
# Out:
# array(['Plantation Creek Site', 'Florida Passage Site', 'Oatland Site',
#        'Estuaries Area of the Altamaha River',
#        'Jekyll Island Boat Ramp Site', 'Oyster Creek Site B',
#        'Jointer Creek Oyster Reef A', 'Jointer Creek Oyster Reef B',
#        'Jointer Creek Oyster Reef C', 'Jointer Creek Oyster Reef D',
#        'Turtle A', 'Turtle B', 'Turtle C', 'Turtle D', 'Turtle E',
#        'Bellville Boat Ramp Site', 'Ashantilly, Sapelo Island',
#        'Long Tabby, Sapelo Island',
#        "Mosquito Creek, Little St. Simon's Island",
#        "Cannon's Point Preserve, St. Simon's Island",
#        'Skidaway Island State Park, Skidaway Island',
#        'Burton 4-H, Tybee Island',
#        'Beach Road Bridge, Little St. Simons Island',
#        'Little Cumberland Island', 'Fortson Pond, Jekyll Island',
#        "DNR's Coastal Regional Headquarters, Brunswick", 'Jekyll TLP'],
#       dtype=object)

# %%
'''##Adding installation year
df2 = pd.read_csv('C:/Users/arj26323/Documents/Data/GA_conservation/all_active_years_installations.csv')

df2['Install_year'] = df2['year']
df2['Site'] = df2['Site name']


df_insta = df2[['Site', 'Install_year']].copy()

# df_insta[df_insta['Site'] == "Mosquito Creek, Little St. Simon's Island"]
# df_insta'''
# Out:
# '##Adding installation year\ndf2 = pd.read_csv(\'C:/Users/arj26323/Documents/Data/GA_conservation/all_active_years_installations.csv\')\n\ndf2[\'Install_year\'] = df2[\'year\']\ndf2[\'Site\'] = df2[\'Site name\']\n\n\ndf_insta = df2[[\'Site\', \'Install_year\']].copy()\n\n# df_insta[df_insta[\'Site\'] == "Mosquito Creek, Little St. Simon\'s Island"]\n# df_insta'

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Remove leading/trailing whitespace
df_long['Site'] = df_long['Site'].str.strip()
'''df_insta['Site'] = df_insta['Site'].str.strip()
'''
# Normalize apostrophes: Replace curly/smart quotes with standard straight quotes
df_long['Site'] = df_long['Site'].str.replace("’", "'").str.replace("`", "'")
'''df_insta['Site'] = df_insta['Site'].str.replace("’", "'").str.replace("`", "'")
'''
'''df_long_install = pd.merge(df_long, df_insta, on = 'Site')

df_long_install = df_long_install[df_long_install['Site'] != "DNR's Coastal Regional Headquarters, Brunswick"] ##FLATS issues?'''

'''g = sns.FacetGrid(df_long_install, col="Site", col_wrap=4, height=3, sharey=True)
g.map(sns.scatterplot, "year", "biomass", marker='o', color = 'black')
# g.set_titles("{col_name}")
for site_name, ax in g.axes_dict.items():
    # Truncate the key string, not the axis object
    display_name = site_name if len(site_name) <= 30 else site_name[:30] + "..."
    
    # Set the title on the correct axis
    ax.set_title(display_name)
    
    # Get install year for this site
    install_year = (
        df_long_install.loc[df_long_install["Site"] == site_name, "Install_year"]
        .iloc[0]
    )

    # Add vertical dotted line
    ax.axvline(
        x=install_year,
        linestyle=":",
        color="red",
        linewidth=1.5
    )



g.set_axis_labels("", "AGB (g/$m^2$)")
g.set(ylim=(0, None))
plt.tight_layout()'''


# ##Save at high res
# import os
# output_dir = r'F:\Figures_PaperII'
# file_name = 'resorationsitetrends.tif'

# save_path = os.path.join(output_dir, file_name)

# # plt.savefig(save_path, bbox_inches='tight', dpi=1000)

# plt.show()
# Out:
# 'g = sns.FacetGrid(df_long_install, col="Site", col_wrap=4, height=3, sharey=True)\ng.map(sns.scatterplot, "year", "biomass", marker=\'o\', color = \'black\')\n# g.set_titles("{col_name}")\nfor site_name, ax in g.axes_dict.items():\n    # Truncate the key string, not the axis object\n    display_name = site_name if len(site_name) <= 30 else site_name[:30] + "..."\n    \n    # Set the title on the correct axis\n    ax.set_title(display_name)\n    \n    # Get install year for this site\n    install_year = (\n        df_long_install.loc[df_long_install["Site"] == site_name, "Install_year"]\n        .iloc[0]\n    )\n\n    # Add vertical dotted line\n    ax.axvline(\n        x=install_year,\n        linestyle=":",\n        color="red",\n        linewidth=1.5\n    )\n\n\n\ng.set_axis_labels("", "AGB (g/$m^2$)")\ng.set(ylim=(0, None))\nplt.tight_layout()'

# %%
df_flats = pd.read_csv('C:/Users/arj26323/Documents/Data/GA_conservation/Landsat_40Year_TimeSeries.csv')
# df_flats = pd.read_csv(
#     'C:/Users/arj26323/Documents/Data/GA_conservation/synthetic_contols/Landsat_40Year_TimeSeries_control.csv'
# ) ###SYNTHETIC CONTROLS!!

df_flats['Site'] = df_flats['Site name']
df_flats['Install_year'] = df_flats['year']

dfx = df_flats[['Site', 'Install_year', 'date', 'evi_mean', 'flats_mean']].copy()

dfx['Site'] = dfx['Site'].replace({"DNR's Costal Regional Headquarters, Brunswick": 
                                   "DNR's Coastal Regional Headquarters, Brunswick"})
dfx
# Out:
#                                                  Site  Install_year     date  \
# 0                               Plantation Creek Site          2010  1984-04
# 1                                Florida Passage Site          2012  1984-04
# 2                                        Oatland Site          2014  1984-04
# 3                                 Skidaway River Site          2010  1984-04
# 4                Estuaries Area of the Altamaha River          2009  1984-04
# ...                                               ...           ...      ...
# 14317     Beach Road Bridge, Little St. Simons Island          2017  2022-12
# 14318                        Little Cumberland Island          2020  2022-12
# 14319                     Fortson Pond, Jekyll Island          2021  2022-12
# 14320  DNR's Coastal Regional Headquarters, Brunswick          2023  2022-12
# 14321                                      Jekyll TLP          2019  2022-12
#
#        evi_mean  flats_mean
# 0      0.030452    0.389619
# 1      0.012869    0.711791
# 2      0.034820    0.271140
# 3      0.068154    0.428756
# 4     -0.019164    0.999925
# ...         ...         ...
# 14317  0.075881    0.008023
# 14318  0.046656    0.256583
# 14319  0.145541    0.000780
# 14320  0.042469    0.143818
# 14321  0.014215    0.655460
#
# [14322 rows x 5 columns]

# %%
# Convert 'date' to datetime and extract the year
dfx['date'] = pd.to_datetime(dfx['date'], format='%Y-%m')
dfx['year'] = dfx['date'].dt.year

# Calculate annual mean for flats
dfx_annual = dfx.groupby(['Site', 'year'])['flats_mean'].mean().reset_index()

# df_long_install['date_dt'] = pd.to_datetime(df_long_install['year'].astype(str), format='%Y')

# Merge into your main plotting dataframe
'''df_merged = df_long_install.merge(dfx_annual, on=['Site', 'year'], how='left')
'''
df_merged = df_long.merge(dfx_annual, on=['Site', 'year'], how='left')

df_merged = df_merged[df_merged['type'] == 'Oyster Reef'] ##Testing statistics just using the more open ORs


# len(df_long_install['Site'].unique())

# %%
# Create the FacetGrid
g = sns.FacetGrid(df_merged, col="Site", col_wrap=4, height=3, sharey=True)

site_type_map = df_merged.groupby('Site')['type'].first().to_dict()

import string

# Get sites in the order you want
sites = sorted(df_merged["Site"].unique())

# Create A, B, C, ...
site_letter_map = {
    site: letter
    for site, letter in zip(g.col_names, string.ascii_uppercase)
}


# Map the scatterplot
g.map(sns.scatterplot, "year", "biomass", marker='o', color='black', s=20)

for site_name, ax in g.axes_dict.items():
    
    # Get the type for this site
    site_type = site_type_map.get(site_name, "Unknown")
    
    site_letter = site_letter_map[site_name]
    
    # Update the title to include both Site and Type
    ax.set_title(f"{site_name}\n{site_type}", size=8.5)
    
    # Update the title to include both Site and Type
    ax.set_title(f"{site_letter}\n{site_name}", size=8.5)
    
    # 1. Create the second axis
    ax2 = ax.twinx()
    
    # 2. Filter data for this specific site
    site_data = df_merged[df_merged["Site"] == site_name]
    
    # 3. Plot the flats_mean on the twin axis
    ax2.plot(site_data["year"], site_data["flats_mean"], color='blue', alpha=0.6, label='Flats')
    
    # 4. Conditionally set labels to avoid repetition
    # Only show the ylabel for the right-most columns
    if ax.is_last_col():
        ax2.set_ylabel("FLATS+ value", color='blue')
    else:
        ax2.set_ylabel("")
        # Hide tick labels for non-right columns if preferred
        ax2.tick_params(axis='y', labelright=False)
        
    ax2.tick_params(axis='y', labelcolor='blue')
    ax2.set_ylim(0, 1)
    
    # Add your existing vertical line
    install_year = site_data["Install_year"].iloc[0]
    ax.axvline(x=install_year, linestyle=":", color="red", linewidth=1.5)

g.set_axis_labels("", "AGB (g/$m^2$)")
g.set(ylim=(0, 2000))
'''g.set_titles("{col_name}", size = 8.5)
'''    
plt.tight_layout()


##Save at high res
import os
output_dir = r'F:\Figures_PaperII'
file_name = 'FIXED_resorationsitetrends_3_oysters.tif'

save_path = os.path.join(output_dir, file_name)

# plt.savefig(save_path, bbox_inches='tight', dpi=1000)
plt.show()
# Out:
# C:\Users\arj26323\AppData\Local\Temp\ipykernel_9536\878924765.py:45: MatplotlibDeprecationWarning:
# The is_last_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_col() instead.
#   if ax.is_last_col():

# %%
import statsmodels.formula.api as smf

# Create a 'years_since_install' column
df_merged['years_since_install'] = df_merged['year'] - df_merged['Install_year']
df_merged['time_since_intervention'] = (df_merged['year'] - df_merged['Install_year']).clip(lower=0)
df_merged['installation_year'] = df_merged['Install_year']

# Clean the data before modeling
df_clean = df_merged.dropna(subset=['biomass', 'flats_mean', 'years_since_install', 'Site']).copy()
df_clean = df_clean.reset_index(drop=True)

# %%
##Combining restoration site trends with synthetic control trends in a single file
xx = pd.read_csv('C:/Users/arj26323/Documents/Data/GA_Conservation/df_rest_sites.csv')
yy = pd.read_csv('C:/Users/arj26323/Documents/Data/GA_Conservation/synthetic_contols/df_syntheticcontrol_sites.csv')
xx['Treatment'] = 'Altered'
yy['Treatment'] = 'Control'

yy["SiteTreat"] = yy["Site"] + "_C"
xx["SiteTreat"] = xx["Site"] + "_A"

zz = df_all = pd.concat([xx, yy], ignore_index=True)

zz
# Out:
#                               Site  Install_year         type  year  \
# 0            Plantation Creek Site          2010  Oyster Reef  1984
# 1             Florida Passage Site          2012  Oyster Reef  1984
# 2                     Oatland Site          2014  Oyster Reef  1984
# 3     Jekyll Island Boat Ramp Site          2009  Oyster Reef  1984
# 4              Oyster Creek Site B          2013  Oyster Reef  1984
# ...                            ...           ...          ...   ...
# 1048                      Turtle B          2014  Oyster Reef  2022
# 1049                      Turtle C          2014  Oyster Reef  2022
# 1050                      Turtle D          2014  Oyster Reef  2022
# 1051                      Turtle E          2014  Oyster Reef  2022
# 1052      Bellville Boat Ramp Site          2008  Oyster Reef  2022
#
#          biomass  flats_mean  years_since_install  time_since_intervention  \
# 0     415.569183    0.379410                  -26                        0
# 1     546.787598    0.752100                  -28                        0
# 2     454.848907    0.239140                  -30                        0
# 3     426.000030    0.880526                  -25                        0
# 4     239.060226    0.745511                  -29                        0
# ...          ...         ...                  ...                      ...
# 1048  452.692535    0.316537                    8                        8
# 1049  379.104492    0.593493                    8                        8
# 1050  468.425079    0.177950                    8                        8
# 1051  424.402832    0.276992                    8                        8
# 1052  265.446014    0.748704                   14                       14
#
#       installation_year  PostInstall  YearSinceInstall       resid Treatment  \
# 0                  2010            0                 0 -157.612103   Altered
# 1                  2012            0                 0  -56.665983   Altered
# 2                  2014            0                 0  -45.020865   Altered
# 3                  2009            0                 0  -76.927027   Altered
# 4                  2013            0                 0  -84.032465   Altered
# ...                 ...          ...               ...         ...       ...
# 1048               2014            1                 8         NaN   Control
# 1049               2014            1                 8         NaN   Control
# 1050               2014            1                 8         NaN   Control
# 1051               2014            1                 8         NaN   Control
# 1052               2008            1                14         NaN   Control
#
#                            SiteTreat
# 0            Plantation Creek Site_A
# 1             Florida Passage Site_A
# 2                     Oatland Site_A
# 3     Jekyll Island Boat Ramp Site_A
# 4              Oyster Creek Site B_A
# ...                              ...
# 1048                      Turtle B_C
# 1049                      Turtle C_C
# 1050                      Turtle D_C
# 1051                      Turtle E_C
# 1052      Bellville Boat Ramp Site_C
#
# [1053 rows x 14 columns]

# %%
#Export CSV file
out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'df_rest_sites.csv')
# df.to_csv(out_csv, index = False)

# %%
#Fin
