# %%
import os
import glob
import rasterio
import geopandas as gpd
'''
# 1. Load the shapefile directly (GeoPandas automatically reads the UTM geometry and CRS)
# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids/gce_sites_zone_pixels_centroids.shp")
# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids2/gce_sites_zone_pixels_centroids2.shp")

# 2. Get the native CRS of your biomass models
raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))
with rasterio.open(raster_files[0]) as src:
    raster_crs = src.crs

# 3. Project the points to match the raster if they don't already
if points_gdf.crs != raster_crs:
    points_gdf = points_gdf.to_crs(raster_crs)

# Extract coordinates as a list of (x, y) tuples
coord_tuples = [(pt.x, pt.y) for pt in points_gdf.geometry]

# 4. Loop through the years and sample the data
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Extracting data for year: {year}...")
    
    with rasterio.open(raster_path) as src:
        # Sample the raster and append directly to the GeoDataFrame
        points_gdf[f"biomass_{year}"] = [val[0] for val in src.sample(coord_tuples)]

# 5. Save out the clean results
# You can save it back out as a flat CSV for them, or even a new shapefile/GeoJSON
points_gdf.drop(columns='geometry').to_csv("biomass_extractions_final.csv", index=False)
print("Done!")'''''
# Out:
# '\n# 1. Load the shapefile directly (GeoPandas automatically reads the UTM geometry and CRS)\n# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids/gce_sites_zone_pixels_centroids.shp")\n# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids2/gce_sites_zone_pixels_centroids2.shp")\n\n# 2. Get the native CRS of your biomass models\nraster_files = sorted(glob.glob(\'F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif\'))\nwith rasterio.open(raster_files[0]) as src:\n    raster_crs = src.crs\n\n# 3. Project the points to match the raster if they don\'t already\nif points_gdf.crs != raster_crs:\n    points_gdf = points_gdf.to_crs(raster_crs)\n\n# Extract coordinates as a list of (x, y) tuples\ncoord_tuples = [(pt.x, pt.y) for pt in points_gdf.geometry]\n\n# 4. Loop through the years and sample the data\nfor raster_path in raster_files:\n    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")\n    print(f"Extracting data for year: {year}...")\n    \n    with rasterio.open(raster_path) as src:\n        # Sample the raster and append directly to the GeoDataFrame\n        points_gdf[f"biomass_{year}"] = [val[0] for val in src.sample(coord_tuples)]\n\n# 5. Save out the clean results\n# You can save it back out as a flat CSV for them, or even a new shapefile/GeoJSON\npoints_gdf.drop(columns=\'geometry\').to_csv("biomass_extractions_final.csv", index=False)\nprint("Done!")'

# %%
points_gdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 points_gdf
#
# NameError: name 'points_gdf' is not defined

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'rest_trends.csv')

#points_gdf.to_csv(out_csv)

# %%
##Window extraction around restoration points
import rasterio
from rasterio.windows import Window
import numpy as np
import pandas as pd
import geopandas as gpd
import glob
import os

# 1. Setup
points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/Restoration sites/Rest_sites.shp")
raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))

with rasterio.open(raster_files[0]) as src:
    raster_crs = src.crs
    if points_gdf.crs != raster_crs:
        points_gdf = points_gdf.to_crs(raster_crs)

# Define window size (e.g., 2x2)
win_size = 4
pad = win_size // 4

# 2. Loop through files
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Extracting 4x4 mean for year: {year}...")
    
    with rasterio.open(raster_path) as src:
        results = []
        for idx, row in points_gdf.iterrows():
            # Get pixel coordinates
            row_idx, col_idx = src.index(row.geometry.x, row.geometry.y)
            
            # Define the window
            window = Window(col_idx - pad, row_idx - pad, win_size, win_size)
            
            # Read the window data
            data = src.read(1, window=window)
            
            # Mask out nodata/NaN values
            # Replace 'src.nodata' with np.nan if your tiff uses actual NaNs
            if src.nodata is not None:
                data = np.where(data == src.nodata, np.nan, data)
                
            # Calculate mean ignoring NaNs
            if np.all(np.isnan(data)):
                results.append(np.nan)
            else:
                results.append(np.nanmean(data))
        
        points_gdf[f"biomass_{year}"] = results

# 3. Save
points_gdf.drop(columns='geometry').to_csv("biomass_extractions_4x4.csv", index=False)
print("Done!")
# Out:
# Extracting 3x3 mean for year: 1984...
# Extracting 3x3 mean for year: 1985...
# Extracting 3x3 mean for year: 1986...
# Extracting 3x3 mean for year: 1987...
# Extracting 3x3 mean for year: 1988...
# Extracting 3x3 mean for year: 1989...
# Extracting 3x3 mean for year: 1990...
# Extracting 3x3 mean for year: 1991...
# Extracting 3x3 mean for year: 1992...
# Extracting 3x3 mean for year: 1993...
# Extracting 3x3 mean for year: 1994...
# Extracting 3x3 mean for year: 1995...
# Extracting 3x3 mean for year: 1996...
# Extracting 3x3 mean for year: 1997...
# Extracting 3x3 mean for year: 1998...
# Extracting 3x3 mean for year: 1999...
# Extracting 3x3 mean for year: 2000...
# Extracting 3x3 mean for year: 2001...
# Extracting 3x3 mean for year: 2002...
# Extracting 3x3 mean for year: 2003...
# Extracting 3x3 mean for year: 2004...
# Extracting 3x3 mean for year: 2005...
# Extracting 3x3 mean for year: 2006...
# Extracting 3x3 mean for year: 2007...
# Extracting 3x3 mean for year: 2008...
# Extracting 3x3 mean for year: 2009...
# Extracting 3x3 mean for year: 2010...
# Extracting 3x3 mean for year: 2011...
# Extracting 3x3 mean for year: 2012...
# Extracting 3x3 mean for year: 2013...
# Extracting 3x3 mean for year: 2014...
# Extracting 3x3 mean for year: 2015...
# Extracting 3x3 mean for year: 2016...
# Extracting 3x3 mean for year: 2017...
# Extracting 3x3 mean for year: 2018...
# Extracting 3x3 mean for year: 2019...
# Extracting 3x3 mean for year: 2020...
# Extracting 3x3 mean for year: 2021...
# Extracting 3x3 mean for year: 2022...
# Extracting 3x3 mean for year: 2023...
# Done!

# %%
points_gdf
# Out:
#                                               Site   Latitude  Longitude Type  \
# 0                         Little Cumberland Island  30.950135 -81.421247   LS
# 1                      Fortson Pond, Jekyll Island  31.053372 -81.414579   LS
# 2   DNR’s Coastal Regional Headquarters, Brunswick  31.122932 -81.478103   LS
# 3      Beach Road Bridge, Little St. Simons Island  31.249670 -81.293518   LS
# 4      Cannon’s Point Preserve, St. Simon’s Island  31.260038 -81.339778   LS
# 5        Mosquito Creek, Little St. Simon’s Island  31.260078 -81.301105   LS
# 6                        Long Tabby, Sapelo Island  31.431955 -81.282659   LS
# 7                        Ashantilly, Sapelo Island  31.435565 -81.280004   LS
# 8      Skidaway Island State Park, Skidaway Island  31.951577 -81.055498   LS
# 9                         Burton 4-H, Tybee Island  32.007732 -80.851325   LS
# 10                           Plantation Creek Site  31.122967 -81.477183   OR
# 11                            Florida Passage Site  31.838650 -81.153333   OR
# 12                                    Oatland Site  32.048017 -81.019233   OR
# 13                             Skidaway River Site  31.988800 -81.024883   OR
# 14            Estuaries Area of the Altamaha River  31.326150 -81.322283   OR
# 15                    Jekyll Island Boat Ramp Site  31.041650 -81.423017   OR
# 16                             Oyster Creek Site A  32.002983 -80.917817   OR
# 17                             Oyster Creek Site B  32.004417 -80.914883   OR
# 18                             Oyster Creek Site C  32.007950 -80.911683   OR
# 19                     Jointer Creek Oyster Reef A  31.080800 -81.500217   OR
# 20                     Jointer Creek Oyster Reef B  31.079600 -81.493967   OR
# 21                     Jointer Creek Oyster Reef C  31.080583 -81.490783   OR
# 22                     Jointer Creek Oyster Reef D  31.070400 -81.470050   OR
# 23                                        Turtle A  31.126267 -81.479067   OR
# 24                                        Turtle B  31.194100 -81.531433   OR
# 25                                        Turtle C  31.196383 -81.537950   OR
# 26                                        Turtle D  31.183717 -81.530133   OR
# 27                                        Turtle E  31.131267 -81.462183   OR
# 28                        Bellville Boat Ramp Site  31.531183 -81.358533   OR
# 29                              Overlook Park Site  31.151567 -81.476850   OR
# 30                                      Jekyll TLP  31.087615 -81.433770  TLP
#
#                       geometry  biomass_1984  biomass_1985  biomass_1986  \
# 0   POINT (-81.42125 30.95014)    629.562134    771.872559    625.393005
# 1   POINT (-81.41458 31.05337)    986.878967   1053.104370    971.976379
# 16    294.401611    382.823700  ...    270.390839    375.388824    244.519592
# 17    291.562958    369.751556  ...    251.925461    379.952362    205.888474
# 18    346.935638    331.831207  ...    256.266510    361.592194    217.594849
# 19    347.091125    369.082184  ...    246.608215    368.636230    251.039337
# 20    360.008636    337.579590  ...    274.967621    381.692657    266.043488
# 21    355.180176    337.854858  ...    262.336914    375.519836    249.687531
# 22    418.006592    403.280396  ...    369.914581    668.582764    369.886169
# 23    701.898438    736.581299  ...    717.710388   1119.431152    761.646179
# 24    396.591858    467.893280  ...    329.033875    472.753845    300.441559
# 25    638.696716    780.221375  ...    507.736786    809.971497    500.277344
# 26    472.512054    525.667908  ...    334.611969    565.732422    359.775604
# 27    373.322693    320.478180  ...    301.034180    525.222839    280.393707
# 28    810.875244   1027.419189  ...    779.644165    775.549622    766.673462
# 29           NaN           NaN  ...           NaN           NaN           NaN
# 30    328.141785    309.657867  ...    242.829041    395.149719    252.238007
#
#     biomass_2017  biomass_2018  biomass_2019  biomass_2020  biomass_2021  \
# 0     777.490234    588.700928    612.736389    611.430481    754.832031
# 1    1086.390259    974.697083    957.501526   1091.748291   1083.312134
# 2     488.927521    342.864105    336.854431    508.599579    492.945221
# 3     624.188538    681.158752    663.015564    971.219055    977.167114
# 4     654.325928    710.111267    712.993896    870.199463    830.845581
# 5     694.225647    707.349548    729.588623    977.102112    919.787781
# 6    1159.304199    661.316833    669.801758    927.404968    565.239319
# 7    1034.705688   1179.414795   1183.139282   1084.255981   1222.003662
# 8     514.268494    514.652344    479.466858    604.774902    567.620178
# 9     525.933594    555.613770    564.926392    600.949768    594.104370
# 10    615.905273    478.254791    434.525177    714.136902    823.788635
# 11    490.022614    480.411011    418.332520    560.940308    493.276245
# 12    434.612732    431.465637    378.262756    505.979706    516.557861
# 13           NaN           NaN           NaN           NaN           NaN
# 14   1945.601929   1816.893677   1365.065308   1973.961060   1929.251587
# 15    562.577576    411.958008    411.658356    465.735260    575.580261
# 16    265.284393    250.335251    254.687744    255.068298    267.692810
# 17    232.572906    215.731125    246.284225    249.831177    214.575150
# 18    236.406189    253.398880    245.119736    258.031128    235.816574
# 19    361.807617    229.932373    265.036041    363.710510    365.909576
# 20    378.523407    241.847824    267.323761    389.814178    370.218231
# 21    361.999756    234.102936    269.492859    398.049225    368.151306
# 22    505.491394    675.972778    384.359161    470.159119    603.878601
# 23    872.395020    800.138000    691.642395   1124.234375   1071.091309
# 24    422.936493    313.756042    286.695892    543.611084    468.616272
# 25    790.875916    519.512817    620.624756    946.911804    734.345398
# 26    400.561066    912.296204    328.488251    654.536377    495.078979
# 27    302.622986    281.318665    288.022675    511.678162    448.159882
# 28   1013.814941    778.083557    753.842896   1094.224976   1083.768555
# 29           NaN           NaN           NaN           NaN           NaN
# 30    398.587341    259.607422    265.320679    403.432495    405.960205
#
#     biomass_2022  biomass_2023
# 0     597.393494    601.492676
# 1    1064.949463    985.661926
# 2     363.176483    359.983917
# 3     696.566650    721.923462
# 4     686.569580    715.785645
# 5     701.898682    711.288513
# 6    1333.237549   1198.355103
# 7     971.112915   1183.157227
# 8     599.156982    589.331787
# 9     605.037231    586.813416
# 10    479.731964    464.357910
# 11    459.225952    502.592590
# 12    391.161011    401.994263
# 13           NaN           NaN
# 14   1754.852905   1458.545532
# 15    408.291718    419.075836
# 16    293.230560    261.743652
# 17    207.701630    215.857468
# 18    237.069565    234.777466
# 19    254.114487    320.252197
# 20    254.134232    271.862732
# 21    257.852875    271.058777
# 22    355.689270    916.806274
# 23    780.271667    832.802063
# 24    464.666687    351.859039
# 25    503.080322    615.188171
# 26    365.702393    403.559814
# 27    320.579773    342.254150
# 28    818.363281    831.408081
# 29           NaN           NaN
# 30    285.945923    300.529510
#
# [31 rows x 45 columns]

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'restoration_window_trends_5.csv')

#points_gdf.to_csv(out_csv)

# %%
# 1. Setup

import geopandas as gpd
import rasterio
from rasterio.mask import mask
import numpy as np
import os
import glob
import pandas as pd

# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspots_theilsen_polyg_500k_m2.shp')
# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspots_theilsen_savan_100_m2.shp')
# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspot_jekyllish.shp')
# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspots_theilsen_sap_100.shp')
polygons = gpd.read_file('F:/Hotspots/Project shapefiles/all_100.shp')

raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))

# Initialize an empty list to store results for each polygon
results = []

# 2. Iterate through each raster
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Processing {year}...")
    
    with rasterio.open(raster_path) as src:
        # Ensure CRS matches
        if polygons.crs != src.crs:
            polygons = polygons.to_crs(src.crs)
            
        # Loop through each polygon
        for idx, row in polygons.iterrows():
            # Use rasterio.mask to clip the raster to the polygon geometry
            # crop=True keeps the resulting array small (the bounding box of the polygon)
            out_image, out_transform = mask(src, [row.geometry], crop=True, nodata=np.nan)
            
            # The mask returns an array [band, height, width]
            data = out_image[0]
            
            # Remove NaNs (NoData pixels)
            valid_pixels = data[~np.isnan(data)]
            
            # Calculate stats
            if valid_pixels.size > 0:
                mean_val = np.nanmean(valid_pixels)
                std_val = np.nanstd(valid_pixels)
            else:
                mean_val = np.nan
                std_val = np.nan
                
            results.append({
                'polygon_id': idx,
                'year': year,
                'mean': mean_val,
                'std': std_val
            })

# 3. Convert results to a DataFrame
stats_df = pd.DataFrame(results)

# Optional: Pivot to wide format if you want one column per year
pivot_df = stats_df.pivot(index='polygon_id', columns='year', values='mean')
print("Extraction complete!")
# Out:
# Processing 1984...
# Processing 1985...
# Processing 1986...
# Processing 1987...
# Processing 1988...
# Processing 1989...
# Processing 1990...
# Processing 1991...
# Processing 1992...
# Processing 1993...
# Processing 1994...
# Processing 1995...
# Processing 1996...
# Processing 1997...
# Processing 1998...
# Processing 1999...
# Processing 2000...
# Processing 2001...
# Processing 2002...
# Processing 2003...
# Processing 2004...
# Processing 2005...
# Processing 2006...
# Processing 2007...
# Processing 2008...
# Processing 2009...
# Processing 2010...
# Processing 2011...
# Processing 2012...
# Processing 2013...
# Processing 2014...
# Processing 2015...
# Processing 2016...
# Processing 2017...
# Processing 2018...
# Processing 2019...
# Processing 2020...
# Processing 2021...
# Processing 2022...
# Processing 2023...
# Extraction complete!

# %%
stats_df
# Out:
#       polygon_id  year        mean         std
# 0              0  1984  465.578949   34.439026
# 1              1  1984  465.542297   33.199669
# 2              2  1984  476.600403   42.166412
# 3              3  1984  456.660065   25.501823
# 4              4  1984  418.759491   69.571579
# ...          ...   ...         ...         ...
# 3715          88  2023  345.837524  270.438843
# 3716          89  2023  249.398560   40.118248
# 3717          90  2023  399.588562  355.779602
# 3718          91  2023  465.820587  147.515091
# 3719          92  2023  445.692535  136.354080
#
# [3720 rows x 4 columns]

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'all_10hectare_hotspots_trends.csv')

#stats_df.to_csv(out_csv)

# %%
#Fin
