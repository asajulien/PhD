# %%
import os
import glob
import rasterio
import geopandas as gpd
'''
# 1. Load the shapefile directly (GeoPandas automatically reads the UTM geometry and CRS)
# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids/gce_sites_zone_pixels_centroids.shp")
# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids2/gce_sites_zone_pixels_centroids2.shp")

# 2. Get the native CRS of your biomass models
raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))
with rasterio.open(raster_files[0]) as src:
    raster_crs = src.crs

# 3. Project the points to match the raster if they don't already
if points_gdf.crs != raster_crs:
    points_gdf = points_gdf.to_crs(raster_crs)

# Extract coordinates as a list of (x, y) tuples
coord_tuples = [(pt.x, pt.y) for pt in points_gdf.geometry]

# 4. Loop through the years and sample the data
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Extracting data for year: {year}...")
    
    with rasterio.open(raster_path) as src:
        # Sample the raster and append directly to the GeoDataFrame
        points_gdf[f"biomass_{year}"] = [val[0] for val in src.sample(coord_tuples)]

# 5. Save out the clean results
# You can save it back out as a flat CSV for them, or even a new shapefile/GeoJSON
points_gdf.drop(columns='geometry').to_csv("biomass_extractions_final.csv", index=False)
print("Done!")'''''
# Out:
# '\n# 1. Load the shapefile directly (GeoPandas automatically reads the UTM geometry and CRS)\n# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids/gce_sites_zone_pixels_centroids.shp")\n# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids2/gce_sites_zone_pixels_centroids2.shp")\n\n# 2. Get the native CRS of your biomass models\nraster_files = sorted(glob.glob(\'F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif\'))\nwith rasterio.open(raster_files[0]) as src:\n    raster_crs = src.crs\n\n# 3. Project the points to match the raster if they don\'t already\nif points_gdf.crs != raster_crs:\n    points_gdf = points_gdf.to_crs(raster_crs)\n\n# Extract coordinates as a list of (x, y) tuples\ncoord_tuples = [(pt.x, pt.y) for pt in points_gdf.geometry]\n\n# 4. Loop through the years and sample the data\nfor raster_path in raster_files:\n    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")\n    print(f"Extracting data for year: {year}...")\n    \n    with rasterio.open(raster_path) as src:\n        # Sample the raster and append directly to the GeoDataFrame\n        points_gdf[f"biomass_{year}"] = [val[0] for val in src.sample(coord_tuples)]\n\n# 5. Save out the clean results\n# You can save it back out as a flat CSV for them, or even a new shapefile/GeoJSON\npoints_gdf.drop(columns=\'geometry\').to_csv("biomass_extractions_final.csv", index=False)\nprint("Done!")'

# %%
points_gdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 points_gdf
#
# NameError: name 'points_gdf' is not defined

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'rest_trends.csv')

#points_gdf.to_csv(out_csv)

# %%
##Window extraction around restoration points
import rasterio
from rasterio.windows import Window
import numpy as np
import pandas as pd
import geopandas as gpd
import glob
import os

# 1. Setup
'''points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/Restoration sites/Rest_sites.shp")
'''
raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))

# Load CSV
# csv_path = "C:/Users/arj26323/Documents/Data/GA_conservation/fixed_actives_installations.csv" #UPDATED LIVINGSHORELINE LOCATIONS

csv_path = "C:/Users/arj26323/Documents/Data/GA_conservation/synthetic_contols/controls.csv" #SYNTHETIC CONTROLS

df = pd.read_csv(csv_path)

# Create GeoDataFrame
points_gdf = gpd.GeoDataFrame(
    df, 
    geometry=gpd.points_from_xy(df.Longitude, df.Latitude),
    crs="EPSG:4326"
)

'''with rasterio.open(raster_files[0]) as src:
    raster_crs = src.crs
    if points_gdf.crs != raster_crs:
        points_gdf = points_gdf.to_crs(raster_crs)'''

# Define window size (e.g., 2x2)
win_size = 3
pad = win_size // 3

# 2. Loop through files
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Extracting window mean for year: {year}...")
    
    with rasterio.open(raster_path) as src:
        results = []
        for idx, row in points_gdf.iterrows():
            # Get pixel coordinates
            row_idx, col_idx = src.index(row.geometry.x, row.geometry.y)
            
            # Define the window
            window = Window(col_idx - pad, row_idx - pad, win_size, win_size)
            
            # Read the window data
            data = src.read(1, window=window)
            
            # Mask out nodata/NaN values
            # Replace 'src.nodata' with np.nan if your tiff uses actual NaNs
            if src.nodata is not None:
                data = np.where(data == src.nodata, np.nan, data)
                
            # Calculate mean ignoring NaNs
            if np.all(np.isnan(data)):
                results.append(np.nan)
            else:
                results.append(np.nanmean(data))
        
        points_gdf[f"biomass_{year}"] = results

# 3. Save
points_gdf.drop(columns='geometry')
# points_gdf.drop(columns='geometry').to_csv("biomass_extractions_5x5.csv", index=False)
print("Done!")
# Out:
# Extracting window mean for year: 1984...
# Extracting window mean for year: 1985...
# Extracting window mean for year: 1986...
# Extracting window mean for year: 1987...
# Extracting window mean for year: 1988...
# Extracting window mean for year: 1989...
# Extracting window mean for year: 1990...
# Extracting window mean for year: 1991...
# Extracting window mean for year: 1992...
# Extracting window mean for year: 1993...
# Extracting window mean for year: 1994...
# Extracting window mean for year: 1995...
# Extracting window mean for year: 1996...
# Extracting window mean for year: 1997...
# Extracting window mean for year: 1998...
# Extracting window mean for year: 1999...
# Extracting window mean for year: 2000...
# Extracting window mean for year: 2001...
# Extracting window mean for year: 2002...
# Extracting window mean for year: 2003...
# Extracting window mean for year: 2004...
# Extracting window mean for year: 2005...
# Extracting window mean for year: 2006...
# Extracting window mean for year: 2007...
# Extracting window mean for year: 2008...
# Extracting window mean for year: 2009...
# Extracting window mean for year: 2010...
# Extracting window mean for year: 2011...
# Extracting window mean for year: 2012...
# Extracting window mean for year: 2013...
# Extracting window mean for year: 2014...
# Extracting window mean for year: 2015...
# Extracting window mean for year: 2016...
# Extracting window mean for year: 2017...
# Extracting window mean for year: 2018...
# Extracting window mean for year: 2019...
# Extracting window mean for year: 2020...
# Extracting window mean for year: 2021...
# Extracting window mean for year: 2022...
# Extracting window mean for year: 2023...
# Done!

# %%
points_gdf
# Out:
#      Latitude  Longitude                                       Site name  \
# 0   31.122967 -81.477183                           Plantation Creek Site
# 1   31.838650 -81.153333                            Florida Passage Site
# 2   32.048017 -81.019233                                    Oatland Site
# 3   31.988800 -81.024883                             Skidaway River Site
# 4   31.326150 -81.322283            Estuaries Area of the Altamaha River
# 5   31.041650 -81.423017                    Jekyll Island Boat Ramp Site
# 6   32.002983 -80.917817                             Oyster Creek Site A
# 7   32.004417 -80.914883                             Oyster Creek Site B
# 8   32.007950 -80.911683                             Oyster Creek Site C
# 9   31.080800 -81.500217                     Jointer Creek Oyster Reef A
# 10  31.079600 -81.493967                     Jointer Creek Oyster Reef B
# 11  31.080583 -81.490783                     Jointer Creek Oyster Reef C
# 12  31.070400 -81.470050                     Jointer Creek Oyster Reef D
# 13  31.126267 -81.479067                                        Turtle A
# 14  31.194100 -81.531433                                        Turtle B
# 15  31.196383 -81.537950                                        Turtle C
# 16  31.183717 -81.530133                                        Turtle D
# 17  31.131267 -81.462183                                        Turtle E
# 18  31.531183 -81.358533                        Bellville Boat Ramp Site
# 19  31.151567 -81.476850                              Overlook Park Site
# 20  31.434344 -81.281177                       Ashantilly, Sapelo Island
# 21  31.431958 -81.282658                       Long Tabby, Sapelo Island
# 22  31.260096 -81.301873       Mosquito Creek, Little St. Simon's Island
# 23  31.260293 -81.340053     Cannon's Point Preserve, St. Simon's Island
# 24  31.951606 -81.055935     Skidaway Island State Park, Skidaway Island
# 25  32.007583 -80.851889                        Burton 4-H, Tybee Island
# 26  31.249585 -81.293448     Beach Road Bridge, Little St. Simons Island
# 27  30.950218 -81.421047                        Little Cumberland Island
# 28  31.053493 -81.414562                     Fortson Pond, Jekyll Island
# 29  31.123576 -81.477320  DNR's Coastal Regional Headquarters, Brunswick
# 30  31.087763 -81.433509                                      Jekyll TLP
#
#     year                  type                    geometry  biomass_1984  \
# 0   2010           Oyster Reef  POINT (-81.47718 31.12297)    415.569183
# 1   2012           Oyster Reef  POINT (-81.15333 31.83865)    546.787598
# 2   2014           Oyster Reef  POINT (-81.01923 32.04802)    454.848907
# 3   2010           Oyster Reef   POINT (-81.02488 31.9888)           NaN
# 4   2009           Oyster Reef  POINT (-81.32228 31.32615)    432.954224
# 5   2009           Oyster Reef  POINT (-81.42302 31.04165)    426.000031
# 6   2013           Oyster Reef  POINT (-80.91782 32.00298)    262.610077
# 7   2013           Oyster Reef  POINT (-80.91488 32.00442)    239.060226
# 8   2013           Oyster Reef  POINT (-80.91168 32.00795)    325.589691
# 9   2012           Oyster Reef   POINT (-81.50022 31.0808)    280.419067
# 10  2012           Oyster Reef   POINT (-81.49397 31.0796)    289.923523
# 11  2012           Oyster Reef  POINT (-81.49078 31.08058)    324.102203
# 12  2012           Oyster Reef   POINT (-81.47005 31.0704)    389.009094
# 13  2014           Oyster Reef  POINT (-81.47907 31.12627)    673.846741
# 14  2014           Oyster Reef   POINT (-81.53143 31.1941)    327.873016
# 15  2014           Oyster Reef  POINT (-81.53795 31.19638)    619.667480
# 16  2014           Oyster Reef  POINT (-81.53013 31.18372)    420.449310
# 17  2014           Oyster Reef  POINT (-81.46218 31.13127)    354.036194
# 18  2008           Oyster Reef  POINT (-81.35853 31.53118)    832.575562
# 19  2013           Oyster Reef  POINT (-81.47685 31.15157)           NaN
# 20  2010      Living Shoreline  POINT (-81.28118 31.43434)    725.934387
# 21  2010      Living Shoreline  POINT (-81.28266 31.43196)    869.103271
# 22  2013      Living Shoreline   POINT (-81.30187 31.2601)    589.755554
# 23  2015      Living Shoreline  POINT (-81.34005 31.26029)    938.501465
# 24  2015      Living Shoreline  POINT (-81.05594 31.95161)    722.534790
# 25  2015      Living Shoreline  POINT (-80.85189 32.00758)    512.275696
# 26  2017      Living Shoreline  POINT (-81.29345 31.24958)    561.316895
# 27  2020      Living Shoreline  POINT (-81.42105 30.95022)    896.741882
# 28  2021      Living Shoreline  POINT (-81.41456 31.05349)    986.878967
# 29  2023      Living Shoreline  POINT (-81.47732 31.12358)    399.133545
# 30  2019  Thin Layer Placement  POINT (-81.43351 31.08776)    245.474884
#
#     biomass_1985  biomass_1986  biomass_1987  ...  biomass_2014  biomass_2015  \
# 0     596.696716    424.160248    444.760101  ...    468.044189    664.676270
# 1     628.008118    713.233459    566.339539  ...    392.914490    673.458801
# 2     431.684174    551.176636    462.359711  ...    409.996338    560.010925
# 3            NaN           NaN           NaN  ...           NaN           NaN
# 4     432.954224    346.108185    367.529572  ...   1785.122437   1951.631470
# 5     584.057495    406.831421    387.468353  ...    403.886597    589.351074
# 6     438.078613    411.706024    294.401611  ...    270.390839    375.388824
# 7     372.658813    358.286591    291.562958  ...    251.925461    379.952362
# 8     409.982025    415.601074    346.935638  ...    256.266510    361.592194
# 9     399.076416    300.492676    347.091125  ...    246.608215    368.636230
# 10    397.946198    302.668671    360.008636  ...    274.967621    381.692657
# 11    431.120758    335.510895    355.180176  ...    262.336914    375.519836
# 12    544.705017    405.797211    418.006592  ...    369.914581    668.582764
# 13    974.247375    729.606628    701.898438  ...    717.710388   1119.431152
# 14    428.230347    348.279419    396.591858  ...    329.033875    472.753845
# 15    939.707031    564.506165    638.696716  ...    507.736786    809.971497
# 16    524.113342    411.366669    472.512054  ...    334.611969    565.732422
# 17    451.991547    328.853729    373.322693  ...    301.034180    525.222839
# 18   1029.989502    823.914673    810.875244  ...    779.644165    775.549622
# 19           NaN           NaN           NaN  ...           NaN           NaN
# 20    695.160400    805.097168    730.561523  ...    516.998169    841.799011
# 21    784.144714    680.016968   1002.779785  ...    761.466064    966.029480
# 22    705.826965    510.175995    607.865662  ...    604.123535    780.585510
# 23    983.160156    795.183044    841.881775  ...    950.361816   1039.586182
# 24    707.014587    934.858826    718.645874  ...    680.769592    941.972595
# 25    566.087402    693.563110    522.491333  ...    597.255249    873.314270
# 26    848.273315    574.211548    601.928650  ...    746.999573    965.995422
# 27   1053.376709    883.325317    872.865356  ...    881.967651   1044.132690
# 28   1053.104370    971.976379    998.429993  ...   1058.848022   1126.922119
# 29    578.778564    407.504211    437.650574  ...    806.282104    947.455688
# 30    395.184814    256.055542    312.617126  ...    222.532715    369.797211
#
#     biomass_2016  biomass_2017  biomass_2018  biomass_2019  biomass_2020  \
# 0     467.191315    615.905273    478.254791    434.525177    714.136902
# 1     477.707764    490.022614    480.411011    418.332520    560.940308
# 2     399.928101    434.612732    431.465637    378.262756    505.979706
# 3            NaN           NaN           NaN           NaN           NaN
# 4    1691.542358   1945.601929   1816.893677   1365.065308   1973.961060
# 5     412.766602    562.577576    411.958008    411.658356    465.735260
# 6     244.519592    265.284393    250.335251    254.687744    255.068298
# 7     205.888474    232.572906    215.731125    246.284225    249.831177
# 8     217.594849    236.406189    253.398880    245.119736    258.031128
# 9     251.039337    361.807617    229.932373    265.036041    363.710510
# 10    266.043488    378.523407    241.847824    267.323761    389.814178
# 11    249.687531    361.999756    234.102936    269.492859    398.049225
# 12    369.886169    505.491394    675.972778    384.359161    470.159119
# 13    761.646179    872.395020    800.138000    691.642395   1124.234375
# 14    300.441559    422.936493    313.756042    286.695892    543.611084
# 15    500.277344    790.875916    519.512817    620.624756    946.911804
# 16    359.775604    400.561066    912.296204    328.488251    654.536377
# 17    280.393707    302.622986    281.318665    288.022675    511.678162
# 18    766.673462   1013.814941    778.083557    753.842896   1094.224976
# 19           NaN           NaN           NaN           NaN           NaN
# 20    442.513336    439.480988    437.720612    426.317352    518.563416
# 21    570.443848   1159.304199    661.316833    669.801758    927.404968
# 22    597.300171    487.294708    600.094482    531.215332    785.536865
# 23    928.047546    931.910217    966.073730    969.026489   1108.160034
# 24    695.792786    598.664246    619.575806    574.401978    698.878784
# 25    537.537170    516.680115    516.220947    522.401245    570.532104
# 26    581.893494    624.188538    681.158752    663.015564    971.219055
# 27    865.995972   1020.771362    865.713440    879.585022    868.380554
# 28   1066.402466   1086.390259    974.697083    957.501526   1091.748291
# 29    760.211609    791.208008    631.176880    629.930176    830.889587
# 30    226.536346    372.142975    233.620468    249.775742    367.070190
#
#     biomass_2021  biomass_2022  biomass_2023
# 0     823.788635    479.731964    464.357910
# 1     493.276245    459.225952    502.592590
# 2     516.557861    391.161011    401.994263
# 3            NaN           NaN           NaN
# 4    1929.251587   1754.852905   1458.545532
# 5     575.580261    408.291718    419.075836
# 6     267.692810    293.230560    261.743652
# 7     214.575150    207.701630    215.857468
# 8     235.816574    237.069565    234.777466
# 9     365.909576    254.114487    320.252197
# 10    370.218231    254.134232    271.862732
# 11    368.151306    257.852875    271.058777
# 12    603.878601    355.689270    916.806274
# 13   1071.091309    780.271667    832.802063
# 14    468.616272    464.666687    351.859039
# 15    734.345398    503.080322    615.188171
# 16    495.078979    365.702393    403.559814
# 17    448.159882    320.579773    342.254150
# 18   1083.768555    818.363281    831.408081
# 19           NaN           NaN           NaN
# 20    454.475830    425.100616    571.178284
# 21    565.239319   1333.237549   1198.355103
# 22    730.699036    628.918091    593.870056
# 23   1101.747681    972.595581    974.015137
# 24    660.033142    697.426941    709.111206
# 25    544.994629    571.632385    524.108765
# 26    977.167114    696.566650    721.923462
# 27   1038.432861    864.384216    854.794678
# 28   1083.312134   1064.949463    985.661926
# 29   1100.889404    717.473511    689.125305
# 30    365.679565    248.875458    261.082672
#
# [31 rows x 46 columns]

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'fixed_restoration_window_trends_5.csv')

# points_gdf.to_csv(out_csv)

# %%
'''##Visualizing the window at each site and synthetic control

import rasterio
from rasterio.windows import Window

output_dir = "~/Downloads"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
filename = f"window_point_{idx}_year_{year}.gpkg"
output_path = os.path.join(output_dir, filename)

# 1. Start your loops
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    
    with rasterio.open(raster_path) as src:
        # 2. Iterate through each point
        for idx, row in points_gdf.iterrows():
            row_idx, col_idx = src.index(row.geometry.x, row.geometry.y)
            window = Window(col_idx - pad, row_idx - pad, win_size, win_size)
            data = src.read(1, window=window)
            
            # Define the transform for this specific window
            win_transform = src.window_transform(window)
            
            # --- EXPORT LOGIC STARTS HERE ---
            # Create a unique filename for every point-year combo
            filename = f"window_pt{idx}_yr{year}.gpkg"
            output_path = os.path.join(output_dir, filename)
            
            results = (
                {'properties': {'pixel_val': v}, 'geometry': s}
                for s, v in rasterio.features.shapes(data, transform=win_transform)
            )
            
            pixel_gdf = gpd.GeoDataFrame.from_features(list(results), crs=src.crs)
            pixel_gdf.to_file(output_path, driver="GPKG")
'''

# %%
# Hotspot data extraction

import geopandas as gpd
import rasterio
from rasterio.mask import mask
import numpy as np
import os
import glob
import pandas as pd

# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspots_theilsen_polyg_500k_m2.shp')
# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspots_theilsen_savan_100_m2.shp')
# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspot_jekyllish.shp')
# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspots_theilsen_sap_100.shp')
polygons = gpd.read_file('F:/Hotspots/Project shapefiles/all_100.shp')

# polygons = gpd.read_file('F:/GA_marsh_conservation/TLP_boundary.shp') ##NOTE PATHWAY - TLP FILE

raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))

# Initialize an empty list to store results for each polygon
results = []

# 2. Iterate through each raster
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Processing {year}...")
    
    with rasterio.open(raster_path) as src:
        # Ensure CRS matches
        if polygons.crs != src.crs:
            polygons = polygons.to_crs(src.crs)
            
        # Loop through each polygon
        for idx, row in polygons.iterrows():
            # Use rasterio.mask to clip the raster to the polygon geometry
            # crop=True keeps the resulting array small (the bounding box of the polygon)
            out_image, out_transform = mask(src, [row.geometry], crop=True, nodata=np.nan)
            
            # The mask returns an array [band, height, width]
            data = out_image[0]
            
            # Remove NaNs (NoData pixels)
            valid_pixels = data[~np.isnan(data)]
            
            # Calculate stats
            if valid_pixels.size > 0:
                mean_val = np.nanmean(valid_pixels)
                std_val = np.nanstd(valid_pixels)
            else:
                mean_val = np.nan
                std_val = np.nan
                
            results.append({
                'polygon_id': idx,
                'year': year,
                'mean': mean_val,
                'std': std_val
            })

# 3. Convert results to a DataFrame
stats_df = pd.DataFrame(results)

# Optional: Pivot to wide format if you want one column per year
pivot_df = stats_df.pivot(index='polygon_id', columns='year', values='mean')
print("Extraction complete!")
# Out:
# Processing 1984...
# Processing 1985...
# Processing 1986...
# Processing 1987...
# Processing 1988...
# Processing 1989...
# Processing 1990...
# Processing 1991...
# Processing 1992...
# Processing 1993...
# Processing 1994...
# Processing 1995...
# Processing 1996...
# Processing 1997...
# Processing 1998...
# Processing 1999...
# Processing 2000...
# Processing 2001...
# Processing 2002...
# Processing 2003...
# Processing 2004...
# Processing 2005...
# Processing 2006...
# Processing 2007...
# Processing 2008...
# Processing 2009...
# Processing 2010...
# Processing 2011...
# Processing 2012...
# Processing 2013...
# Processing 2014...
# Processing 2015...
# Processing 2016...
# Processing 2017...
# Processing 2018...
# Processing 2019...
# Processing 2020...
# Processing 2021...
# Processing 2022...
# Processing 2023...
# Extraction complete!

# %%
stats_df
# Out:
#     polygon_id  year        mean         std
# 0            0  1984  254.143982   42.131569
# 1            0  1985  402.975555   67.127029
# 2            0  1986  268.039551   47.658062
# 3            0  1987  329.259644   45.774506
# 4            0  1988  315.414368   59.511745
# 5            0  1989  389.488739   67.759819
# 6            0  1990  266.965729   51.324287
# 7            0  1991  292.584290   74.735641
# 8            0  1992  378.537872   65.980988
# 9            0  1993  258.746124   41.870255
# 10           0  1994  392.450562   66.619568
# 11           0  1995  414.394684   74.390862
# 12           0  1996  448.260010   93.124336
# 13           0  1997  278.543457   55.843845
# 14           0  1998  304.106140   68.271111
# 15           0  1999  233.383896   54.165909
# 16           0  2000  254.718887   43.180542
# 17           0  2001  258.083771   51.697971
# 18           0  2002  385.133209   65.777130
# 19           0  2003  282.770660   61.913216
# 20           0  2004  383.184479   76.028229
# 21           0  2005  389.362183   85.878426
# 22           0  2006  239.404449   46.359890
# 23           0  2007  377.917084   73.581497
# 24           0  2008  303.647705   45.996292
# 25           0  2009  409.477234   87.020454
# 26           0  2010  235.296722   47.960796
# 27           0  2011  237.875595   46.268948
# 28           0  2012  293.013916   58.771664
# 29           0  2013  519.540405  169.504715
# 30           0  2014  239.902008   49.093983
# 31           0  2015  400.271851  102.175514
# 32           0  2016  246.239426   61.624252
# 33           0  2017  388.704681   82.807236
# 34           0  2018  256.485779   75.845947
# 35           0  2019  264.490784   61.502945
# 36           0  2020  393.749451   98.201790
# 37           0  2021  395.133698   93.865562
# 38           0  2022  275.476624   68.277397
# 39           0  2023  309.650391   97.527046

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'tlp_trend_biomass.csv')

#stats_df.to_csv(out_csv)

# %%
#Fin
