# %%
import os
import glob
import rasterio
import geopandas as gpd
'''
# 1. Load the shapefile directly (GeoPandas automatically reads the UTM geometry and CRS)
# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids/gce_sites_zone_pixels_centroids.shp")
# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids2/gce_sites_zone_pixels_centroids2.shp")

# 2. Get the native CRS of your biomass models
raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))
with rasterio.open(raster_files[0]) as src:
    raster_crs = src.crs

# 3. Project the points to match the raster if they don't already
if points_gdf.crs != raster_crs:
    points_gdf = points_gdf.to_crs(raster_crs)

# Extract coordinates as a list of (x, y) tuples
coord_tuples = [(pt.x, pt.y) for pt in points_gdf.geometry]

# 4. Loop through the years and sample the data
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Extracting data for year: {year}...")
    
    with rasterio.open(raster_path) as src:
        # Sample the raster and append directly to the GeoDataFrame
        points_gdf[f"biomass_{year}"] = [val[0] for val in src.sample(coord_tuples)]

# 5. Save out the clean results
# You can save it back out as a flat CSV for them, or even a new shapefile/GeoJSON
points_gdf.drop(columns='geometry').to_csv("biomass_extractions_final.csv", index=False)
print("Done!")'''''
# Out:
# '\n# 1. Load the shapefile directly (GeoPandas automatically reads the UTM geometry and CRS)\n# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids/gce_sites_zone_pixels_centroids.shp")\n# points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids2/gce_sites_zone_pixels_centroids2.shp")\n\n# 2. Get the native CRS of your biomass models\nraster_files = sorted(glob.glob(\'F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif\'))\nwith rasterio.open(raster_files[0]) as src:\n    raster_crs = src.crs\n\n# 3. Project the points to match the raster if they don\'t already\nif points_gdf.crs != raster_crs:\n    points_gdf = points_gdf.to_crs(raster_crs)\n\n# Extract coordinates as a list of (x, y) tuples\ncoord_tuples = [(pt.x, pt.y) for pt in points_gdf.geometry]\n\n# 4. Loop through the years and sample the data\nfor raster_path in raster_files:\n    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")\n    print(f"Extracting data for year: {year}...")\n    \n    with rasterio.open(raster_path) as src:\n        # Sample the raster and append directly to the GeoDataFrame\n        points_gdf[f"biomass_{year}"] = [val[0] for val in src.sample(coord_tuples)]\n\n# 5. Save out the clean results\n# You can save it back out as a flat CSV for them, or even a new shapefile/GeoJSON\npoints_gdf.drop(columns=\'geometry\').to_csv("biomass_extractions_final.csv", index=False)\nprint("Done!")'

# %%
points_gdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 points_gdf
#
# NameError: name 'points_gdf' is not defined

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'rest_trends.csv')

#points_gdf.to_csv(out_csv)

# %%
##Window extraction around restoration points
import rasterio
from rasterio.windows import Window
import numpy as np
import pandas as pd
import geopandas as gpd
import glob
import os

# 1. Setup
'''points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/Restoration sites/Rest_sites.shp")
'''
raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))

# Load CSV
csv_path = "C:/Users/arj26323/Documents/Data/GA_conservation/fixed_actives_installations.csv" #UPDATED LIVINGSHORELINE LOCATIONS
df = pd.read_csv(csv_path)

# Create GeoDataFrame
points_gdf = gpd.GeoDataFrame(
    df, 
    geometry=gpd.points_from_xy(df.Longitude, df.Latitude),
    crs="EPSG:4326"
)

'''with rasterio.open(raster_files[0]) as src:
    raster_crs = src.crs
    if points_gdf.crs != raster_crs:
        points_gdf = points_gdf.to_crs(raster_crs)'''

# Define window size (e.g., 2x2)
win_size = 5
pad = win_size // 5

# 2. Loop through files
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Extracting window mean for year: {year}...")
    
    with rasterio.open(raster_path) as src:
        results = []
        for idx, row in points_gdf.iterrows():
            # Get pixel coordinates
            row_idx, col_idx = src.index(row.geometry.x, row.geometry.y)
            
            # Define the window
            window = Window(col_idx - pad, row_idx - pad, win_size, win_size)
            
            # Read the window data
            data = src.read(1, window=window)
            
            # Mask out nodata/NaN values
            # Replace 'src.nodata' with np.nan if your tiff uses actual NaNs
            if src.nodata is not None:
                data = np.where(data == src.nodata, np.nan, data)
                
            # Calculate mean ignoring NaNs
            if np.all(np.isnan(data)):
                results.append(np.nan)
            else:
                results.append(np.nanmean(data))
        
        points_gdf[f"biomass_{year}"] = results

# 3. Save
points_gdf.drop(columns='geometry').to_csv("biomass_extractions_5x5.csv", index=False)
print("Done!")
# Out:
# Extracting window mean for year: 1984...
# Extracting window mean for year: 1985...
# Extracting window mean for year: 1986...
# Extracting window mean for year: 1987...
# Extracting window mean for year: 1988...
# Extracting window mean for year: 1989...
# Extracting window mean for year: 1990...
# Extracting window mean for year: 1991...
# Extracting window mean for year: 1992...
# Extracting window mean for year: 1993...
# Extracting window mean for year: 1994...
# Extracting window mean for year: 1995...
# Extracting window mean for year: 1996...
# Extracting window mean for year: 1997...
# Extracting window mean for year: 1998...
# Extracting window mean for year: 1999...
# Extracting window mean for year: 2000...
# Extracting window mean for year: 2001...
# Extracting window mean for year: 2002...
# Extracting window mean for year: 2003...
# Extracting window mean for year: 2004...
# Extracting window mean for year: 2005...
# Extracting window mean for year: 2006...
# Extracting window mean for year: 2007...
# Extracting window mean for year: 2008...
# Extracting window mean for year: 2009...
# Extracting window mean for year: 2010...
# Extracting window mean for year: 2011...
# Extracting window mean for year: 2012...
# Extracting window mean for year: 2013...
# Extracting window mean for year: 2014...
# Extracting window mean for year: 2015...
# Extracting window mean for year: 2016...
# Extracting window mean for year: 2017...
# Extracting window mean for year: 2018...
# Extracting window mean for year: 2019...
# Extracting window mean for year: 2020...
# Extracting window mean for year: 2021...
# Extracting window mean for year: 2022...
# Extracting window mean for year: 2023...
# Done!

# %%
points_gdf
# Out:
#      Latitude  Longitude                                       Site name  \
# 0   31.122967 -81.477183                           Plantation Creek Site
# 1   31.838650 -81.153333                            Florida Passage Site
# 2   32.048017 -81.019233                                    Oatland Site
# 3   31.988800 -81.024883                             Skidaway River Site
# 4   31.326150 -81.322283            Estuaries Area of the Altamaha River
# 5   31.041650 -81.423017                    Jekyll Island Boat Ramp Site
# 6   32.002983 -80.917817                             Oyster Creek Site A
# 7   32.004417 -80.914883                             Oyster Creek Site B
# 8   32.007950 -80.911683                             Oyster Creek Site C
# 9   31.080800 -81.500217                     Jointer Creek Oyster Reef A
# 10  31.079600 -81.493967                     Jointer Creek Oyster Reef B
# 11  31.080583 -81.490783                     Jointer Creek Oyster Reef C
# 12  31.070400 -81.470050                     Jointer Creek Oyster Reef D
# 13  31.126267 -81.479067                                        Turtle A
# 14  31.194100 -81.531433                                        Turtle B
# 15  31.196383 -81.537950                                        Turtle C
# 16  31.183717 -81.530133                                        Turtle D
# 17  31.131267 -81.462183                                        Turtle E
# 18  31.531183 -81.358533                        Bellville Boat Ramp Site
# 19  31.151567 -81.476850                              Overlook Park Site
# 20  31.434344 -81.281177                       Ashantilly, Sapelo Island
# 21  31.431958 -81.282658                       Long Tabby, Sapelo Island
# 22  31.260096 -81.301873       Mosquito Creek, Little St. Simon's Island
# 23  31.260293 -81.340053     Cannon's Point Preserve, St. Simon's Island
# 24  31.951606 -81.055935     Skidaway Island State Park, Skidaway Island
# 25  32.007583 -80.851889                        Burton 4-H, Tybee Island
# 26  31.249585 -81.293448     Beach Road Bridge, Little St. Simons Island
# 27  30.950218 -81.421047                        Little Cumberland Island
# 28  31.053493 -81.414562                     Fortson Pond, Jekyll Island
# 29  31.123576 -81.477320  DNR's Coastal Regional Headquarters, Brunswick
# 30  31.087763 -81.433509                                      Jekyll TLP
#
#     year                  type                    geometry  biomass_1984  \
# 0   2010           Oyster Reef  POINT (-81.47718 31.12297)    359.861572
# 1   2012           Oyster Reef  POINT (-81.15333 31.83865)    467.979218
# 2   2014           Oyster Reef  POINT (-81.01923 32.04802)    466.399323
# 3   2010           Oyster Reef   POINT (-81.02488 31.9888)           NaN
# 4   2009           Oyster Reef  POINT (-81.32228 31.32615)    429.707520
# 5   2009           Oyster Reef  POINT (-81.42302 31.04165)    525.224426
# 6   2013           Oyster Reef  POINT (-80.91782 32.00298)    283.327515
# 7   2013           Oyster Reef  POINT (-80.91488 32.00442)    263.357117
# 8   2013           Oyster Reef  POINT (-80.91168 32.00795)    303.001709
# 9   2012           Oyster Reef   POINT (-81.50022 31.0808)    290.034821
# 10  2012           Oyster Reef   POINT (-81.49397 31.0796)    360.083252
# 11  2012           Oyster Reef  POINT (-81.49078 31.08058)    403.481079
# 12  2012           Oyster Reef   POINT (-81.47005 31.0704)    479.319977
# 13  2014           Oyster Reef  POINT (-81.47907 31.12627)    630.748474
# 14  2014           Oyster Reef   POINT (-81.53143 31.1941)    413.736511
# 15  2014           Oyster Reef  POINT (-81.53795 31.19638)    444.552399
# 16  2014           Oyster Reef  POINT (-81.53013 31.18372)    426.944366
# 17  2014           Oyster Reef  POINT (-81.46218 31.13127)    378.144653
# 18  2008           Oyster Reef  POINT (-81.35853 31.53118)    682.885620
# 19  2013           Oyster Reef  POINT (-81.47685 31.15157)           NaN
# 20  2010      Living Shoreline  POINT (-81.28118 31.43434)    725.934387
# 21  2010      Living Shoreline  POINT (-81.28266 31.43196)    869.103271
# 22  2013      Living Shoreline   POINT (-81.30187 31.2601)    465.416687
# 23  2015      Living Shoreline  POINT (-81.34005 31.26029)    680.660217
# 24  2015      Living Shoreline  POINT (-81.05594 31.95161)    714.109924
# 25  2015      Living Shoreline  POINT (-80.85189 32.00758)    598.268250
# 26  2017      Living Shoreline  POINT (-81.29345 31.24958)    582.118774
# 27  2020      Living Shoreline  POINT (-81.42105 30.95022)   1087.719849
# 28  2021      Living Shoreline  POINT (-81.41456 31.05349)    824.060059
# 29  2023      Living Shoreline  POINT (-81.47732 31.12358)    354.224915
# 30  2019  Thin Layer Placement  POINT (-81.43351 31.08776)    256.197388
#
#     biomass_1985  biomass_1986  biomass_1987  ...  biomass_2014  biomass_2015  \
# 0     517.220154    367.110535    404.826416  ...    396.410889    575.266785
# 1     520.887451    652.131104    520.747253  ...    390.632751    640.385864
# 2     424.682587    603.626221    472.495361  ...    426.259766    631.455261
# 3            NaN           NaN           NaN  ...           NaN           NaN
# 4     415.862732    341.976624    362.343506  ...   1787.974243   1959.631104
# 5     729.417542    580.894226    615.125427  ...    699.967163    800.085632
# 6     397.633209    396.362396    276.705017  ...    263.679810    373.867554
# 7     400.524597    376.023254    259.259338  ...    243.975906    375.204315
# 8     394.366333    393.221710    328.405792  ...    242.188736    352.372162
# 9     413.622101    315.562347    350.982605  ...    312.176910    473.172668
# 10    505.043396    386.306763    439.254333  ...    400.808228    559.189331
# 11    538.428711    433.935364    490.824493  ...    424.181702    583.799683
# 12    622.823914    460.333160    512.551941  ...    539.201111    917.890869
# 13    852.181458    656.575684    652.729858  ...    664.618408    935.971497
# 14    524.034668    414.742676    479.373871  ...    386.987427    586.060059
# 15    670.876038    455.227753    522.803467  ...    399.284760    612.394043
# 16    593.958435    427.563385    463.665161  ...    384.583221    616.512146
# 17    541.442810    350.475464    381.806824  ...    369.130646    611.800415
# 18    890.277588    694.098450    714.366089  ...    675.892517    688.932495
# 19           NaN           NaN           NaN  ...           NaN           NaN
# 20    695.160400    805.097168    730.561523  ...    516.998169    841.799011
# 15    586.997375    396.373871    469.911285
# 16    561.080017    404.480225    434.706665
# 17    549.435669    393.562744    420.936737
# 18    940.462708    698.483582    697.518250
# 19           NaN           NaN           NaN
# 20    454.475830    425.100616    571.178284
# 21    565.239319   1333.237671   1198.355103
# 22    632.923523    494.546814    499.524475
# 23    854.058105    689.952087    725.390991
# 24    628.985291    654.156921    652.555298
# 25    642.499939    642.576599    615.317505
# 26    995.127686    750.734741    759.299622
# 27   1191.869995   1067.363403   1010.831848
# 28   1012.622314    900.052429    821.505371
# 29    741.955994    517.292053    497.761597
# 30    389.305511    268.135254    303.691498
#
# [31 rows x 46 columns]

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'fixed_restoration_window_trends_5.csv')

# points_gdf.to_csv(out_csv)

# %%
# 1. Setup

import geopandas as gpd
import rasterio
from rasterio.mask import mask
import numpy as np
import os
import glob
import pandas as pd

# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspots_theilsen_polyg_500k_m2.shp')
# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspots_theilsen_savan_100_m2.shp')
# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspot_jekyllish.shp')
# polygons = gpd.read_file('F:/Hotspots/Project shapefiles/hotspots_theilsen_sap_100.shp')
polygons = gpd.read_file('F:/Hotspots/Project shapefiles/all_100.shp')

raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))

# Initialize an empty list to store results for each polygon
results = []

# 2. Iterate through each raster
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Processing {year}...")
    
    with rasterio.open(raster_path) as src:
        # Ensure CRS matches
        if polygons.crs != src.crs:
            polygons = polygons.to_crs(src.crs)
            
        # Loop through each polygon
        for idx, row in polygons.iterrows():
            # Use rasterio.mask to clip the raster to the polygon geometry
            # crop=True keeps the resulting array small (the bounding box of the polygon)
            out_image, out_transform = mask(src, [row.geometry], crop=True, nodata=np.nan)
            
            # The mask returns an array [band, height, width]
            data = out_image[0]
            
            # Remove NaNs (NoData pixels)
            valid_pixels = data[~np.isnan(data)]
            
            # Calculate stats
            if valid_pixels.size > 0:
                mean_val = np.nanmean(valid_pixels)
                std_val = np.nanstd(valid_pixels)
            else:
                mean_val = np.nan
                std_val = np.nan
                
            results.append({
                'polygon_id': idx,
                'year': year,
                'mean': mean_val,
                'std': std_val
            })

# 3. Convert results to a DataFrame
stats_df = pd.DataFrame(results)

# Optional: Pivot to wide format if you want one column per year
pivot_df = stats_df.pivot(index='polygon_id', columns='year', values='mean')
print("Extraction complete!")
# Out:
# Processing 1984...
# Processing 1985...
# Processing 1986...
# Processing 1987...
# Processing 1988...
# Processing 1989...
# Processing 1990...
# Processing 1991...
# Processing 1992...
# Processing 1993...
# Processing 1994...
# Processing 1995...
# Processing 1996...
# Processing 1997...
# Processing 1998...
# Processing 1999...
# Processing 2000...
# Processing 2001...
# Processing 2002...
# Processing 2003...
# Processing 2004...
# Processing 2005...
# Processing 2006...
# Processing 2007...
# Processing 2008...
# Processing 2009...
# Processing 2010...
# Processing 2011...
# Processing 2012...
# Processing 2013...
# Processing 2014...
# Processing 2015...
# Processing 2016...
# Processing 2017...
# Processing 2018...
# Processing 2019...
# Processing 2020...
# Processing 2021...
# Processing 2022...
# Processing 2023...
# Extraction complete!

# %%
stats_df
# Out:
#       polygon_id  year        mean         std
# 0              0  1984  465.578949   34.439026
# 1              1  1984  465.542297   33.199669
# 2              2  1984  476.600403   42.166412
# 3              3  1984  456.660065   25.501823
# 4              4  1984  418.759491   69.571579
# ...          ...   ...         ...         ...
# 3715          88  2023  345.837524  270.438843
# 3716          89  2023  249.398560   40.118248
# 3717          90  2023  399.588562  355.779602
# 3718          91  2023  465.820587  147.515091
# 3719          92  2023  445.692535  136.354080
#
# [3720 rows x 4 columns]

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'all_10hectare_hotspots_trends.csv')

#stats_df.to_csv(out_csv)

# %%
#Fin
