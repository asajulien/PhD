# %%
import os
import glob
import rasterio
import geopandas as gpd

# 1. Load the shapefile directly (GeoPandas automatically reads the UTM geometry and CRS)
points_gdf = gpd.read_file("C:/Users/arj26323/Documents/Data/Pennings_validation_points/gce_sites_zone_pixels_centroids/gce_sites_zone_pixels_centroids.shp")

# 2. Get the native CRS of your biomass models
raster_files = sorted(glob.glob('F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final/*.tif'))
with rasterio.open(raster_files[0]) as src:
    raster_crs = src.crs

# 3. Project the points to match the raster if they don't already
if points_gdf.crs != raster_crs:
    points_gdf = points_gdf.to_crs(raster_crs)

# Extract coordinates as a list of (x, y) tuples
coord_tuples = [(pt.x, pt.y) for pt in points_gdf.geometry]

# 4. Loop through the years and sample the data
for raster_path in raster_files:
    year = os.path.basename(raster_path).split("_")[-1].replace(".tif", "")
    print(f"Extracting data for year: {year}...")
    
    with rasterio.open(raster_path) as src:
        # Sample the raster and append directly to the GeoDataFrame
        points_gdf[f"biomass_{year}"] = [val[0] for val in src.sample(coord_tuples)]

# 5. Save out the clean results
# You can save it back out as a flat CSV for them, or even a new shapefile/GeoJSON
points_gdf.drop(columns='geometry').to_csv("biomass_extractions_final.csv", index=False)
print("Done!")
# Out:
# Extracting data for year: 1984...
# Extracting data for year: 1985...
# Extracting data for year: 1986...
# Extracting data for year: 1987...
# Extracting data for year: 1988...
# Extracting data for year: 1989...
# Extracting data for year: 1990...
# Extracting data for year: 1991...
# Extracting data for year: 1992...
# Extracting data for year: 1993...
# Extracting data for year: 1994...
# Extracting data for year: 1995...
# Extracting data for year: 1996...
# Extracting data for year: 1997...
# Extracting data for year: 1998...
# Extracting data for year: 1999...
# Extracting data for year: 2000...
# Extracting data for year: 2001...
# Extracting data for year: 2002...
# Extracting data for year: 2003...
# Extracting data for year: 2004...
# Extracting data for year: 2005...
# Extracting data for year: 2006...
# Extracting data for year: 2007...
# Extracting data for year: 2008...
# Extracting data for year: 2009...
# Extracting data for year: 2010...
# Extracting data for year: 2011...
# Extracting data for year: 2012...
# Extracting data for year: 2013...
# Extracting data for year: 2014...
# Extracting data for year: 2015...
# Extracting data for year: 2016...
# Extracting data for year: 2017...
# Extracting data for year: 2018...
# Extracting data for year: 2019...
# Extracting data for year: 2020...
# Extracting data for year: 2021...
# Extracting data for year: 2022...
# Extracting data for year: 2023...
# Done!

# %%
points_gdf
# Out:
#                 pix  utm_east  utm_north     ID       zone  site  \
# 0    471750 3489270  471750.0  3489270.0      6  creekbank   2.0
# 1    471750 3489240  471750.0  3489240.0      7  creekbank   2.0
# 2    471750 3489210  471750.0  3489210.0      8  creekbank   2.0
# 3    471750 3489180  471750.0  3489180.0      9  creekbank   2.0
# 4    471750 3489150  471750.0  3489150.0     10  creekbank   2.0
# ..              ...       ...        ...    ...        ...   ...
# 256  474420 3482430  474420.0  3482430.0     39   midmarsh  10.0
# 257  474420 3482280  474420.0  3482280.0     40  creekbank  10.0
# 258  474420 3482460  474420.0  3482460.0  39999   midmarsh  10.0
# 259  474390 3482490  474390.0  3482490.0  31999   midmarsh  10.0
# 260  474300 3482640  474300.0  3482640.0  21999   midmarsh  10.0
#
#                        geometry  biomass_1984  biomass_1985  biomass_1986  \
# 0     POINT (-81.2976 31.53803)    317.603699    443.674164    309.249481
# 1     POINT (-81.2976 31.53776)    298.106903    364.171295    294.213318
# 2     POINT (-81.2976 31.53749)    307.131012    374.890747    338.152985
# 3     POINT (-81.2976 31.53722)    315.141541    386.412445    321.520966
# 4     POINT (-81.2976 31.53695)    402.260803    529.122498    389.755737
# ..                          ...           ...           ...           ...
# 256   POINT (-81.2693 31.47638)    368.385223    442.159729    343.353119
# 257  POINT (-81.26929 31.47503)    463.889893    389.966248    382.597992
# 258   POINT (-81.2693 31.47665)    397.934235    375.327515    358.440125
# 259  POINT (-81.26961 31.47692)    371.936157    381.310242    350.471802
# 260  POINT (-81.27056 31.47827)    516.771484    623.864014    414.523010
#
#      ...  biomass_2014  biomass_2015  biomass_2016  biomass_2017  \
# 0    ...    338.226105    388.722870    339.977814    426.279999
# 1    ...    363.390778    392.903992    350.487854    532.692505
# 2    ...    350.278534    410.802338    345.062958    541.610840
# 3    ...    338.907806    387.094635    351.648621    442.065399
# 4    ...    368.923218    442.050568    363.477112    588.417053
# ..   ...           ...           ...           ...           ...
# 256  ...    230.338669    391.090454    229.830490    261.774261
# 257  ...    300.079041    440.825500    319.928467    373.444275
# 258  ...    218.163406    379.264893    215.010300    252.707535
# 259  ...    214.088318    383.266418    224.834854    256.055756
# 260  ...    315.276672    466.760986    311.050873    351.482819
#
#      biomass_2018  biomass_2019  biomass_2020  biomass_2021  biomass_2022  \
# 0      367.906708    278.811920    469.260712    538.787903    334.009583
# 1      379.453979    353.225586    547.388245    551.226624    346.061737
# 2      379.655701    352.275482    545.239685    541.496094    362.297150
# 3      387.486603    358.333649    542.984680    537.500793    360.061310
# 4      414.012085    321.041046    574.971436    587.230286    385.602173
# ..            ...           ...           ...           ...           ...
# 256    225.293015    232.090836    326.640289    338.246033    231.393448
# 257    300.873840    322.532684    419.547852    464.822723    318.363068
# 258    215.150436    205.272339    312.800537    325.592010    227.951553
# 259    212.865143    208.000168    314.297394    332.948364    228.090881
# 260    334.854767    333.339539    454.505737    532.950684    442.661102
#
#      biomass_2023
# 0      359.638672
# 1      490.392242
# 2      379.395447
# 3      386.965057
# 4      501.821381
# ..            ...
# 256    350.627228
# 257    484.971619
# 258    316.212219
# 259    348.005188
# 260    412.409027
#
# [261 rows x 47 columns]

# %%
##Exporting extraction

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'EOY_AGB_point_extraction.csv')

#points_gdf.to_csv(out_csv)
