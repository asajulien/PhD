# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdb
from IPython.display import display
import os

# %%
import ee
import geemap
service_account = ' boba-account@boba-430314.iam.gserviceaccount.com '
credentials = ee.ServiceAccountCredentials(service_account,'C:/Users/arj26323/OneDrive - University of Georgia/Documents/GEE AUTH/boba-430314-a19be859bfca.json')

ee.Initialize(credentials)

print(geemap.__version__)
# Out:
# 0.34.1

# %%
import rasterio
import numpy as np
import glob
import os

## Directory where rasters are stored
# raster_dir = "F:\\Biomass tiffs\\Output\\Clippy"

#Updated: 08/05/2025 - to reflect 'final' model
# raster_dir = "F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/GEE_Exports"
# raster_dir = "F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/log_model"
# raster_dir = "F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_results"
# raster_dir = "F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_smoothed"
raster_dir = "F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/LOGO_final"


# #All of GA coast:
# raster_dir = "F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/all_coast_ga"

raster_files = sorted(glob.glob(os.path.join(raster_dir, "*.tif")))

# Optionally extract years from filenames
# years = [int(os.path.basename(f)[4:8]) for f in raster_files] #For non-clipped output
years = [int(os.path.basename(f).split('_')[-1].split('.')[0]) for f in raster_files]

##ADDED
years = np.array(years)

# Load stack: shape (time, rows, cols)
stack = []
for file in raster_files:
    with rasterio.open(file) as src:
        stack.append(src.read(1).astype(np.float32))  # Ensure float for NaNs
        profile = src.profile  # Save profile from one file to write output later

stack = np.stack(stack)  # (time, rows, cols)

# Mask no-data values (assuming 0 or some other value is nodata)
stack[stack == profile['nodata']] = np.nan  # Or pick your own nodata value



    ##OLD
# # Read all rasters into a 3D array (time, rows, cols)
# stack = []
# for file in raster_files:
#     with rasterio.open(file) as src:
#         stack.append(src.read(1))  # Read first band

# stack = np.stack(stack)  # Shape: (years, rows, cols)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
'''##Non-parametric technique with considerations for p-values:
import os
import glob
import numpy as np
import rasterio
import pymannkendall as pmk
from statsmodels.stats.multitest import multipletests

rows, cols = stack.shape[1:]

# Initialize empty arrays for the Theil-Sen slope and raw p-values
slope_array = np.full((rows, cols), np.nan, dtype=np.float32)
pval_array = np.full((rows, cols), np.nan, dtype=np.float32)

print("Calculating Yue-Pilon pre-whitened Mann-Kendall and Theil-Sen slopes per pixel...")

# 1. Calculate non-parametric slope + p-value per pixel
for i in range(rows):
    # Optional progress tracker since this takes longer than OLS
    if i % 100 == 0: 
        print(f"Processing row {i} of {rows}...")
        
    for j in range(cols):
        y = stack[:, i, j]

        # Remove NaNs BEFORE running Mann-Kendall
        y_clean = y[np.isfinite(y)]

        if len(y_clean) >= 20 and np.std(y_clean) > 0:
            try:
                res = pmk.yue_wang_modification_test(y_clean)

                slope_array[i, j] = res.slope
                pval_array[i, j] = res.p

            except Exception as e:
                print(f"Error at pixel ({i},{j}): {e}")

# 2. Save the Master Theil-Sen Slope Raster
slope_out = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_1984to2023_Thiel_Sen.tif"
profile.update(dtype=rasterio.float32, count=1, nodata=np.nan)
with rasterio.open(slope_out, 'w', **profile) as dst:
    dst.write(slope_array, 1)
print(f"Master Theil-Sen Slope map saved: {slope_out}")

# ==========================================
# 3. APPLY BENJAMINI-HOCHBERG FDR CORRECTION
# ==========================================
print("Applying Benjamini-Hochberg False Discovery Rate adjustment...")

# Isolate valid, calculated p-values to feed into the multiple-test corrector
valid_p_mask = ~np.isnan(pval_array)
flat_p_values = pval_array[valid_p_mask]

# Initialize a blank boolean array for the final significance mask
sig_mask = np.zeros_like(pval_array, dtype=bool)

if len(flat_p_values) > 0:
    # reject: boolean array showing True where trends survive FDR correction at alpha=0.05
    reject, _, _, _ = multipletests(flat_p_values, alpha=0.05, method='fdr_bh')
    
    # Map the 1D results back onto your 2D spatial grid
    sig_mask[valid_p_mask] = reject

# ==========================================
# 4. SAVE THE SIGNIFICANT SLOPES RASTER
# ==========================================
sig_slopes = np.where(sig_mask, slope_array, np.nan)
sig_out = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_Thiel_Sen.tif"
with rasterio.open(sig_out, 'w', **profile) as dst:
    dst.write(sig_slopes, 1)

print(f"FDR-Significant slope map saved: {sig_out}")'''
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...

# %%
# import os
# import glob
# import numpy as np
# import rasterio
# from scipy.stats import linregress

# rows, cols = stack.shape[1:]
# slope_array = np.full((rows, cols), np.nan, dtype=np.float32)
# pval_array = np.full((rows, cols), np.nan, dtype=np.float32)

# # Calculate slope + p-value per pixel
# for i in range(rows):
#     for j in range(cols):
#         y = stack[:, i, j]
#         if np.isfinite(y).sum() > 1:  # need at least 2 points
#             res = linregress(years, y)
#             slope_array[i, j] = res.slope
#             pval_array[i, j] = res.pvalue

# # Save slope raster
# slope_out = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_1984to2023_final.tif"
# profile.update(dtype=rasterio.float32, count=1, nodata=np.nan)
# with rasterio.open(slope_out, 'w', **profile) as dst:
#     dst.write(slope_array, 1)

# # Save significant slopes only (p < 0.05)
# sig_mask = (pval_array < 0.05)
# sig_slopes = np.where(sig_mask, slope_array, np.nan)
# sig_out = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_final.tif"
# with rasterio.open(sig_out, 'w', **profile) as dst:
#     dst.write(sig_slopes, 1)

# print(f"Slope map saved: {slope_out}")
# print(f"Significant slope map saved: {sig_out}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# #Clipping to GA_estuaries file
# import geopandas as gpd
# import rasterio
# from rasterio.mask import mask
# import matplotlib.pyplot as plt

# # Paths
# # raster_path = out_path  OLD
# raster_path = slope_out
# # raster_path = sig_out
# # raster_path = "F:/Biomass tiffs/Biomass modeling/Georgia/Georgia model only/GEE_Exports/abg_2023.tif"

# # shapefile_path = "F:/Wetlands shapefiles/GA_shapefile_wetlands/GA_estuaries.shp"

# # Load the shapefile
# gdf = gpd.read_file(shapefile_path)
# gdf = gdf.to_crs("EPSG:4326")  # Optional: match CRS if needed

# # Open the raster and clip it
# with rasterio.open(raster_path) as src:
#     # Ensure CRS matches
#     if src.crs != gdf.crs:
#         gdf = gdf.to_crs(src.crs)

#     # Convert GeoDataFrame geometry to GeoJSON-like mapping
#     shapes = gdf.geometry.values
#     out_image, out_transform = mask(src, shapes, crop=True)
#     out_meta = src.meta.copy()

# # Update metadata to match clipped output
# out_meta.update({
#     "height": out_image.shape[1],
#     "width": out_image.shape[2],
#     "transform": out_transform
# })

# # Plot the clipped prediction
# plt.figure(figsize=(10, 8))
# plt.imshow(out_image[0], cmap='viridis')
# plt.colorbar(label='Predicted Value')
# plt.title("Clipped Model Predictions")
# plt.axis('off')
# plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# #Export clipped image
# clipped_path = f"F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/CLIPPED_TESTtrend_sig_1984to2023.tif"
# with rasterio.open(clipped_path, "w", **out_meta) as dest:
#     dest.write(out_image)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
##Point time series visualization
from rasterio.transform import rowcol

'''# lat, lon = 31.43, -81.29  #Negative - Airport marsh?

# lat, lon = 31.32881, -81.39192  #Negative - Juncus?  old ones'''

lat, lon = 31.30184, -81.28859 #Positive - accretion

lat, lon = 31.86948, -81.00784 ## Great example of an eroding marsh

lat, lon = 31.68917, -81.25666 ##Intermediate - decline seems likely

lat, lon = 31.81021, -81.060884 ##Suspect - most likely not a real signal, even though it's significant

lat, lon = 31.82556, -81.07738 ##Something weird going on - error in model

lat, lon = 31.833894, -81.08675 ## Intermediate but noisy, most likely decline (slope of -7)

lat, lon = 31.30407, -81.38318 ##Juncus, mid-coast, slope of 14, clear increase

lat, lon = 30.828699, -81.614158 ##South Georgia region, intermediate pixel (slope -8), steady decline


###PICKING SPOTS WITH RELEVANCE TO THE 'STORY':

lat, lon = 31.0813, -81.4303 ##By TLP experiment; kind of messy, but shows the trend at least


# # lat, lon = 30.8405, -81.5989 ##Freshwater S. Georgia declining area, moderate decline
# lat, lon = 30.8576, -81.6142 ##Brackish S. Georgia declining area, moderate decline




with rasterio.open(raster_files[0]) as src:
    row, col = rowcol(src.transform, lon, lat)  # note: lon first, then lat

pixel_values = stack[:, row, col]

plt.figure(figsize=(8, 5))
plt.plot(years, pixel_values, marker='o', linestyle='')
plt.xlabel("")
plt.ylabel("EOY Biomass (g/m^2)")
plt.title(f"Time series at ({lat}, {lon})")
plt.grid(False)
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
##Ultimap

import matplotlib.pyplot as plt
import numpy as np
import rasterio
from rasterio.plot import show
from rasterio.transform import rowcol

import geopandas as gpd

##Base trend layer directory:
# base_layer = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_1984to2023_final.tif"
base_layer = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_final.tif"
# base_layer = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_Thiel_Sen.tif"


base_shape = "F:/Wetlands shapefiles/GA_shapefile_wetlands/GA_estuaries.shp"
gdf = gpd.read_file(base_shape)

# 1. Define your 4 target pixels (lat, lon) IN ORDER N TO S!
sites = {
    "A": (31.86948, -81.00784), ##Steep decline
    "B": (31.44690, -81.22984), ##moderate increase
    "C": (31.30184, -81.28859), ##steep increase
    "D": (30.828699, -81.614158) ##intermediate decline
}

# 2. Define Layout (2 columns: Map is 'M', Plots are A-D)
layout = """
         MA
         MB
         MC
         MD
         """
# Now width_ratios=[3, 1] works because the layout has exactly 2 columns
fig, axd = plt.subplot_mosaic(layout, figsize=(16, 12), 
                               gridspec_kw={'width_ratios': [3, 1]})


# --- 1. PLOT THE MAP ---

from matplotlib.colors import LinearSegmentedColormap

# ## Define colors: Brown -> Light Green -> Green
# positions = [0, 0.25, 0.75, 1]
# colors = ["#8B4513", "#8B4513", "#ADFF2F", "#006400"] 

## Define colors: Brown -> Ivory -> Green
positions = [0, 0.25, 0.5, 1]
colors = ["#8B4513", "#8B4513", "#FFFFCB", "#006400"] 

# positions = [0, 0.5, 1]
# colors = ["#8B4513", "#FFFFCB", "#006400"] 

# positions = [0, 1]
# colors = ["#8B4513", "#006400"] 

cmap_name = "brown_to_green"
custom_cmap = LinearSegmentedColormap.from_list(cmap_name, list(zip(positions, colors)), N=256)

with rasterio.open(base_layer) as src2:
    gdf = gdf.to_crs(src2.crs)
    img = axd['M'].imshow(src2.read(1), cmap=custom_cmap, interpolation = 'nearest',
                          extent=[src2.bounds.left, src2.bounds.right, 
                                  src2.bounds.bottom, src2.bounds.top])
    left, bottom, right, top = src2.bounds
    
        # Add markers for each site
    for name, (lat, lon) in sites.items():
        axd['M'].plot(lon, lat, marker='o', color='red', markersize=8, markeredgecolor='black')
        axd['M'].text(lon, lat, f' {name}', color='black', fontweight='bold')
    
    #Keep map zoomed in
    axd['M'].set_xlim(left, right)
    axd['M'].set_ylim(bottom, top)
    
    # Overlay the shapefile
    gdf.plot(ax=axd['M'], facecolor='none', edgecolor='black', linewidth=0.1, zorder = 2)

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
cbaxes = inset_axes(axd['M'], width="3%", height="30%", loc=2) 
plt.colorbar(img, cax = cbaxes, label='AGB trend (g/$m^2$)')

# Axis Labels
ax_m = axd['M']
ax_m.set_xlabel("Longitude", fontsize=12)
ax_m.set_ylabel("Latitude", fontsize=12)

# Add North Arrow
x, y, arrow_length = 0.15, 0.99, 0.05
axd['M'].annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
                  arrowprops=dict(facecolor='black', width=5, headwidth=15),
                  ha='center', va='center', fontsize=20, xycoords='axes fraction')

# --- 2. EXTRACT DATA & FIND GLOBAL LIMITS ---
all_pixel_data = {}
for name, (lat, lon) in sites.items():
    with rasterio.open(raster_files[0]) as src:
        row, col = rowcol(src.transform, lon, lat)
    all_pixel_data[name] = stack[:, row, col]

# Determine global Y-axis scale for standardization
y_min = min([d.min() for d in all_pixel_data.values()]) * 0  ##or 0.9
y_max = max([d.max() for d in all_pixel_data.values()]) * 1.1

# --- 5. ADD SCALE BAR (Calculated for Georgia's latitude) ---
# At ~30.8°N, 1 degree lon is roughly 95.6 km. 
# So, 10km is ~0.1046 degrees.
scale_len_deg = 10 / 95.6  
sb_x = left + (right - left) * 0.80 # Start 80% from left
sb_y = bottom + (top - bottom) * 0.96 # Start 96% from bottom

axd['M'].plot([sb_x, sb_x + scale_len_deg], [sb_y, sb_y], color='black', lw=3, zorder=5)
axd['M'].text(sb_x + (scale_len_deg/2), sb_y + (top-bottom)*0.02, '10 km', 
              ha='center', va='bottom', fontsize=10, fontweight='bold')



# --- 3. PLOT STANDARDIZED TIME SERIES ---

from matplotlib.patches import ConnectionPatch

# for i, (name, data) in enumerate(all_pixel_data.items()):
#     ax_key = list("ABCD")[i]
#     ax = axd[ax_key]
    
#     ax.scatter(years, data, s=10, color='black', alpha=0.6)
    
#     # Standardize Axes
#     ax.set_ylim(y_min, y_max)
#     ax.set_title(f"Site {name}", fontsize=10)
    
# #     #Clean up labels for the stack
# #     if ax_key != 'D': ax.set_xticklabels([]) 
        
#     ax.set_title(name)
#     ax.set_ylabel("AGB (g/$m^2$)")
#     if i == 0: ax.set_xlabel("")
        
# --- 4. TRENDLINES & CONNECTING LINES ---
import seaborn as sns

site_colors = dict(zip(sites.keys(), sns.color_palette("tab10", len(sites))))

for i, (name, (lat, lon)) in enumerate(sites.items()):
    ax_key = list("ABCD")[i]
    ax_t = axd[ax_key]
    data = all_pixel_data[name]
    
    color = site_colors[name]   # <- shared color for this site
    
    # Plot Trend
    ax_t.scatter(years, data, s=20, color=color, alpha=0.8)
    m, b = np.polyfit(years, data, 1)
#     ax_t.plot(years, m*years + b, color='red', lw=1.5)
    
    # Standardize axes
    ax_t.set_ylim(y_min, y_max)
    ax_t.set_title(f"Site {name}", fontsize=10, color = color)
    
    # DRAW CONNECTION LINE
    # This connects the point on the map to the Y-axis of the trendline
    con = ConnectionPatch(xyA=(lon, lat), xyB=(years[0], np.mean(data)), 
                          coordsA=ax_m.transData, coordsB=ax_t.transData,
                          arrowstyle="-", color="gray", linestyle=":", 
                          alpha=0.6, zorder=10)
    fig.add_artist(con)
    
    # Mark the point on the map
    ax_m.plot(lon, lat, 'o', markersize=8, markeredgecolor='black', zorder=11)
    
    ax_t.set_title(name)
    ax_t.set_ylabel("AGB (g/$m^2$)")
    if i == 0: ax_t.set_xlabel("")

# fig.suptitle("Long-term Biomass Trends: Georgia Coast", fontsize=16)
# plt.tight_layout()

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.patches as patches

# 1. Create the inset axis (loc=4 is lower right, loc=1 is upper right)
ax_inset = inset_axes(axd['M'], width="20%", height="20%", loc=4, borderpad=3)

# 2. Load and plot the Georgia Shapefile
ga_gdf = gpd.read_file("F:/US states/Georgia.shp")
ga_gdf = ga_gdf.to_crs(src2.crs) # Match CRS to your raster
ga_gdf.plot(ax=ax_inset, facecolor='#f0f0f0', edgecolor='black', linewidth=0.5)

# 3. Add a "You Are Here" rectangle
# Using the 'left, bottom, right, top' variables you already defined from src2.bounds
rect = patches.Rectangle((left, bottom), right - left, top - bottom, 
                         linewidth=1.5, edgecolor='red', facecolor='none', zorder=10)
ax_inset.add_patch(rect)

# 4. Clean up the inset (remove coordinates/spines for a "clean" look)
ax_inset.set_xticks([])
ax_inset.set_yticks([])
for spine in ax_inset.spines.values():
    spine.set_visible(False)
    

##Save at high res
import os
output_dir = r'F:\Figures_PaperII'
file_name = 'MAPPY_XY.tif'

save_path = os.path.join(output_dir, file_name)

# plt.savefig(save_path, bbox_inches='tight', dpi=300)

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
##Ultimap - Zonal statistics, aggregating trends

import matplotlib.pyplot as plt
import numpy as np
import rasterio
from rasterio.plot import show
from rasterio.transform import rowcol

import geopandas as gpd

##Base trend layer directory:
# base_layer = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_final.tif"
base_layer = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_Thiel_Sen.tif"

base_shape = "F:/Wetlands shapefiles/GA_shapefile_wetlands/GA_estuaries.shp"
gdf = gpd.read_file(base_shape)

# 1. Define your 4 target pixels (lat, lon) IN ORDER N TO S!
sites = {
    "A": (31.86948, -81.00784), ##Steep decline
    "B": (31.44690, -81.22984), ##moderate increase
    "C": (31.30184, -81.28859), ##steep increase
    "D": (30.828699, -81.614158) ##intermediate decline
}

# 2. Define Layout (2 columns: Map is 'M', Plots are A-D)
layout = """
         MA
         MB
         MC
         MD
         """
# Now width_ratios=[3, 1] works because the layout has exactly 2 columns
fig, axd = plt.subplot_mosaic(layout, figsize=(16, 12), 
                               gridspec_kw={'width_ratios': [3, 1]})


# --- 1. PLOT THE MAP ---

from matplotlib.colors import LinearSegmentedColormap

# ## Define colors: Brown -> Light Green -> Green
# positions = [0, 0.25, 0.75, 1]
# colors = ["#8B4513", "#8B4513", "#ADFF2F", "#006400"] 

## Define colors: Brown -> Ivory -> Green
positions = [0, 0.25, 0.5, 0.75, 1]
colors = ["#8B4513", "#8B4513", "#FFFFCB", "#006400", "#006400"]

# positions = [0, 1]
# colors = ["#8B4513", "#006400"] 

cmap_name = "brown_to_green"
custom_cmap = LinearSegmentedColormap.from_list(cmap_name, list(zip(positions, colors)), N=256)

##Pixel counts
with rasterio.open(base_layer) as src:
    data = src.read(1) # Read the first band
    is_not_nan = ~np.isnan(data) & (data < 0)  ##DECLINING  
    total_valid_pixels = np.sum(is_not_nan)    
    print(f"Total pixels (including zeros, excluding NaNs): {total_valid_pixels}")

##Mapping
with rasterio.open(base_layer) as src2:
    gdf = gdf.to_crs(src2.crs)
    img = axd['M'].imshow(src2.read(1), cmap=custom_cmap, interpolation = 'nearest',
                          extent=[src2.bounds.left, src2.bounds.right, 
                                  src2.bounds.bottom, src2.bounds.top])
    left, bottom, right, top = src2.bounds
    
        # Add markers for each site
    for name, (lat, lon) in sites.items():
        axd['M'].plot(lon, lat, marker='o', color='red', markersize=8, markeredgecolor='black')
        axd['M'].text(lon, lat, f' {name}', color='black', fontweight='bold')
    
    #Keep map zoomed in
    axd['M'].set_xlim(left, right)
    axd['M'].set_ylim(bottom, top)
    
    # Overlay the shapefile
    gdf.plot(ax=axd['M'], facecolor='none', edgecolor='black', linewidth=0.1, zorder = 2)

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
cbaxes = inset_axes(axd['M'], width="3%", height="30%", loc=2) 
plt.colorbar(img, cax = cbaxes, label='AGB trend (g/$m^2$)')

# Axis Labels
ax_m = axd['M']
ax_m.set_xlabel("Longitude", fontsize=12)
ax_m.set_ylabel("Latitude", fontsize=12)

# Add North Arrow
x, y, arrow_length = 0.15, 0.99, 0.05
axd['M'].annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
                  arrowprops=dict(facecolor='black', width=5, headwidth=15),
                  ha='center', va='center', fontsize=20, xycoords='axes fraction')


import numpy as np
from rasterio.transform import rowcol

# --- 2. EXTRACT DATA WITH SPATIAL MEAN ---
all_pixel_data = {}
all_pixel_std = {}
offset = 1  # This creates a 3x3 grid. Use offset=2 for a 5x5 grid.

for name, (lat, lon) in sites.items():
    with rasterio.open(raster_files[0]) as src:
        row, col = rowcol(src.transform, lon, lat)
    
    # Slice the stack: [all_time, row_range, col_range]
    # We use nanmean to ignore any pixels that might be 'nodata'
    grid_window = stack[:, row-offset : row+offset+1, col-offset : col+offset+1]
    all_pixel_data[name] = np.nanmean(grid_window, axis=(1, 2))
    all_pixel_std[name] = np.nanstd(grid_window, axis=(1, 2))

# Global Y-axis limits
y_min = min([d.min() for d in all_pixel_data.values()]) * 0 
y_max = max([d.max() for d in all_pixel_data.values()]) * 1.1

'''# --- 2. EXTRACT DATA & FIND GLOBAL LIMITS ---
all_pixel_data = {}
for name, (lat, lon) in sites.items():
    with rasterio.open(raster_files[0]) as src:
        row, col = rowcol(src.transform, lon, lat)
    all_pixel_data[name] = stack[:, row, col]

# Determine global Y-axis scale for standardization
y_min = min([d.min() for d in all_pixel_data.values()]) * 0  ##or 0.9
y_max = max([d.max() for d in all_pixel_data.values()]) * 1.1'''

# --- 5. ADD SCALE BAR (Calculated for Georgia's latitude) ---
# At ~30.8°N, 1 degree lon is roughly 95.6 km. 
# So, 10km is ~0.1046 degrees.
scale_len_deg = 10 / 95.6  
sb_x = left + (right - left) * 0.80 # Start 80% from left
sb_y = bottom + (top - bottom) * 0.96 # Start 96% from bottom

axd['M'].plot([sb_x, sb_x + scale_len_deg], [sb_y, sb_y], color='black', lw=3, zorder=5)
axd['M'].text(sb_x + (scale_len_deg/2), sb_y + (top-bottom)*0.02, '10 km', 
              ha='center', va='bottom', fontsize=10, fontweight='bold')



# --- 3. PLOT STANDARDIZED TIME SERIES ---

from matplotlib.patches import ConnectionPatch

# for i, (name, data) in enumerate(all_pixel_data.items()):
#     ax_key = list("ABCD")[i]
#     ax = axd[ax_key]
    
#     ax.scatter(years, data, s=10, color='black', alpha=0.6)
    
#     # Standardize Axes
#     ax.set_ylim(y_min, y_max)
#     ax.set_title(f"Site {name}", fontsize=10)
    
# #     #Clean up labels for the stack
# #     if ax_key != 'D': ax.set_xticklabels([]) 
        
#     ax.set_title(name)
#     ax.set_ylabel("AGB (g/$m^2$)")
#     if i == 0: ax.set_xlabel("")
        
# --- 4. TRENDLINES & CONNECTING LINES ---
import seaborn as sns

site_colors = dict(zip(sites.keys(), sns.color_palette("tab10", len(sites))))

for i, (name, (lat, lon)) in enumerate(sites.items()):
    ax_key = list("ABCD")[i]
    ax_t = axd[ax_key]
    data = all_pixel_data[name]
    std_dev = all_pixel_std[name]
    
    color = site_colors[name]   # <- shared color for this site
    
    # Plot Trend
    ax_t.scatter(years, data, s=20, color=color, alpha=0.8)
    m, b = np.polyfit(years, data, 1)
#     ax_t.plot(years, m*years + b, color='red', lw=1.5)
    
#     # Plot Trend with traditional vertical error bars
#     ax_t.errorbar(years, data, yerr=std_dev, fmt='o', ms=4, color=color, 
#                   ecolor=color, elinewidth=1, capsize=2, alpha=0.8)
    
    
    # Standardize axes
    ax_t.set_ylim(y_min, y_max)
    ax_t.set_title(f"Site {name}", fontsize=10, color = color)
    
    # DRAW CONNECTION LINE
    # This connects the point on the map to the Y-axis of the trendline
    con = ConnectionPatch(xyA=(lon, lat), xyB=(years[0], np.mean(data)), 
                          coordsA=ax_m.transData, coordsB=ax_t.transData,
                          arrowstyle="-", color="gray", linestyle=":", 
                          alpha=0.6, zorder=10)
    fig.add_artist(con)
    
    # Mark the point on the map
    ax_m.plot(lon, lat, 'o', markersize=8, markeredgecolor='black', zorder=11)
    
    ax_t.set_title(name)
    ax_t.set_ylabel("AGB (g/$m^2$)")
    if i == 0: ax_t.set_xlabel("")

# fig.suptitle("Long-term Biomass Trends: Georgia Coast", fontsize=16)
# plt.tight_layout()

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.patches as patches

# 1. Create the inset axis (loc=4 is lower right, loc=1 is upper right)
ax_inset = inset_axes(axd['M'], width="20%", height="20%", loc=4, borderpad=3)

# 2. Load and plot the Georgia Shapefile
ga_gdf = gpd.read_file("F:/US states/Georgia.shp")
ga_gdf = ga_gdf.to_crs(src2.crs) # Match CRS to your raster
ga_gdf.plot(ax=ax_inset, facecolor='#f0f0f0', edgecolor='black', linewidth=0.5)

# 3. Add a "You Are Here" rectangle
# Using the 'left, bottom, right, top' variables you already defined from src2.bounds
rect = patches.Rectangle((left, bottom), right - left, top - bottom, 
                         linewidth=1.5, edgecolor='red', facecolor='none', zorder=10)
ax_inset.add_patch(rect)

# 4. Clean up the inset (remove coordinates/spines for a "clean" look)
ax_inset.set_xticks([])
ax_inset.set_yticks([])
for spine in ax_inset.spines.values():
    spine.set_visible(False)
    

##Save at high res
import os
output_dir = r'F:\Figures_PaperII'
file_name = 'MAPPY_XYZ_THIELSEN_GRID_new_palette_errorbars.tif'

save_path = os.path.join(output_dir, file_name)

# plt.savefig(save_path, bbox_inches='tight', dpi=1000)

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total pixels (including zeros, excluding NaNs): 1135317

# %%
##Plotting other layers

# base_layer = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_final.tif"
base_layer = "F:/Flats imagery/Trend_nocutoffareas/flood84_23.tif"

base_shape = "F:/Wetlands shapefiles/GA_shapefile_wetlands/GA_estuaries.shp"
gdf = gpd.read_file(base_shape)

# 2. Define Layout (2 columns: Map is 'M', Plots are A-D)
layout = """
         MM
         MM
         MM
         MM
         """
# Now width_ratios=[3, 1] works because the layout has exactly 2 columns
fig, axd = plt.subplot_mosaic(layout, figsize=(16, 12), 
                               gridspec_kw={'width_ratios': [3, 1]})


# --- 1. PLOT THE MAP ---

from matplotlib.colors import LinearSegmentedColormap
positions = [0, 0.5, 1]
colors = ["limegreen", "w", "b"] 
cmap_name = "blue_to_green"
custom_cmap = LinearSegmentedColormap.from_list(cmap_name, list(zip(positions, colors)), N=256)

from rasterio.mask import mask
from rasterio.plot import plotting_extent

##Pixel counts
with rasterio.open(base_layer) as src:
    data = src.read(1) # Read the first band
    is_not_nan = ~np.isnan(data)    
    total_valid_pixels = np.sum(is_not_nan)    
    print(f"Total pixels (including zeros, excluding NaNs): {total_valid_pixels}")
    

##Mapping
with rasterio.open(base_layer) as src2:
    gdf = gdf.to_crs(src2.crs)
    out_image, out_transform = mask(src2, gdf.geometry, crop=True)
    clip_extent = plotting_extent(out_image[0], out_transform)
    
    # 4. Plot the clipped image (out_image[0] is the first band)
    img = axd['M'].imshow(out_image[0], 
                          cmap=custom_cmap, 
                          interpolation='nearest',
                          extent=clip_extent)
    
    #Keep map zoomed in
    axd['M'].set_xlim(left, right)
    axd['M'].set_ylim(bottom, top)
    
    # Overlay the shapefile
    gdf.plot(ax=axd['M'], facecolor='none', edgecolor='black', linewidth=0.1, zorder = 2)

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
cbaxes = inset_axes(axd['M'], width="3%", height="30%", loc=2) 
cbar = plt.colorbar(img, cax = cbaxes, label='Flooding probability trend (%)')

import matplotlib.ticker as ticker

# 2. Apply a custom formatter to multiply the labels by 100
# (Change :.0f to :.1f if you want 1 decimal place!)
cbar.formatter = ticker.FuncFormatter(lambda x, pos: f'{x * 100:.0f}')

# 3. Force the colorbar to update its display
cbar.update_ticks()



# Axis Labels
ax_m = axd['M']
ax_m.set_xlabel("Longitude", fontsize=12)
ax_m.set_ylabel("Latitude", fontsize=12)

# Add North Arrow
x, y, arrow_length = 0.15, 0.99, 0.05
axd['M'].annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
                  arrowprops=dict(facecolor='black', width=5, headwidth=15),
                  ha='center', va='center', fontsize=20, xycoords='axes fraction')

# --- 2. EXTRACT DATA & FIND GLOBAL LIMITS ---
all_pixel_data = {}
for name, (lat, lon) in sites.items():
    with rasterio.open(raster_files[0]) as src:
        row, col = rowcol(src.transform, lon, lat)
    all_pixel_data[name] = stack[:, row, col]

# Determine global Y-axis scale for standardization
y_min = min([d.min() for d in all_pixel_data.values()]) * 0  ##or 0.9
y_max = max([d.max() for d in all_pixel_data.values()]) * 1.1

# --- 5. ADD SCALE BAR (Calculated for Georgia's latitude) ---
# At ~30.8°N, 1 degree lon is roughly 95.6 km. 
# So, 10km is ~0.1046 degrees.
scale_len_deg = 10 / 95.6  
sb_x = left + (right - left) * 0.80 # Start 80% from left
sb_y = bottom + (top - bottom) * 0.96 # Start 96% from bottom

axd['M'].plot([sb_x, sb_x + scale_len_deg], [sb_y, sb_y], color='black', lw=3, zorder=5)
axd['M'].text(sb_x + (scale_len_deg/2), sb_y + (top-bottom)*0.02, '10 km', 
              ha='center', va='bottom', fontsize=10, fontweight='bold')

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.patches as patches

# 1. Create the inset axis (loc=4 is lower right, loc=1 is upper right)
ax_inset = inset_axes(axd['M'], width="20%", height="20%", loc=4, borderpad=3)

# 2. Load and plot the Georgia Shapefile
ga_gdf = gpd.read_file("F:/US states/Georgia.shp")
ga_gdf = ga_gdf.to_crs(src2.crs) # Match CRS to your raster
ga_gdf.plot(ax=ax_inset, facecolor='#f0f0f0', edgecolor='black', linewidth=0.5)

# 3. Add a "You Are Here" rectangle
# Using the 'left, bottom, right, top' variables you already defined from src2.bounds
rect = patches.Rectangle((left, bottom), right - left, top - bottom, 
                         linewidth=1.5, edgecolor='red', facecolor='none', zorder=10)
ax_inset.add_patch(rect)

# 4. Clean up the inset (remove coordinates/spines for a "clean" look)
ax_inset.set_xticks([])
ax_inset.set_yticks([])
for spine in ax_inset.spines.values():
    spine.set_visible(False)
    

##Save at high res
import os
output_dir = r'F:\Figures_PaperII'
file_name = 'FLATS_XY.tif'

save_path = os.path.join(output_dir, file_name)

# plt.savefig(save_path, bbox_inches='tight', dpi=300)

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total pixels (including zeros, excluding NaNs): 8856351

# %%
##Hotspot pixel count

##FLATS
base_layer1 = "F:/Flats imagery/Trend_nocutoffareas/flood84_23.tif"

##LOGO
# base_layer = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_final.tif"
base_layer2 = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_Thiel_Sen.tif"

base_shape = "F:/Wetlands shapefiles/GA_shapefile_wetlands/GA_estuaries.shp"
gdf = gpd.read_file(base_shape)

import rasterio
from rasterio.mask import mask
import geopandas as gpd

# 2. Ensure the shapefile CRS matches your rasters
# (It is critical that both rasters and the shapefile are in the same CRS)
with rasterio.open(base_layer1) as src:
    gdf = gdf.to_crs(src.crs)
    shapes = [feature for feature in gdf.geometry]

# 3. Create a function to clip/mask both to the shapefile
def clip_raster_to_shape(raster_path, shapes):
    with rasterio.open(raster_path) as src:
        # crop=True cuts the raster to the shapefile's bounding box
        out_image, out_transform = mask(src, shapes, crop=True)
        
        # Select ONLY the first band [0, :, :]
        # This turns the (bands, height, width) array into a (height, width) array
        return out_image[0, :, :], out_transform

# Clip both
data1, transform1 = clip_raster_to_shape(base_layer1, shapes)
data2, transform2 = clip_raster_to_shape(base_layer2, shapes)

# 4. Now both data1 and data2 are 2D arrays (height, width)
if data1.shape != data2.shape:
    print(f"Still a shape mismatch! Raster1: {data1.shape}, Raster2: {data2.shape}")
else:
    # Since they are now 2D, you don't need the [0] index anymore
    mask_condition = (data1 > 0.005) & (data2 < 0) ##0.005 chosen because 40*0.005 is 0.2, the threshold for FLATS+. Absent sig
    print(f"Pixel count: {np.sum(mask_condition)}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Pixel count: 121432

# %%
with rasterio.open(base_layer1) as src:
    print(f"Number of bands: {src.count}")
    print(f"Band descriptions: {src.descriptions}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of bands: 2
# Band descriptions: ('scale', 'offset')

# %%
##Plotting other layers

# base_layer = "F:/Biomass tiffs/Biomass modeling/Georgia/All_trend/LOGO_sig_1984to2023_final.tif"
# base_layer = "F:/Flats imagery/Trend_nocutoffareas/flood84_23.tif"
# base_layer = "F:/Hotspots/Hotspots.tif"
# base_layer = "F:/Hotspots/hotspots_NEW.tif"
base_layer = "F:/Hotspots/hotspots_theilsen.tif"


base_shape = "F:/Wetlands shapefiles/GA_shapefile_wetlands/GA_estuaries.shp"
gdf = gpd.read_file(base_shape)

# oysters = "F:/Hotspots/Project shapefiles/oyster_reefs.shp"
# oyster_shp = gpd.read_file(oysters)

# actives = "F:/Hotspots/Project shapefiles/actives.shp"
# actives_shp = gpd.read_file(actives)

# restor = "F:/Hotspots/Project shapefiles/restoration_sites.shp"
# restor_shp = gpd.read_file(actives)

df_restor = pd.read_csv("F:/GA_marsh_conservation/LS_OR_TLP.csv", encoding='latin1')
restor_gdf = gpd.GeoDataFrame(
    df_restor, geometry=gpd.points_from_xy(df_restor.Longitude, df_restor.Latitude), crs="EPSG:4326"
)

mml = "F:/Hotspots/Project shapefiles/mml.shp"
mml_shp = gpd.read_file(mml)

# 2. Define Layout (2 columns: Map is 'M', Plots are A-D)
layout = """
         MM
         MM
         MM
         MM
         """
# Now width_ratios=[3, 1] works because the layout has exactly 2 columns
fig, axd = plt.subplot_mosaic(layout, figsize=(16, 12), 
                               gridspec_kw={'width_ratios': [3, 1]})


# --- 1. PLOT THE MAP ---

# from matplotlib.colors import LinearSegmentedColormap
# positions = [0,1]
# colors = ["w", "r"] 
# cmap_name = "white_red"
# custom_cmap = LinearSegmentedColormap.from_list(cmap_name, list(zip(positions, colors)), N=256)

from matplotlib.colors import ListedColormap

# Define colors for values 0, 1, 2, 3, 4
colors = ["white","red", "white", "white", "white"]

# Create a discrete colormap
custom_cmap = ListedColormap(colors)

# Example usage with imshow:
# plt.imshow(your_raster_data, cmap=custom_cmap, vmin=0, vmax=4

from rasterio.mask import mask
from rasterio.plot import plotting_extent

# ##Pixel counts
# with rasterio.open(base_layer) as src:
#     data = src.read(1) # Read the first band
#     is_not_nan = ~np.isnan(data) & (data == 999)   
#     total_valid_pixels = np.sum(is_not_nan)    
#     print(f"Total pixels (including zeros, excluding NaNs): {total_valid_pixels}")

##Pixel counts
with rasterio.open(base_layer) as src:
    data = src.read(1) # Read the first band
    is_not_nan = ~np.isnan(data) & (data == 1)   
    total_valid_pixels = np.sum(is_not_nan)    
    print(f"Total pixels (including zeros, excluding NaNs): {total_valid_pixels}")
    
##Mapping
with rasterio.open(base_layer) as src2:
    gdf = gdf.to_crs(src2.crs)
    out_image, out_transform = mask(src2, gdf.geometry, crop=True)
    clip_extent = plotting_extent(out_image[0], out_transform)
    
    # 4. Plot the clipped image (out_image[0] is the first band)
    img = axd['M'].imshow(out_image[0], 
                          cmap=custom_cmap, 
                          interpolation='nearest',
                          extent=clip_extent)
    
    #Keep map zoomed in
    axd['M'].set_xlim(left, right)
    axd['M'].set_ylim(bottom, top)
    
    # Overlay the shapefiles
    gdf.plot(ax=axd['M'], facecolor='none', edgecolor='black', linewidth=0.1, zorder = 2)
    
    # Ensure restor_shp and mml_shp match the raster CRS
    restor_gdf = restor_gdf.to_crs(src2.crs)
    mml_shp = mml_shp.to_crs(src2.crs)
    
    #Restoration projects
    restor_gdf.plot(ax=axd['M'], color='black', marker = 'o', markersize = 20, zorder = 3, label = 'Restoration projects')
    mml_shp.plot(ax=axd['M'], edgecolor='green', linewidth=1, zorder = 4, label = 'Marsh Migration Boundary')

# Axis Labels
ax_m = axd['M']
ax_m.set_xlabel("Longitude", fontsize=12)
ax_m.set_ylabel("Latitude", fontsize=12)

# Add North Arrow
x, y, arrow_length = 0.15, 0.99, 0.05
axd['M'].annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
                  arrowprops=dict(facecolor='black', width=5, headwidth=15),
                  ha='center', va='center', fontsize=20, xycoords='axes fraction')

# --- 2. EXTRACT DATA & FIND GLOBAL LIMITS ---
all_pixel_data = {}
for name, (lat, lon) in sites.items():
    with rasterio.open(raster_files[0]) as src:
        row, col = rowcol(src.transform, lon, lat)
    all_pixel_data[name] = stack[:, row, col]

# Determine global Y-axis scale for standardization
y_min = min([d.min() for d in all_pixel_data.values()]) * 0  ##or 0.9
y_max = max([d.max() for d in all_pixel_data.values()]) * 1.1

# --- 5. ADD SCALE BAR (Calculated for Georgia's latitude) ---
# At ~30.8°N, 1 degree lon is roughly 95.6 km. 
# So, 10km is ~0.1046 degrees.
scale_len_deg = 10 / 95.6  
sb_x = left + (right - left) * 0.80 # Start 80% from left
sb_y = bottom + (top - bottom) * 0.96 # Start 96% from bottom

axd['M'].plot([sb_x, sb_x + scale_len_deg], [sb_y, sb_y], color='black', lw=3, zorder=5)
axd['M'].text(sb_x + (scale_len_deg/2), sb_y + (top-bottom)*0.02, '10 km', 
              ha='center', va='bottom', fontsize=10, fontweight='bold')

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.patches as patches

# 1. Create the inset axis (loc=4 is lower right, loc=1 is upper right)
ax_inset = inset_axes(axd['M'], width="20%", height="20%", loc=4, borderpad=3)

# 2. Load and plot the Georgia Shapefile
ga_gdf = gpd.read_file("F:/US states/Georgia.shp")
ga_gdf = ga_gdf.to_crs(src2.crs) # Match CRS to your raster
ga_gdf.plot(ax=ax_inset, facecolor='#f0f0f0', edgecolor='black', linewidth=0.5)

# 3. Add a "You Are Here" rectangle
# Using the 'left, bottom, right, top' variables you already defined from src2.bounds
rect = patches.Rectangle((left, bottom), right - left, top - bottom, 
                         linewidth=1.5, edgecolor='red', facecolor='none', zorder=10)
ax_inset.add_patch(rect)

# 4. Clean up the inset (remove coordinates/spines for a "clean" look)
ax_inset.set_xticks([])
ax_inset.set_yticks([])
for spine in ax_inset.spines.values():
    spine.set_visible(False)
    
# Add the legend to the plot
axd['M'].legend(loc='center right', bbox_to_anchor=(1.0, 0.25),  frameon=False)
    

##Save at high res
import os
output_dir = r'F:\Figures_PaperII'
file_name = 'hotspots_all_legendXYZZY.tif'

save_path = os.path.join(output_dir, file_name)

# plt.savefig(save_path, bbox_inches='tight', dpi=1000)

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total pixels (including zeros, excluding NaNs): 121566

# %%
# #Interactive map
# import matplotlib.pyplot as plt
# from rasterio.transform import rowcol

# def interactive_pixel_timeseries(stack, years, reference_raster):
#     """
#     Click on a pixel to plot its time series.
    
#     stack: numpy array (time, rows, cols)
#     years: list or array of years
#     reference_raster: path to one of the rasters (for georeferencing)
#     """
    
#     with rasterio.open(reference_raster) as src:
#         transform = src.transform
    
#     fig, ax = plt.subplots(figsize=(10, 8))
#     img = ax.imshow(stack[0, :, :], cmap='viridis')  # show first year
#     ax.set_title("Click on a pixel to view time series")
#     plt.colorbar(img, ax=ax, label="Value")
    
#     def onclick(event):
#         if event.inaxes != ax:
#             return
        
#         # Get pixel coordinates from click
#         col, row = int(round(event.xdata)), int(round(event.ydata))
        
#         # Check bounds
#         if row < 0 or col < 0 or row >= stack.shape[1] or col >= stack.shape[2]:
#             print("Click inside the image!")
#             return
        
#         # Extract values
#         values = stack[:, row, col]
        
#         if np.isnan(values).all():
#             print(f"Pixel ({row}, {col}) has no data.")
#             return
        
#         # Plot time series
#         plt.figure(figsize=(8, 5))
#         plt.plot(years, values, marker='o')
#         plt.xlabel("Year")
#         plt.ylabel("Value")
#         plt.title(f"Time series at pixel ({row}, {col})")
#         plt.grid(True)
#         plt.show()
    
#     # Connect click event
#     cid = fig.canvas.mpl_connect('button_press_event', onclick)
#     plt.show()

# # Example usage
# interactive_pixel_timeseries(stack, years, raster_files[0])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#Finito
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ##OLD CODE

# import sklearn
# from sklearn.linear_model import LinearRegression

# # Prepare x values (years) for regression
# X = np.array(years).reshape(-1, 1)  # shape: (n_years, 1)
# rows, cols = stack.shape[1:]

# # Initialize output array for slopes
# slope_array = np.full((rows, cols), np.nan)

# # Loop over each pixel
# for i in range(rows):
#     for j in range(cols):
#         y = stack[:, i, j]
#         if np.all(np.isfinite(y)):
#             model = LinearRegression().fit(X, y)
#             slope_array[i, j] = model.coef_[0]  # slope
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# # out_path = "F:\\Biomass tiffs\\All_trend\\trend_2010to2023.tif"
# out_path = "F:\\Biomass tiffs\\Biomass modeling\\Georgia\\All_trend\\trend_1984to2023.tif"


# # Use metadata from one of the input files
# with rasterio.open(raster_files[0]) as src:
#     meta = src.meta.copy()

# meta.update(dtype=rasterio.float32, count=1)

# with rasterio.open(out_path, 'w', **meta) as dst:
#     dst.write(slope_array.astype(rasterio.float32), 1)

# print(f"Saved slope image to {out_path}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
