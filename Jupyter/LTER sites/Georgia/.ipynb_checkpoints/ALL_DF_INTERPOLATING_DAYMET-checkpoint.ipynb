# %%
import pandas as pd

df = pd.read_csv('C:/Users/arj26323/Documents/Data/Biomass datasets/Pennings/Final_df_interpolated/GA_new_df.csv')

df
# Out:
#        Latitude  Longitude  Sampling_year  LS_year  ndvi_mean_08_10  \
# 0     31.308449 -81.415129           2013     2013         0.608544
# 1     31.308449 -81.415129           2015     2015         0.502339
# 2     31.308449 -81.415129           2016     2016         0.548571
# 3     31.308449 -81.415129           2018     2018         0.497044
# 4     31.308449 -81.415129           2021     2021         0.496204
# ...         ...        ...            ...      ...              ...
# 3076  31.539505 -81.421937           2018     2018         0.539582
# 3077  31.539505 -81.421937           2019     2019         0.453920
# 3078  31.539505 -81.421937           2020     2020         0.572171
# 3079  31.539505 -81.421937           2021     2021         0.566227
# 3080  31.539505 -81.421937           2022     2022         0.510891
#
#       evi_mean_08_10  nd_swir2_r_mean_08_10  nd_swir2_nir_mean_08_10  \
# 0           0.185087               0.262307                -0.411777
# 1           0.148550               0.240085                -0.298153
# 2           0.179854               0.294428                -0.302436
# 3           0.161636               0.261019                -0.271003
# 4           0.159708               0.267223                -0.263843
# ...              ...                    ...                      ...
# 3076        0.148651               0.293553                -0.292413
# 3077        0.121159               0.268477                -0.211386
# 3078        0.170051               0.309778                -0.318770
# 3079        0.167103               0.236192                -0.380722
# 3080        0.140481               0.238366                -0.308614
#
#       nd_g_b_mean_08_10  nd_r_g_mean_08_10  ...  spei90d_Min  pdsi_gridmet  \
# 0              0.188730           0.020280  ...         1.69     -1.323333
# 1              0.132298           0.062364  ...         1.69      0.580556
# 2              0.142160           0.049064  ...         1.69     -0.713684
# 3              0.122543           0.050631  ...         1.69      3.070555
# 4              0.129631           0.059329  ...         2.09      4.330555
# ...                 ...                ...  ...          ...           ...
# 3076           0.173896           0.038968  ...         1.69      3.003889
# 3077           0.140268           0.030576  ...        -0.10     -0.112222
# 3078           0.322373           0.006610  ...         1.69      3.605263
# 3079           0.192631           0.046198  ...         2.09      3.286667
# 3080           0.179200           0.041194  ...         1.69      0.091111
#
#       spei180d_gridmet  spei1y_gridmet  spei30d_gridmet  spei5y_gridmet  \
# 0             0.988333        0.032778         0.311111       -1.355556
# 1             0.415556        0.333333         0.433889       -0.873889
# 2            -0.314211       -0.456842         0.080526       -0.234737
# 3             1.047778        0.569444         0.081667        0.937778
# 4             1.030000        0.983889         0.826111        1.872222
# ...                ...             ...              ...             ...
# 3076          1.262222        0.670556         0.163889        0.208889
# 3077         -0.970000       -0.271667        -0.491667        0.030714
# 3078          1.011579        1.280000         0.273684        0.736842
# 3079          0.833889        0.633333         0.205000        1.288333
# 3080          0.268889       -0.154444         0.044444        0.879444
#
#       spei90d_gridmet        Yr      lat_r      lon_r
# 0            0.623333  1/1/2013  31.308449 -81.415129
# 1            0.706111  1/1/2015  31.308449 -81.415129
# 2           -0.184737  1/1/2016  31.308449 -81.415129
# 3            0.662222  1/1/2018  31.308449 -81.415129
# 4            1.567222  1/1/2021  31.308449 -81.415129
# ...               ...       ...        ...        ...
# 3076         0.877778  1/1/2018  31.539505 -81.421937
# 3077        -0.812222  1/1/2019  31.539505 -81.421937
# 3078         0.847368  1/1/2020  31.539505 -81.421937
# 3079         1.075556  1/1/2021  31.539505 -81.421937
# 3080         0.567222  1/1/2022  31.539505 -81.421937
#
# [3081 rows x 431 columns]

# %%
dfs2 = df[df['Site'] == 2]
dfs2['dayl_Max']
# Out:
# 2441   NaN
# 2442   NaN
# 2443   NaN
# 2444   NaN
# 2445   NaN
#         ..
# 2793   NaN
# 2794   NaN
# 2795   NaN
# 2796   NaN
# 2797   NaN
# Name: dayl_Max, Length: 357, dtype: float64

# %%
climate_vars = ['srad_peak', 'dayl_Max', 'spei14d']

df['Year'] = df['LS_year']

donors = (
    df[df['Site'] == 3]
    .dropna(subset=climate_vars)
    .groupby('Year', as_index=False)
    .first()
    [['Year'] + climate_vars]
)

df_filled = df.merge(
    donors,
    on='Year',
    how='left',
    suffixes=('', '_donor')
)

# %%
mask = df_filled['Site'] == 2

for v in climate_vars:
    df_filled.loc[mask, v] = (
        df_filled.loc[mask, v]
        .fillna(df_filled.loc[mask, f'{v}_donor'])
    )

# %%
df_filled = df_filled.drop(columns=[f'{v}_donor' for v in climate_vars])

# %%
print(
    df_filled.loc[df_filled['Site'] == 2, climate_vars]
    .isna()
    .sum()
)
##You want all zeros
# Out:
# srad_peak    16
# dayl_Max     16
# spei14d      16
# dtype: int64

# %%
dfs2 = df_filled[df_filled['Site'] == 2]
dfs2['srad_peak']
# Out:
# 2441    336.230316
# 2442    318.082489
# 2443    332.947388
# 2444    312.132812
# 2445    332.019562
#            ...
# 2793           NaN
# 2794    349.659027
# 2795    324.776947
# 2796    337.880005
# 2797    332.019562
# Name: srad_peak, Length: 357, dtype: float64

# %%
##Exporting coordinates
import os

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'LOGO_df_interpolated.csv')

# df_filled.to_csv(out_csv)
