# %%
import pandas as pd
import numpy as np

# %%
# df0 = pd.read_csv('C:/Users/arj26323/Documents/Data/Restoration_trends/restoration_window_trends.csv') ##2x2 window
# df0 = pd.read_csv('C:/Users/arj26323/Documents/Data/Restoration_trends/rest_trends.csv') ##Individual pixels
df0 = pd.read_csv('C:/Users/arj26323/Documents/Data/Restoration_trends/restoration_window_trends_4.csv') ##4x4 window

df = df0.iloc[:, [1] + list(range(6,46))].dropna()

df
# Out:
#                                               Site  biomass_1984  \
# 0                         Little Cumberland Island    845.632202
# 1                      Fortson Pond, Jekyll Island    885.162720
# 2   DNR’s Coastal Regional Headquarters, Brunswick    368.049713
# 3      Beach Road Bridge, Little St. Simons Island    569.847717
# 4      Cannon’s Point Preserve, St. Simon’s Island    622.550415
# 5        Mosquito Creek, Little St. Simon’s Island    634.806396
# 6                        Long Tabby, Sapelo Island    869.103271
# 7                        Ashantilly, Sapelo Island   1134.372681
# 8      Skidaway Island State Park, Skidaway Island    756.271606
# 9                         Burton 4-H, Tybee Island    622.936157
# 10                           Plantation Creek Site    349.334106
# 11                            Florida Passage Site    516.593506
# 12                                    Oatland Site    477.637268
# 14            Estuaries Area of the Altamaha River    430.925049
# 15                    Jekyll Island Boat Ramp Site    452.684570
# 17                             Oyster Creek Site B    260.552704
# 19                     Jointer Creek Oyster Reef A    279.225586
# 20                     Jointer Creek Oyster Reef B    364.467865
# 21                     Jointer Creek Oyster Reef C    369.482513
# 22                     Jointer Creek Oyster Reef D    456.699066
# 23                                        Turtle A    639.585632
# 24                                        Turtle B    381.340424
# 25                                        Turtle C    488.741455
# 26                                        Turtle D    425.416107
# 27                                        Turtle E    377.211761
# 28                        Bellville Boat Ramp Site    722.908081
# 30                                      Jekyll TLP    255.696426
#
#     biomass_1985  biomass_1986  biomass_1987  biomass_1988  biomass_1989  \
# 0     933.813477    799.116638    824.808472    816.119751    979.320312
# 1     988.716492    881.033081    889.252563    959.028687   1035.771240
# 2     535.406372    373.745758    409.829102    460.569641    685.860535
# 3     835.799194    575.408325    602.188904    625.453979    930.274780
# 4     706.866638    590.903015    622.860168    731.036987    787.819885
# 5     866.574036    627.699280    649.412292    730.943176    853.088379
# 6     784.144775    680.016968   1002.779724    842.643127    980.532715
# 7    1157.219482   1138.954712   1134.064209   1057.723755   1217.909546
# 8     781.118286    919.217529    723.581116    929.094116    920.794067
# 9     639.629028    869.150696    625.258789    866.979309    892.894653
# 10    502.913269    354.691345    393.420380    404.804169    528.652344
# 11    596.136658    724.716553    572.690796    715.190308    787.268066
# 12    432.319122    584.750732    481.761017    583.451294    570.608459
# 14    429.720184    343.162567    364.288269    431.623291    430.925049
# 15    620.743896    473.538757    501.261566    577.328369    616.968994
# 17    392.389252    367.548004    267.478882    369.052826    362.755859
# 19    406.347656    314.428955    348.494354    379.389160    381.468384
# 20    513.061768    392.994965    445.010101    427.946045    497.482697
# 21    495.543091    388.738617    465.912384    394.317963    442.123291
# 22    596.757507    447.460602    502.396484    458.673370    558.339966
# 23    870.055115    675.025391    663.784729    683.545898    816.842407
# 24    491.679840    388.739288    440.060455    534.337830    534.180359
# 25    732.929810    478.428802    542.212280    634.888977    654.179932
# 26    589.081421    437.889740    476.403320    563.510071    600.458130
# 27    517.113770    355.684296    386.090271    350.690002    507.924377
# 28    924.245544    726.928162    743.593079    920.427490    913.539490
# 30    384.505768    268.478638    327.370483    305.576233    402.376343
#
#     biomass_1990  biomass_1991  biomass_1992  ...  biomass_2014  biomass_2015  \
# 0     828.968140    901.660156    982.398438  ...    840.648071    983.949829
# 1     915.898010   1041.485107    983.286194  ...    906.148071   1055.030029
# 2     360.966644    501.814758    532.314087  ...    365.030334    562.932129
# 3     591.176392   1063.240967    804.530151  ...    764.715088    977.683594
# 4     576.033386   1047.516968    704.552185  ...    608.711792    729.271484
# 5     606.213806    900.559143    789.837891  ...    714.870056    943.925476
# 6     617.983582    979.086853    846.714111  ...    761.466064    966.029480
# 7    1017.015015   1174.855103   1140.144653  ...   1082.276001   1230.273682
# 8     680.704407    808.896484    863.706543  ...    643.707275    907.423828
# 9     639.575317    919.501770    843.830261  ...    844.642395   1031.200562
# 10    358.370392    724.275452    506.029663  ...    387.670715    545.979553
# 11    472.345367    704.951172    658.650757  ...    422.003815    708.343262
# 12    440.441040    591.764893    522.362549  ...    426.507660    610.615906
# 14    316.291351    407.398376    432.913452  ...   1792.355347   1956.185913
# 15    453.711395    535.713135    657.394653  ...    447.576721    636.436707
# 17    241.847092    345.609863    349.381622  ...    247.974075    377.046478
# 19    266.027679    331.308136    377.535919  ...    290.786194    451.411377
# 20    375.501984    462.909424    496.889648  ...    392.108185    553.935059
# 21    380.837311    571.822083    448.946625  ...    358.766022    494.358063
# 22    423.336273    699.995972    579.484680  ...    544.558777    923.185913
# 23    643.969727   1343.666748    874.824097  ...    682.105042    985.596436
# 24    380.368073    507.994537    489.738159  ...    364.350922    547.454529
# 25    530.632874    604.013062    691.850830  ...    427.644196    656.788452
# 26    405.737061    506.420410    570.923950  ...    357.853577    618.787109
# 27    338.276031    406.091248    492.295258  ...    361.430878    604.168457
# 28    719.859619   1038.329102    919.665344  ...    701.718323    716.262268
# 30    256.471588    311.963715    367.059814  ...    236.853500    389.131592
#
#     biomass_2016  biomass_2017  biomass_2018  biomass_2019  biomass_2020  \
# 0     818.740051    980.403198    818.742065    829.755676    835.821411
# 1     931.354492   1023.133728    882.690186    872.310669   1063.300171
# 2     371.112610    528.135437    369.428650    365.227844    545.489319
# 3     604.434082    692.834229    715.331909    734.273315    979.992920
# 4     605.489380    596.202515    651.209106    661.011841    826.275513
# 5     724.032410    703.487488    738.799805    731.459656    969.149475
# 6     570.443848   1159.304199    661.316833    669.801758    927.405029
# 7    1008.475281    955.304810   1136.453125   1080.640747   1095.369873
# 8     691.308533    597.531860    612.939209    529.747559    690.808472
# 9     762.561768    686.991516    703.557739    641.180176    788.218628
# 10    392.765137    517.512573    386.327545    365.599609    589.839783
# 11    510.590179    517.194031    521.772827    459.005341    589.865417
# 12    430.738831    450.998322    446.943604    401.030518    612.924316
# 14   1681.566772   1945.769897   1816.705078   1448.168457   1974.206543
# 15    470.957855    608.429199    468.846649    455.108887    522.395935
# 17    200.297195    230.038803    208.098328    241.937119    244.747070
# 19    304.899811    409.434967    294.207642    272.487122    427.791077
# 20    389.421967    552.567932    383.204010    348.155670    585.521118
# 21    344.536469    472.735474    335.751526    337.796143    548.355225
# 22    459.058655    563.848938    797.129150    440.188629    593.979919
# 23    724.553162    825.771179    747.461060    673.232300    996.216492
# 24    345.097870    483.673248    371.546478    326.000000    629.312622
# 25    425.307465    649.945435    427.862793    493.484039    772.056030
# 26    392.461151    427.827545    801.862122    405.360840    742.623230
# 27    343.346130    327.039276    346.404358    360.172516    622.650208
# 28    692.788086    921.160706    712.455811    693.315613    973.602234
# 30    244.884949    393.523651    250.711197    260.059479    394.958557
#
#     biomass_2021  biomass_2022  biomass_2023
# 0     940.861145    815.248779    786.960815
# 1    1039.480347    970.523315    873.720276
# 2     531.824463    388.307556    386.003021
# 3     988.187378    739.651367    751.543274
# 4     781.883850    625.793518    667.444153
# 5     918.246338    705.757324    715.641357
# 6     565.239319   1333.237671   1198.355103
# 7    1180.381348   1002.009949   1136.510498
# 8     645.660156    674.531311    671.139526
# 9     734.820862    777.247070    769.877808
# 10    635.438354    410.277618    392.580963
# 11    502.335052    496.143799    546.082397
# 12    578.058838    417.451599    435.169189
# 14   1940.200073   1770.534668   1547.264160
# 15    640.847290    460.545898    531.526672
# 17    210.421143    202.948929    211.819336
# 19    395.279816    298.255737    323.562744
# 20    551.393372    374.041718    399.102539
# 21    514.151794    340.539307    351.847992
# 22    682.270813    414.860077    916.823669
# 23    979.900452    739.023010    784.731567
# 24    524.637207    463.679047    390.193115
# 25    615.579956    417.096771    502.390381
# 26    539.333557    393.456757    425.917297
# 27    527.830444    382.665253    405.133514
# 28    967.836670    724.407959    730.691833
# 30    393.682434    275.106262    292.630615
#
# [27 rows x 41 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Melt the DataFrame
# Assumes 'site' is the column that identifies your locations
df_long = pd.melt(
    df, 
    id_vars=['Site'], 
    var_name='year', 
    value_name='biomass'
)

# 2. Clean the 'year' column
# Remove 'biomass_' prefix and convert to numeric
df_long['year'] = df_long['year'].str.replace('biomass_', '').astype(int)

# %%
df_long
# Out:
#                                                 Site  year     biomass
# 0                           Little Cumberland Island  1984  845.632202
# 1                        Fortson Pond, Jekyll Island  1984  885.162720
# 2     DNR’s Coastal Regional Headquarters, Brunswick  1984  368.049713
# 3        Beach Road Bridge, Little St. Simons Island  1984  569.847717
# 4        Cannon’s Point Preserve, St. Simon’s Island  1984  622.550415
# ...                                              ...   ...         ...
# 1075                                        Turtle C  2023  502.390381
# 1076                                        Turtle D  2023  425.917297
# 1077                                        Turtle E  2023  405.133514
# 1078                        Bellville Boat Ramp Site  2023  730.691833
# 1079                                      Jekyll TLP  2023  292.630615
#
# [1080 rows x 3 columns]

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

g = sns.FacetGrid(df_long, col="Site", col_wrap=4, height=3, sharey=True)
g.map(sns.scatterplot, "year", "biomass", marker='o', color = 'black')
g.set_titles("{col_name}")
g.set_axis_labels("Year", "AGB (g/$m^2$)")
g.set(ylim=(0, None))
plt.tight_layout()
plt.show()

# %%
df_short = df_long[df_long['Site'] == 'Estuaries Area of the Altamaha River']

# 3. Plotting
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_short, x='year', y='biomass', marker='o', color = 'black')

plt.xlabel('Year')
plt.ylabel('AGB (g/$m^2$)')
plt.ylim(0, None)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
##Major and Savannah and Jekyll-ish hotspot trends

dfx = pd.read_csv('C:/Users/arj26323/Documents/Data/Restoration_trends/major_hotspots_trends.csv') ##only big hotspots 
dfx = pd.read_csv('C:/Users/arj26323/Documents/Data/Restoration_trends/savan_hotspots_trends.csv') ##only savannah hotspots 

dfx

dfy = dfx.groupby(['year'])[['mean', 'std']].mean().reset_index()
dfy

dfy = pd.read_csv('C:/Users/arj26323/Documents/Data/Restoration_trends/jekyllish_hotspots_trends.csv')
dfy
# Out:
#     Unnamed: 0  polygon_id  year        mean        std
# 0            0           0  1984  1244.87780  486.68620
# 1            1           0  1985  1197.59690  523.64330
# 2            2           0  1986  1091.53880  548.52620
# 3            3           0  1987  1158.10000  544.15510
# 4            4           0  1988  1175.36500  553.53186
# 5            5           0  1989  1175.53750  522.85500
# 6            6           0  1990   899.42720  510.10483
# 7            7           0  1991  1269.58300  555.26166
# 8            8           0  1992  1022.26620  499.33307
# 9            9           0  1993   879.14813  507.82867
# 10          10           0  1994  1033.39940  496.40326
# 11          11           0  1995  1000.00040  506.39557
# 12          12           0  1996  1025.38320  515.60440
# 13          13           0  1997   833.44574  498.99460
# 14          14           0  1998   830.98895  509.64377
# 15          15           0  1999   594.93180  389.38810
# 16          16           0  2000   587.02484  346.28730
# 17          17           0  2001   608.39110  374.57720
# 18          18           0  2002   725.67440  381.77676
# 19          19           0  2003   616.00450  392.54820
# 20          20           0  2004   746.13240  369.19757
# 21          21           0  2005   789.80945  394.69460
# 22          22           0  2006   497.43080  254.74333
# 23          23           0  2007   711.35080  312.40662
# 24          24           0  2008   554.97766  306.55234
# 25          25           0  2009   635.42760  337.91205
# 26          26           0  2010   517.96940  281.92130
# 27          27           0  2011   480.14250  226.26738
# 28          28           0  2012   531.19180  229.02257
# 29          29           0  2013   756.67290  353.84296
# 30          30           0  2014   507.65110  261.32330
# 31          31           0  2015   665.74710  306.10360
# 32          32           0  2016   501.49000  275.71530
# 33          33           0  2017   672.99940  311.32028
# 34          34           0  2018   467.00797  236.59848
# 35          35           0  2019   462.86487  239.42159
# 36          36           0  2020   500.03665  233.86241
# 37          37           0  2021   678.96410  315.74740
# 38          38           0  2022   491.36870  269.23730
# 39          39           0  2023   524.18410  266.59055

# %%
import matplotlib.pyplot as plt

# Filter for one polygon if you want to test, or loop through unique IDs
unique_polygons = dfx['polygon_id'].unique()

plt.figure(figsize=(12, 6))

for pid in unique_polygons:
    subset = dfx[dfx['polygon_id'] == pid]
    
    # Plot mean with std as error bar
    plt.errorbar(
        subset['year'].astype(int), 
        subset['mean'], 
        yerr=subset['std'], 
        label=f'Polygon {pid}',
        fmt='-o', 
        capsize=3,
        alpha=0.7
    )

plt.xlabel('')
plt.ylabel('Mean AGB (g/$m^2$)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0, None) # Keeping y-axis at 0
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

g = sns.FacetGrid(dfx, col="polygon_id", col_wrap=3, height=4, sharey=True)
g.map(plt.errorbar, "year", "mean", "std", fmt="-o", capsize=3)
g.set_titles("Polygon {col_name}")
g.set_axis_labels("Year", "Biomass Mean")
g.set(ylim=(0, None))
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

    
# Plot mean with std as error bar
plt.errorbar(
    subset['year'].astype(int), 
    subset['mean'], 
#     yerr=subset['std'], 
    label=f'Polygon {pid}',
    fmt='o', 
    capsize=3,
    alpha=0.7
)

plt.xlabel('')
plt.ylim(0, 1500)
plt.ylabel('Mean AGB (g/$m^2$)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0, None) # Keeping y-axis at 0
plt.tight_layout()
plt.show()

# %%
##Jekyll area 

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

# Plot mean with std as error bar
plt.errorbar(
    dfy['year'].astype(int), 
    dfy['mean'], 
    yerr=dfy['std'], 
    fmt='-o',
    color = 'black',
    capsize=3,
    alpha=0.7
)

plt.xlabel('')
plt.ylim(0, 2000)
plt.ylabel('Mean AGB (g/$m^2$)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0, None) # Keeping y-axis at 0
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Fin
