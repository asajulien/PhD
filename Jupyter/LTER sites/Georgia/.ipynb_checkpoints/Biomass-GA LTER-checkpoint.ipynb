# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdb
from IPython.display import display
import os
import seaborn as sns
import statsmodels.formula.api as sm
from numpy.polynomial.polynomial import polyfit
from sklearn.model_selection import train_test_split
import sklearn
from math import sqrt
import glob

# %%
##import and concatenate datasets
##Mac:
# path = r'/Users/asariversjulien/Documents/Data/CSV files/Pennings'
# all_files = glob.glob(path + "/*.csv")

# li = []

# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     li.append(df)

# df = pd.concat(li, axis=0, ignore_index=True)

##PC:
path = r'C:/Users/arj26323/Documents/Data/Biomass datasets/Pennings' 
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

##Begin:
##Important note 2/9/2022: Need to sum all biomass measurements within each plot, then divide by quadrat area \
##Pennings measured biomass of each individual plant within quadrat - currently you are finding the average for each plant
##Will change everything

#df['Plant_Biomass'] = df['Plant_Biomass']/df['Quadrat_Area'] ##adjust to grams/m^2

df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

#df = df[df['Species_Code'] == 'A1'] ##Remove all non-Spartina alterniflora plots - messes up unique coordinates section
##Need to filter out other species later!

df = df[df['Zone'] >= 0] ##Zone "-1" in 2013 needs to be addressed - refers to old plot location that was relocated

df['Plant_Biomass'].hist(bins = 50)
print(max(df['Plant_Biomass']))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#       1 ##import and concatenate datasets
#       2 ##Mac:
#       3 # path = r'/Users/asariversjulien/Documents/Data/CSV files/Pennings'
#    (...)
#      13
#      14 ##PC:
#      15 path = r'C:/Users/arj26323/Documents/Data/Biomass datasets/Pennings'
# ---> 16 all_files = glob.glob(path + "/*.csv")
#      18 li = []
#      20 for filename in all_files:
#
# NameError: name 'glob' is not defined

# %%
##Sum biomass, and coordinates

# df = df[df['Species_Code'] == 'A1'] ##Remove non-Spartina alterniflora species

df_sum = df.groupby(['Plot', 'Zone', 'Site', 'Year'], as_index = False).aggregate(
    {
        'Plant_Biomass':[np.sum, np.size],'Longitude':[np.mean], 'Latitude':[np.mean], 'Quadrat_Area':[np.mean], 
        'Species_Code':'first', 'Flowering_Status':'first','Date':'first'
    }
) 

df_sum.columns = [
    'Plot','Zone','Site','Year','Plant_Biomass', 'Sample_Size', 'Longitude', 'Latitude', 'Quadrat_Area', 'Species_Code',
    'Flowering_Status', 'Date'
]

##(:[np.mean] thrown in to detect differences within plot, though there shouldn't be any)

df_sum['Plant_Biomass'] = df_sum['Plant_Biomass']/df_sum['Quadrat_Area']

df_sum['Plant_Biomass'].hist(bins = 50) ##Note: Greatest biomass plots are not S. alterniflora - will be removed
df_sum

## note: df_sum is cross-referenced with raw data from Pennings - biomass and lat/long are correct

##All coordinates, not separated by year
# df_sum_coords = df_sum.groupby(['Plot', 'Zone', 'Site'], as_index = False).aggregate({'Longitude':[np.mean], \
#                                 'Latitude':[np.mean], 'Quadrat_Area':[np.mean], 'Species_Code':'first', \
#                                 'Flowering_Status':'first','Date':'first'})

# df_sum_coords.columns = ['Plot','Zone','Site','Longitude', 'Latitude', \
#                'Quadrat_Area', 'Species_Code','Flowering_Status', 'Date']

# df_sum_coords

# coords_all = df_sum_coords[['Longitude', 'Latitude']]
# coords_all

##NOTE (5/24/22): Flowering status will confuse the csv_to_gee (feature class) function due to NaNs
##IDEA: make different coordinate spreadsheets for EACH YEAR (e.g. name it coords_2000); just need to use df_sum


coords_2000 = df_sum[df_sum['Year'] == 2000]
print(len(coords_2000[['Longitude']]))
coords_2001 = df_sum[df_sum['Year'] == 2001]
coords_2002 = df_sum[df_sum['Year'] == 2002]
coords_2003 = df_sum[df_sum['Year'] == 2003]
coords_2004 = df_sum[df_sum['Year'] == 2004]
coords_2005 = df_sum[df_sum['Year'] == 2005]
coords_2006 = df_sum[df_sum['Year'] == 2006]
coords_2007 = df_sum[df_sum['Year'] == 2007]
coords_2008 = df_sum[df_sum['Year'] == 2008]
coords_2009 = df_sum[df_sum['Year'] == 2009]
coords_2010 = df_sum[df_sum['Year'] == 2010]
coords_2011 = df_sum[df_sum['Year'] == 2011]
coords_2012 = df_sum[df_sum['Year'] == 2012]
coords_2013 = df_sum[df_sum['Year'] == 2013]
coords_2014 = df_sum[df_sum['Year'] == 2014]
coords_2015 = df_sum[df_sum['Year'] == 2015]
coords_2016 = df_sum[df_sum['Year'] == 2016]
coords_2017 = df_sum[df_sum['Year'] == 2017]
coords_2018 = df_sum[df_sum['Year'] == 2018]
coords_2019 = df_sum[df_sum['Year'] == 2019]
print(len(coords_2019[['Longitude']]))
print(coords_2019)

#Export CSV file
out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'GA_allplots_NEW.csv')
# df_sum.to_csv(out_csv, index = False)

print('biomass median is: '+str(df_sum['Plant_Biomass'].median()))
print('biomass mean is: '+str(df_sum['Plant_Biomass'].mean()))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14732\799751117.py in <module>
#      19 df_sum['Plant_Biomass'] = df_sum['Plant_Biomass']/df_sum['Quadrat_Area']
#      20
# ---> 21 df_sum['Plant_Biomass'].hist(bins = 50) ##Note: Greatest biomass plots are not S. alterniflora - will be removed
#      22 df_sum
#      23
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      97     matplotlib.axes.Axes.hist : Plot a histogram using matplotlib.
#      98     """
# ---> 99     plot_backend = _get_plot_backend(backend)
#     100     return plot_backend.hist_series(
#     101         self,
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1812         return _backends[backend]
#    1813
# -> 1814     module = _load_backend(backend)
#    1815     _backends[backend] = module
#    1816     return module
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\pandas\plotting\_core.py in _load_backend(backend)
#    1752             module = importlib.import_module("pandas.plotting._matplotlib")
#    1753         except ImportError:
# -> 1754             raise ImportError(
#    1755                 "matplotlib is required for plotting when the "
#    1756                 'default backend "matplotlib" is selected.'
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
#Hist plot
import seaborn as sn

df_sum =df_sum[df_sum['Species_Code'] == 'A1']
g = sn.histplot(data = df_sum, x = 'Plant_Biomass', bins = 80)
g.set(xlabel='Aboveground biomass (g $m^{-2}$)', ylabel='Frequency(count)')
g
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14732\2638671405.py in <module>
#       1 #Hist plot
# ----> 2 import seaborn as sn
#       3
#       4 df_sum =df_sum[df_sum['Species_Code'] == 'A1']
#       5 g = sn.histplot(data = df_sum, x = 'Plant_Biomass', bins = 80)
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\seaborn\__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\seaborn\rcmod.py in <module>
#       3 import functools
#       4 from distutils.version import LooseVersion
# ----> 5 import matplotlib as mpl
#       6 from cycler import cycler
#       7 from . import palettes
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\matplotlib\__init__.py in <module>
#     127 # cbook must import matplotlib only within function
#     128 # definitions, so it is safe to import from it here.
# --> 129 from . import _api, _version, cbook, _docstring, rcsetup
#     130 from matplotlib.cbook import sanitize_sequence
#     131 from matplotlib._api import MatplotlibDeprecationWarning
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\matplotlib\rcsetup.py in <module>
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\matplotlib\colors.py in <module>
#      49 from numbers import Number
#      50 import re
# ---> 51 from PIL import Image
#      52 from PIL.PngImagePlugin import PngInfo
#      53
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\PIL\Image.py in <module>
#      98     # Also note that Image.core is not a publicly documented interface,
#      99     # and should be considered private and subject to change.
# --> 100     from . import _imaging as core
#     101
#     102     if __version__ != getattr(core, "PILLOW_VERSION", None):
#
# ImportError: DLL load failed while importing _imaging: The specified module could not be found.

# %%
#df['Plant_Biomass'].hist(by=df['Year'])

df2 = df_sum.groupby(['Zone', 'Site', 'Year'], as_index = False).aggregate({'Plant_Biomass':[np.mean, np.size, np.std], \
    'Longitude':[np.mean], 'Latitude':[np.mean], 'Quadrat_Area':'first', 'Species_Code':'first', 'Flowering_Status':'first', \
    'Date':[np.mean]}) 
##grouping by zone, average the plots together (along with lat/long in df_sum) - this will be used to scale up to landsat data
##Average plot coordinates together! In previous step (df_sum from df) all coordinates were the same within grouping

df2.columns = ['Zone','Site','Year','Mean_Biomass', 'Sample_Size', 'Std_Biomass', 'Longitude', 'Latitude', \
               'Quadrat_Area', 'Species_Code','Flowering_Status', 'Date']

df2['SE_Biomass'] = df2['Std_Biomass']/np.sqrt(df2['Sample_Size'])

df2['Mean_Biomass'].hist(bins = 50)

df2
# df3 = df.groupby(['Plot', 'Zone', 'Site', 'Year'], as_index = False).mean()
# site_list = [7]
# df4 = df[df['Site'].isin(site_list)]
##site 7 seems to have the highest biomass
# list(df2) ##need to rename columns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14732\1602022738.py in <module>
#      12 df2['SE_Biomass'] = df2['Std_Biomass']/np.sqrt(df2['Sample_Size'])
#      13
# ---> 14 df2['Mean_Biomass'].hist(bins = 50)
#      15
#      16 df2
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      97     matplotlib.axes.Axes.hist : Plot a histogram using matplotlib.
#      98     """
# ---> 99     plot_backend = _get_plot_backend(backend)
#     100     return plot_backend.hist_series(
#     101         self,
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1812         return _backends[backend]
#    1813
# -> 1814     module = _load_backend(backend)
#    1815     _backends[backend] = module
#    1816     return module
#
# C:\ProgramData\Anaconda3\envs\venv\lib\site-packages\pandas\plotting\_core.py in _load_backend(backend)
#    1752             module = importlib.import_module("pandas.plotting._matplotlib")
#    1753         except ImportError:
# -> 1754             raise ImportError(
#    1755                 "matplotlib is required for plotting when the "
#    1756                 'default backend "matplotlib" is selected.'
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
# df_x = df.groupby(['Site'], as_index = False).mean()
# df_x = df_x[['Site', 'Longitude', 'Latitude']]
# df_x
# ##lat/lon - these average lat/longs are used in GEE script! They are the points used in analysis. Lats/longs for \
# ##individual plots are shown in the df_plots dataframe below

# %%
##All coordinates (does not work if df is filtered to only Spartina alterniflora, not sure why though)
longx = df['Longitude'].unique()
latx = df['Latitude'].unique()

unique_coordinates = pd.DataFrame(latx, longx)

print(len(longx))
print(len(longx))

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     print(unique_coordinates)
# Out:
# 203
# 203

# %%
##Unique values for dates - match with imagery in GEE
print(df['Year'].unique())
df_z = df.groupby('Year')['Day'].unique()

print(df_z)

##Locations of each plot, for each zone/site, on each sampling date
lat_x = df.groupby(['Year','Day', 'Site', 'Zone', 'Plot'], as_index=False)['Latitude'].mean()
# print(lat_x)

long_x = df.groupby(['Year','Day', 'Site', 'Zone', 'Plot'], as_index=False)['Longitude'].mean()
# print(long_x)

df_plots = pd.merge(lat_x, long_x)
print(df_plots) ##there is a better way of doing this than averaging - can you confirm?

##Export df_plots as CSV file - to then load in GEE-GA file
in_fc = df_plots
out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'GA_allplots.csv')
#df_plots.to_csv(out_csv, index = False)

print("feesh")
print(len(df_plots['Longitude'].unique()))
print(len(df_plots['Latitude'].unique()))
# Out:
# [2000 2001 2002 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
#  2015 2016 2017 2018 2019]
# Year
# 2000    [11, 18, 10, 12, 13, 17, 16]
# 2001           [17, 15, 16, 8, 5, 9]
# 2002    [16, 18, 20, 15, 19, 14, 17]
# 2004                [25, 22, 24, 23]
# 2005        [24, 27, 22, 26, 21, 23]
# 2006                [16, 17, 15, 14]
# 2007            [22, 23, 24, 21, 20]
# 2008                [27, 28, 26, 25]
# 2009                [16, 15, 17, 14]
# 2010                [19, 20, 21, 18]
# 2011                [25, 27, 24, 26]
# 2012                [13, 14, 15, 12]
# 2013            [16, 18, 13, 15, 14]
# 2014        [17, 16, 18, 20, 21, 15]
# 2015    [20, 22, 25, 21, 15, 23, 24]
# 2016            [26, 25, 23, 24, 27]
# 2017        [14, 18, 19, 23, 16, 20]
# 2018    [13, 17, 14, 19, 12, 15, 16]
# 2019             [4, 11, 9, 8, 7, 5]
# Name: Day, dtype: object
#       Year  Day  Site  Zone  Plot   Latitude  Longitude
# 0     2000   10     4     1     1  31.451676 -81.365498
# 1     2000   10     4     1     2  31.451548 -81.365560
# 2     2000   10     4     1     3  31.451473 -81.365566
# 3     2000   10     4     1     4  31.451373 -81.365579
# 4     2000   10     4     1     5  31.451197 -81.366132
# ...    ...  ...   ...   ...   ...        ...        ...
# 3211  2019   11     5     2     4  31.435830 -81.341134
# 3212  2019   11     5     2     5  31.435748 -81.341275
# 3213  2019   11     5     2     6  31.435647 -81.341406
# 3214  2019   11     5     2     7  31.435543 -81.341501
# 3215  2019   11     5     2     8  31.435437 -81.341614
#
# [3216 rows x 7 columns]
# feesh
# 260
# 500

# %%
# sns.scatterplot( x = 'Date', y = 'Plant_Biomass', hue = 'Site', data = df[df['Species_Code'] == 'A1'])

# %%
##Exporting coordinates

out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'plotcoord.csv')

#df_plots.to_csv(out_csv)

# %%
##Create dataframe with both biomass and band data from gee
##Important note: GA_bands vs GA_avtest are now different versions of same process - ga_bands was created (1/2)
##before I realized I needed to sum within each plot first. Recommend removing. (2/2)

##NOTE 2/9/22: need to recalculate ga_bands - not set up to merge with 
#ga_bands = pd.read_csv('C:/Users/arj26323/Documents/Data/Biomass datasets/Sapelo/ga_bands.csv')

# ga_avbands = pd.read_csv('C:/Users/arj26323/Documents/Data/Biomass datasets/Sapelo/ga_avtest.csv')
ga_avbands = pd.read_csv('C:/Users/arj26323/Documents/Data/Biomass datasets/Sapelo/buffplots.csv') ##Buffer zones

master_plots = pd.merge(ga_avbands, df2) ##exported as csv; can re-upload, if need be 
##was this changed from masterplots file?

##Remove non-Spartina alterniflora rows (should be around 2400 rows, down from 3215)
master_plots = master_plots[master_plots['Species_Code'] == 'A1'] ##THIS IS A VERY IMPORTANT STEP!
dfx = master_plots ##NOTE: changed 'df' replica to 'dfx' - make sure all changes work

year_dict = {
    '10_':'2010x_',
    '11_':'2011x_',
    '12_':'2012x_',
    '13_':'2013x_',
    '14_':'2014x_',
    '15_':'2015x_',
    '16_':'2016x_',
    '17_':'2017x_',
    '18_':'2018x_',
    '19_':'2019x_',
    '0_':'2000x_',
    '1_':'2001x_',
    '2_':'2002x_',
    '3_':'2003x_',
    '4_':'2004x_',
    '5_':'2005x_',
    '6_':'2006x_',
    '7_':'2007x_',
    '8_':'2008x_',
    '9_':'2009x_'
} ## 'x' added to avoid applying dictionary to unintended columns; start with 10-19 also BRUTAL

for k, v in year_dict.items():
    dfx.columns = dfx.columns.str.replace(k, v)

dfx.columns = dfx.columns.str.replace('x', '') ##removing the 'x' BRUTAL

for col in dfx.columns:
    print(col)

# dfx

#dfx = dfx.drop(dfx.columns[[154, 155, 158, 159, 160, 162, 163, 164, 165, 166, 167, 168, 169, 170]], axis=1) ##BRUTAL, redo
##^^above for original ga_bands (before summing plots).

# dfx = dfx.drop(dfx.columns[[154, 157, 159, 160, 161, 162, 163, 164, 165, 166, 167]], axis=1) ##BRUTAL, redo. DID THIS WORK?
##^^above for non-buffered points

dfx = dfx.drop(dfx.columns[[154, 155, 158, 159, 160, 161, 163, 164, 165, 166, 167, 168, 169, 170, 171]], axis=1) 
##FOR BUFFERPLOTS ONLY^^^

##3-4-22: Removed all columns except for bands, year, and lat/long, then applied code below (then remerged)
##Seems like a roundabout way...
##Old work is still here, final product is GA_spectra. Most likely incorrect

##credit to stackexchange user modesitt for solving this:
ff = dfx.copy()  ## we will use this later
## split your variable column(s) into an identifier and value column
dfx = dfx.melt(id_vars=["Year", "Latitude", "Longitude"])
## parse the parts of {year}_A{n}
parts = dfx.variable.str.split("_")
dfx["var_year"] = parts.str[0].astype(int)
dfx["var_kind"] = parts.str[1]
dfx = dfx[dfx.var_year == dfx.Year] ## use your filtering criteria
ident = ["Year", "Latitude", "Longitude"]

## pivot the frame to get A{n} columns
##Asa note: changed to pivot_table() from pivot(); added 'index =' 
dfx = dfx.pivot_table(index = ident, columns="var_kind", values="value")
dfx = dfx.reset_index()
dfx = pd.merge(ff, dfx, on=ident)  ## retain original {year}_A{n}

dfx = pd.merge(dfx, master_plots) ##on=ident? seems to work fine without, just be careful
##THIS STEP NEEDS TO BE DOUBLE-CHECKED!
##Year, latitude, and longitude all disappear - is it possible to keep them in end product?

dfx ##exported as csv; watch for name overlap with different sections
# Out:
# 2000_B1
# 2000_B2
# 2000_B3
# 2000_B4
# 2000_B5
# 2000_B6
# 2000_B7
# 2001_B1
# 2001_B2
# 2001_B3
# 2001_B4
# 2001_B5
# 2001_B6
# 2001_B7
# 2002_B1
# 2002_B2
# 2002_B3
# 2002_B4
# 2002_B5
# 2002_B6
# 2002_B7
# 2003_B1
# 2003_B2
# 2003_B3
# 2003_B4
# 2003_B5
# 2003_B6
# 2003_B7
# 2004_B1
# 2004_B2
# 2004_B3
# 2004_B4
# 2004_B5
# 2004_B6
# 2004_B7
# 2005_B1
# 2005_B2
# 2005_B3
# 2005_B4
# 2005_B5
# 2005_B6
# 2005_B7
# 2006_B1
# 2006_B2
# 2006_B3
# 2006_B4
# 2006_B5
# 2006_B6
# 2006_B7
# 2007_B1
# 2007_B2
# 2007_B3
# 2007_B4
# 2007_B5
# 2007_B6
# 2007_B7
# 2008_B1
# 2008_B2
# 2008_B3
# 2008_B4
# 2008_B5
# 2008_B6
# 2008_B7
# 2009_B1
# 2009_B2
# 2009_B3
# 2009_B4
# 2009_B5
# 2009_B6
# 2009_B7
# 2010_B1
# 2010_B2
# 2010_B3
# 2010_B4
# 2010_B5
# 2010_B6
# 2010_B7
# 2011_B1
# 2011_B2
# 2011_B3
# 2011_B4
# 2011_B5
# 2011_B6
# 2011_B7
# 2012_B1
# 2012_B2
# 2012_B3
# 2012_B4
# 2012_B5
# 2012_B6
# 2012_B7
# 2013_B1
# 2013_B2
# 2013_B3
# 2013_B4
# 2013_B5
# 2013_B6
# 2013_B7
# 2013_B10
# 2013_B11
# 2014_B1
# 2014_B2
# 2014_B3
# 2014_B4
# 2014_B5
# 2014_B6
# 2014_B7
# 2014_B10
# 2014_B11
# 2015_B1
# 2015_B2
# 2015_B3
# 2015_B4
# 2015_B5
# 2015_B6
# 2015_B7
# 2015_B10
# 2015_B11
# 2016_B1
# 2016_B2
# 2016_B3
# 2016_B4
# 2016_B5
# 2016_B6
# 2016_B7
# 2016_B10
# 2016_B11
# 2017_B1
# 2017_B2
# 2017_B3
# 2017_B4
# 2017_B5
# 2017_B6
# 2017_B7
# 2017_B10
# 2017_B11
# 2018_B1
# 2018_B2
# 2018_B3
# 2018_B4
# 2018_B5
# 2018_B6
# 2018_B7
# 2018_B10
# 2018_B11
# 2019_B1
# 2019_B2
# 2019_B3
# 2019_B4
# 2019_B5
# 2019_B6
# 2019_B7
# 2019_B10
# 2019_B11
# system:inde
# BUFF_DIST
# Latitude
# Longitude
# ORIG_FID
# Shape_Area
# Shape_Leng
# Site
# Year
# Zone
# Mean_Biomass
# Sample_Size
# Std_Biomass
# Quadrat_Area
# Species_Code
# Flowering_Status
# Date
# SE_Biomass
#       2000_B1   2000_B2   2000_B3   2000_B4   2000_B5   2000_B6   2000_B7  \
# 0    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# 1    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# 2    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# 3    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# 4    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# ..        ...       ...       ...       ...       ...       ...       ...
# 194  0.031524  0.044658  0.043953  0.126128  0.095976  0.291671  0.052782
# 195  0.031524  0.044658  0.043953  0.126128  0.095976  0.291671  0.052782
# 196  0.031524  0.044658  0.043953  0.126128  0.095976  0.291671  0.052782
# 197  0.032938  0.045279  0.046781  0.128521  0.104049  0.291950  0.058142
# 198  0.032938  0.045279  0.046781  0.128521  0.104049  0.291950  0.058142
#
#       2001_B1   2001_B2   2001_B3  ...  Site  Zone  Mean_Biomass  Sample_Size  \
# 0    0.028453  0.043025  0.041849  ...     1     1      690.3910            8
# 1    0.028453  0.043025  0.041849  ...     1     1      674.2440            8
# 2    0.028453  0.043025  0.041849  ...     1     1      774.9750            8
# 3    0.028453  0.043025  0.041849  ...     1     1      469.3465            8
# 4    0.028453  0.043025  0.041849  ...     1     1     1492.8820            8
# ..        ...       ...       ...  ...   ...   ...           ...          ...
# 194  0.029821  0.041492  0.041291  ...    10     2      601.9100            8
# 195  0.029821  0.041492  0.041291  ...    10     2      392.8120            8
# 196  0.029821  0.041492  0.041291  ...    10     2      595.2660            8
# 197  0.031206  0.041876  0.043186  ...    10     3      752.1860            8
# 198  0.031206  0.041876  0.043186  ...    10     3      709.5100            8
#
#      Std_Biomass  Quadrat_Area  Species_Code  Flowering_Status       Date  \
# 0     258.763177        0.2500            A1               0.0 2000-10-11
# 1     323.092134        0.2500            A1               1.0 2001-10-17
# 2     587.820341        0.2500            A1               0.0 2002-10-16
# 3     250.973879        0.2500            A1               0.0 2004-10-25
# 4     746.511111        0.2500            A1               0.0 2005-10-24
# ..           ...           ...           ...               ...        ...
# 194   324.772537        0.0625            A1               0.0 2013-10-13
# 195   135.427704        0.0625            A1               0.0 2016-10-27
# 196   240.200103        0.0625            A1               0.0 2017-10-19
# 197   204.014064        0.0625            A1               0.0 2008-10-26
# 198   294.153887        0.0625            A1               0.0 2009-10-17
#
#      SE_Biomass
# 0     91.486598
# 1    114.230319
# 2    207.825874
# 3     88.732666
# 4    263.931534
# ..          ...
# 194  114.824432
# 195   47.880924
# 196   84.923561
# 197   72.129864
# 198  103.999104
#
# [199 rows x 181 columns]

# %%
##Massaging the data
dfx['Sensor'] = np.where(dfx['Year']<2013, 'Landsat 5', 'Landsat 8')

dfx['ndvi'] = np.where(dfx['Sensor'] == 'Landsat 5', (dfx['B4']-dfx['B3'])/(dfx['B4']+dfx['B3']), \
                      (dfx['B5']-dfx['B4'])/(dfx['B5']+dfx['B4'])) ##ndvi conditional based on whether sensor is Landsat-5 or 8

dfx['Blue_band'] = np.where(dfx['Sensor'] == 'Landsat 5', dfx['B1'], dfx['B2'])
dfx['Green_band'] = np.where(dfx['Sensor'] == 'Landsat 5', dfx['B2'], dfx['B3'])
dfx['Red_band'] = np.where(dfx['Sensor'] == 'Landsat 5', dfx['B3'], dfx['B4'])
dfx['NIR_band'] = np.where(dfx['Sensor'] == 'Landsat 5', dfx['B4'], dfx['B5'])
dfx['SWIR1_band'] = np.where(dfx['Sensor'] == 'Landsat 5', dfx['B5'], dfx['B6'])
dfx['SWIR2_band'] = np.where(dfx['Sensor'] == 'Landsat 5', dfx['B7'], dfx['B7'])

##Variables from Byrd et al. 2018

dfx['savi'] = ((dfx['NIR_band']-dfx['Red_band'])*1.5)/(dfx['NIR_band']+dfx['Red_band']+0.5)
dfx['wdrvi5'] = (0.5*dfx['NIR_band']-dfx['Red_band'])/(0.5*dfx['NIR_band']+dfx['Red_band'])
dfx['nd_r_g'] = (dfx['Red_band']-dfx['Green_band'])/(dfx['Red_band']+dfx['Green_band'])
dfx['nd_g_b'] = (dfx['Green_band']-dfx['Blue_band'])/(dfx['Green_band']+dfx['Blue_band'])
dfx['nd_swir2_nir'] = (dfx['SWIR2_band']-dfx['NIR_band'])/(dfx['SWIR2_band']+dfx['NIR_band'])
dfx['nd_swir2_r'] = (dfx['SWIR2_band']-dfx['Red_band'])/(dfx['SWIR2_band']+dfx['Red_band'])

dfx
##Note: Landsat 5 from 2011-2013 was with the MSS; may have to remove
##Another note: NOT EXACT MATCHES BETWEEN L5 AND L8 for each band type! Use indices such as ndvi
# Out:
#       2000_B1   2000_B2   2000_B3   2000_B4   2000_B5   2000_B6   2000_B7  \
# 0    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# 1    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# 2    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# 3    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# 4    0.027004  0.035713  0.033428  0.055247  0.044956  0.290819  0.026624
# ..        ...       ...       ...       ...       ...       ...       ...
# 194  0.031524  0.044658  0.043953  0.126128  0.095976  0.291671  0.052782
# 195  0.031524  0.044658  0.043953  0.126128  0.095976  0.291671  0.052782
# 196  0.031524  0.044658  0.043953  0.126128  0.095976  0.291671  0.052782
# 197  0.032938  0.045279  0.046781  0.128521  0.104049  0.291950  0.058142
# 198  0.032938  0.045279  0.046781  0.128521  0.104049  0.291950  0.058142
#
#       2001_B1   2001_B2   2001_B3  ...  Red_band  NIR_band  SWIR1_band  \
# 0    0.028453  0.043025  0.041849  ...  0.033428  0.055247    0.044956
# 1    0.028453  0.043025  0.041849  ...  0.041849  0.076135    0.069389
# 2    0.028453  0.043025  0.041849  ...  0.032704  0.063922    0.040587
# 3    0.028453  0.043025  0.041849  ...  0.036731  0.081133    0.065510
# 4    0.028453  0.043025  0.041849  ...  0.029858  0.088674    0.056085
# ..        ...       ...       ...  ...       ...       ...         ...
# 194  0.029821  0.041492  0.041291  ...  0.033392  0.132351    0.083477
# 195  0.029821  0.041492  0.041291  ...  0.055914  0.181339    0.137969
# 196  0.029821  0.041492  0.041291  ...  0.037701  0.137005    0.094602
# 197  0.031206  0.041876  0.043186  ...  0.044085  0.113884    0.079894
# 198  0.031206  0.041876  0.043186  ...  0.043157  0.126582    0.097663
#
#      SWIR2_band      savi    wdrvi5    nd_r_g    nd_g_b  nd_swir2_nir  \
# 0      0.026624  0.055597 -0.095074 -0.033046  0.138862     -0.349608
# 1      0.045643  0.083222 -0.047315 -0.013856  0.203871     -0.250395
# 2      0.024642  0.078485 -0.011496 -0.031584  0.077028     -0.443519
# 3      0.037662  0.107795  0.049621 -0.029302  0.122819     -0.365935
# 4      0.029385  0.142635  0.195148 -0.013156  0.088420     -0.502193
# ..          ...       ...       ...       ...       ...           ...
# 194    0.045949  0.222968  0.329265 -0.024207  0.141987     -0.484585
# 195    0.074263  0.255187  0.237104 -0.043631  0.142896     -0.418915
# 196    0.049482  0.220773  0.290029 -0.047019  0.150276     -0.469322
# 197    0.045011  0.159124  0.127264 -0.023785  0.159489     -0.433454
# 198    0.051270  0.186845  0.189143 -0.006803  0.130364     -0.423457
#
#      nd_swir2_r
# 0     -0.113297
# 1      0.043362
# 2     -0.140588
# 3      0.012512
# 4     -0.007976
# ..          ...
# 194    0.158276
# 195    0.140957
# 196    0.135139
# 197    0.010389
# 198    0.085913
#
# [199 rows x 195 columns]

# %%
##Export master_plots as CSV file
##CURRENTLY SET UP FOR BUFFERED VERSION!!!
in_fc = dfx
out_dir = os.path.expanduser('~/Documents/Data/Biomass datasets/Sapelo')
out_csv = os.path.join(out_dir, 'GA_spectra_BUFFERED_6-16-22.csv')
#dfx.to_csv(out_csv, index = False)

# %%
##Allometry data - the plant height/biomass relationship - hidden for now, just uncomment to see plots
# allom_df = pd.read_csv('C:/Users/arj26323/Documents/Data/Biomass datasets/Pennings/Original data/Pennings_Allometry.csv', \
#                        skiprows = [0,1,3,4])
# allom_df = allom_df[allom_df['Species_Code'] == 'A1'] ##Remove all non-Spartina alterniflora plots; N now is 757 (not 1139)

# print(allom_df)
# print(len(allom_df['Plant_Mass']))

# g = sns.FacetGrid(allom_df, col = 'Site')
# g = (g.map(sns.scatterplot, 'Shoot_Height', 'Plant_Mass').add_legend())
# plt.show()

# g2 = sns.scatterplot(x = 'Shoot_Height', y = 'Plant_Mass', data = allom_df)
# plt.show()
##equation for relationship: ln(Biomass) = constant + htslope*ln(Plant_Height) + flslope*ln(Flowering_Status)
##this equation changes between sites, species, and years; see metadata (search 'allom' until you find it)
##Spartina alterniflora (A1) only done in 2002

# %%
##NEW ALLPLOTS CSV (different from allplots_av csv file and file in GA-GEE)
allplots_av2 = df_sum[df_sum['Species_Code'] == 'A1'].groupby(['Plot','Zone', 'Site', 'Year'], as_index = False).aggregate({\
    'Longitude':'first', 'Latitude':'first'}) ##Limiting the species to Spartina alterniflora

allplots_av2.columns = ['Plot','Zone','Site','Year','Longitude', 'Latitude']

allplots_av2
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  ## more options can be specified also
    print(allplots_av2)
# Out:
#       Plot  Zone  Site  Year  Longitude   Latitude
# 0        1     1     1  2000 -81.422539  31.538627
# 1        1     1     1  2001 -81.422539  31.538627
# 2        1     1     1  2002 -81.422539  31.538627
# 3        1     1     1  2004 -81.422539  31.538627
# 4        1     1     1  2005 -81.422539  31.538627
# 5        1     1     1  2006 -81.422539  31.538627
# 6        1     1     1  2007 -81.422539  31.538627
# 7        1     1     1  2008 -81.422539  31.538627
# 8        1     1     1  2009 -81.422539  31.538627
# 9        1     1     1  2010 -81.422539  31.538627
# 10       1     1     1  2011 -81.422539  31.538627
# 11       1     1     1  2012 -81.422539  31.538627
# 12       1     1     1  2013 -81.422539  31.538627
# 13       1     1     1  2014 -81.422539  31.538627
# 14       1     1     1  2015 -81.422539  31.538627
# 15       1     1     1  2016 -81.422539  31.538627
# 16       1     1     1  2017 -81.422539  31.538627
# 17       1     1     1  2018 -81.422539  31.538627
# 18       1     1     1  2019 -81.422539  31.538627
# 19       1     1     2  2000 -81.296118  31.536199
# 20       1     1     2  2001 -81.296118  31.536199
# 21       1     1     3  2000 -81.228956  31.518920
# 22       1     1     3  2001 -81.228956  31.518920
# 23       1     1     3  2002 -81.228956  31.518920
# 24       1     1     3  2004 -81.228956  31.518920
# 25       1     1     3  2005 -81.228956  31.518920
# 26       1     1     3  2006 -81.228956  31.518920
# 27       1     1     3  2007 -81.228956  31.518920
# 28       1     1     3  2008 -81.228956  31.518920
# 29       1     1     3  2009 -81.228956  31.518920
# 30       1     1     3  2010 -81.228956  31.518920
# 31       1     1     3  2011 -81.228956  31.518920
# 32       1     1     3  2012 -81.228956  31.518920
# 33       1     1     4  2000 -81.365498  31.451676
# 34       1     1     4  2001 -81.365498  31.451676
# 35       1     1     4  2002 -81.365498  31.451676
# 36       1     1     4  2004 -81.365498  31.451676
# 37       1     1     4  2005 -81.365498  31.451676
# 38       1     1     4  2006 -81.365498  31.451676
# 39       1     1     4  2007 -81.365498  31.451676
# 40       1     1     4  2008 -81.365498  31.451676
# 41       1     1     4  2009 -81.365498  31.451676
# 42       1     1     4  2010 -81.365498  31.451676
# 43       1     1     4  2011 -81.365498  31.451676
# 44       1     1     4  2012 -81.365498  31.451676
# 45       1     1     4  2013 -81.365498  31.451676
# 46       1     1     4  2014 -81.365498  31.451676
# 47       1     1     5  2000 -81.339919  31.436090
# 2276    46     1     4  2012 -81.366151  31.451282
# 2277    46     1     4  2013 -81.366151  31.451282
# 2278    46     1     4  2014 -81.366151  31.451282
# 2279    46     1     4  2015 -81.366151  31.451282
# 2280    46     1     4  2016 -81.366151  31.451282
# 2281    46     1     4  2017 -81.366151  31.451282
# 2282    46     1     6  2018 -81.279719  31.387776
# 2283    46     1     6  2019 -81.279719  31.387776
# 2284    47     1     2  2018 -81.295132  31.535747
# 2285    47     1     2  2019 -81.295132  31.535747
# 2286    48     1     2  2011 -81.295103  31.535651
# 2287    48     1     2  2012 -81.295100  31.535648
# 2288    48     1     2  2013 -81.295100  31.535648
# 2289    48     1     2  2014 -81.295100  31.535648
# 2290    48     1     2  2015 -81.295100  31.535648
# 2291    51     1     2  2018 -81.296087  31.536199
# 2292    51     1     2  2019 -81.296087  31.536199
# 2293    52     1     2  2016 -81.295883  31.536196
# 2294    52     1     2  2017 -81.295883  31.536196
# 2295    53     1     2  2018 -81.295753  31.536255
# 2296    53     1     2  2019 -81.295753  31.536255
# 2297    53     1     6  2015 -81.279884  31.388212
# 2298    53     1     6  2016 -81.279884  31.388212
# 2299    53     1     6  2017 -81.279884  31.388212
# 2300    53     1     6  2018 -81.279884  31.388212
# 2301    53     1     6  2019 -81.279884  31.388212
# 2302    53     1     9  2018 -81.333980  31.351949
# 2303    53     1     9  2019 -81.333980  31.351949
# 2304    54     1     6  2015 -81.279858  31.388000
# 2305    54     1     6  2016 -81.279858  31.388000
# 2306    54     1     6  2017 -81.279858  31.388000
# 2307    55     1     1  2016 -81.422320  31.538420
# 2308    55     1     8  2018 -81.415592  31.307693
# 2309    55     1     8  2019 -81.415592  31.307693
# 2310    56     1     4  2018 -81.366151  31.451282
# 2311    56     1     4  2019 -81.366151  31.451282
# 2312    58     1     2  2016 -81.295100  31.535648
# 2313    58     1     2  2017 -81.295100  31.535648
# 2314    58     1     2  2018 -81.295100  31.535648
# 2315    58     1     2  2019 -81.295100  31.535648
# 2316    62     1     2  2018 -81.295883  31.536196
# 2317    62     1     2  2019 -81.295883  31.536196
# 2318    64     1     6  2018 -81.279858  31.388000
# 2319    64     1     6  2019 -81.279858  31.388000
# 2320    65     1     1  2017 -81.422320  31.538420
# 2321    65     1     1  2018 -81.422320  31.538420
# 2322    65     1     1  2019 -81.422320  31.538420

# %%
##AllPLOTS - unique plot coordinates, not separated by year
print(len(allplots_av2['Latitude'].unique()))
print(len(allplots_av2['Longitude'].unique())) ##WHY is this so different?
##Same discrepancy as df_plots (above), numbers are different here because non-Spartina plots are exluded in allplots_av2

print(len(df_sum['Latitude'].unique()))
print(len(df_sum['Longitude'].unique()))
# Out:
# 370
# 198
# 500
# 260

# %%
##Export CSV file to then load as feature class
in_fc = allplots_av2
out_dir = os.path.expanduser('~/Documents/Data/Biomass datasets/Sapelo')
out_csv = os.path.join(out_dir, 'allplots_av2.csv')
#allplots_av2.to_csv(out_csv, index = False)
#print(df)

##Export CSV file
out_dir = os.path.expanduser('~/Downloads')
out_csv = os.path.join(out_dir, 'xxx.csv')
#master_plots.to_csv(out_csv, index = False)
#print(df)
